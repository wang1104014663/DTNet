# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os
from My_Loss import HardTripletLoss
from tensorboardX import SummaryWriter

# %%
BATCH_SIZE = 64
EPISODE = 200000
TEST_EPISODE = 1000
LEARNING_RATE =1e-5
Weight_Deacy = 1e-4
GPU = 0
Margin = 3

# %%
print("init dataset")
##################################参数##################################################################
dataroot = '../data'
dataset = 'AwA1_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'original_att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个


    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net_3 import AttributeNetwork
from my_net_3 import AttributeNetwork2
from my_net_3 import MetricNetwork

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork2(85,1024,1024,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
metric_network = MetricNetwork(2048,1024,2048)

attribute_network.cuda(GPU) 
metric_network.cuda(GPU)

#学习率每200k步 乘0.5
attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE,weight_decay=Weight_Deacy)
metric_network_optim = torch.optim.Adam(metric_network.parameters(), lr=LEARNING_RATE,weight_decay=Weight_Deacy)
#
#triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE,momentum=0.9 , 
#                                         weight_decay=Weight_Deacy)

attribute_network_scheduler = StepLR(attribute_network_optim , step_size=20000 , gamma=0.5)
metric_network_scheduler = StepLR(metric_network_optim , step_size=20000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = metric_network(Variable(batch_features_ext).cuda(GPU).float())  # 32*1024


        sample_features = metric_network(attribute_network(Variable(sample_attributes).cuda(GPU).float()))
        sample_features_ext = sample_features.repeat(batch_size, 1)


        relations = F.pairwise_distance(batch_features_ext, sample_features_ext, 2).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
def compute_accuracy_per_class(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0
    #print(test_features.size())
    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]
    per_class_num = np.zeros(class_num)
    per_class_true= np.zeros(class_num)

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = metric_network(Variable(batch_features_ext).cuda(GPU).float())  # 32*1024


        sample_features = metric_network(attribute_network(Variable(sample_attributes).cuda(GPU).float()))
        sample_features_ext = sample_features.repeat(batch_size, 1)


        relations = F.pairwise_distance(batch_features_ext, sample_features_ext, 2).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels_id, batch_per_num = np.unique(re_batch_labels , return_counts=True) 
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)
        
        for each in range(re_batch_labels_id.size):
            #print(re_batch_labels_id[each])
            #print(batch_per_num[each])
            per_class_num[re_batch_labels_id[each]] = per_class_num[re_batch_labels_id[each]] + batch_per_num[each]
        #print(re_batch_labels_id)
        #print('-'*100)
        #print(batch_per_num)
        #print('-'*100)


        _, predict_labels = torch.min(relations.data, 1)
        for j in range(batch_size):
            if predict_labels[j] == re_batch_labels[j]:
                per_class_true[re_batch_labels[j]] = per_class_true[re_batch_labels[j]] + 1
            
        
        
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    per_accuracy = per_class_true[np.nonzero(per_class_num)] / per_class_num[np.nonzero(per_class_num)]
    

    test_accuracy = np.sum(per_accuracy)/1.0/np.count_nonzero(per_class_num)
    test_accuracy2 = total_rewards/1.0/test_size
    #print(np.count_nonzero(per_class_num))
    return  test_accuracy, test_accuracy2

# %%
print("training...")
last_accuracy = 0.0
loss_zero_num =0
#writer = SummaryWriter()
for episode in range(EPISODE):

    attribute_network_scheduler.step(episode)
    metric_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    batch_id = np.unique(batch_labels)

    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_id]).squeeze(1)
    batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(batch_id.size, 0))
    batch_attributes_ext = batch_attributes.repeat(BATCH_SIZE, 1)

    batch_features_ext = Variable(batch_features_ext).cuda(GPU).float()  # 32*2048
    batch_attributes_ext = Variable(batch_attributes_ext).cuda(GPU)


    re_batch_labels = []
    for label in batch_labels.numpy():
        index = np.argwhere(batch_id == label)
        re_batch_labels.append(index[0][0])
    re_batch_labels = torch.cuda.LongTensor(re_batch_labels)
    re_batch_labels = Variable(re_batch_labels).cuda(GPU)
    

    criterion = HardTripletLoss(margin = Margin).cuda(GPU)
    triplet_loss= criterion(metric_network(attribute_network(batch_attributes_ext)), 
                            metric_network(batch_features_ext), re_batch_labels)
    if triplet_loss == 0:
        loss_zero_num = loss_zero_num + 1
    
    
    attribute_network.zero_grad()
    metric_network.zero_grad()
    
    triplet_loss.backward()
    
    attribute_network_optim.step()
    metric_network_optim.step()

    
    if (episode+1)%200 == 0 or episode==0:
        print("episode:", episode+1, "loss", triplet_loss)
        print('loss_zero_number= ',loss_zero_num)
        loss_zero_num = 0
        #writer.add_scalar('data/loss', triplet_loss, episode)
    if (episode+1)%200 == 0 or episode==0:
        print("Testing...")
        #attribute_network.eval()
        zsl_accuracy, zsl_accuracy2 = compute_accuracy_per_class(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy , gzsl_unseen_accuracy2= compute_accuracy_per_class(test_features, test_label, np.arange(50), attributes)
        gzsl_seen_accuracy ,gzsl_seen_accuracy2 = compute_accuracy_per_class(test_seen_features, test_seen_label, np.arange(50), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        H2 = 2 * gzsl_seen_accuracy2 * gzsl_unseen_accuracy2 / (gzsl_unseen_accuracy2 + gzsl_seen_accuracy2)
        print('zsl:', zsl_accuracy)
        #print('zsl:', zsl_accuracy2)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        #print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy2 , gzsl_seen_accuracy2, H2))
        print('_'*100)
        #writer.add_scalar('data/zsl_accuracy', zsl_accuracy, episode)
        #writer.add_scalar('data/gzsl_unseen_accuracy', gzsl_unseen_accuracy, episode)
        #writer.add_scalar('data/gzsl_seen_accuracy', gzsl_seen_accuracy, episode)
        #writer.add_scalar('data/H', H, episode)
#writer.export_scalars_to_json("./test.json")
#writer.close()
# Out:
# training...
# episode: 1 loss tensor(3.0974, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.10347865714719733
# gzsl: unseen=0.0011 , seen=0.0230 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 200 loss tensor(2.9980, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.14017173851968995
# gzsl: unseen=0.1193 , seen=0.0717 , h=0.0896
# ____________________________________________________________________________________________________
# episode: 400 loss tensor(2.9420, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2732734525043905
# gzsl: unseen=0.1005 , seen=0.2067 , h=0.1352
# ____________________________________________________________________________________________________
# episode: 600 loss tensor(2.8760, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3507115184742197
# gzsl: unseen=0.1955 , seen=0.3779 , h=0.2577
# ____________________________________________________________________________________________________
# episode: 800 loss tensor(2.8068, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.4057267000244055
# gzsl: unseen=0.2337 , seen=0.4898 , h=0.3165
# ____________________________________________________________________________________________________
# episode: 1000 loss tensor(2.7758, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.540034893752248
# gzsl: unseen=0.3511 , seen=0.5810 , h=0.4377
# ____________________________________________________________________________________________________
# episode: 1200 loss tensor(2.6314, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5361187873202993
# gzsl: unseen=0.3710 , seen=0.6364 , h=0.4687
# ____________________________________________________________________________________________________
# episode: 1400 loss tensor(2.5309, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6086073649498405
# gzsl: unseen=0.4158 , seen=0.6707 , h=0.5133
# ____________________________________________________________________________________________________
# episode: 1600 loss tensor(2.3870, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5904531063773579
# gzsl: unseen=0.4341 , seen=0.6618 , h=0.5243
# ____________________________________________________________________________________________________
# episode: 1800 loss tensor(2.2619, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6158003514338726
# gzsl: unseen=0.4656 , seen=0.6440 , h=0.5405
# ____________________________________________________________________________________________________
# episode: 2000 loss tensor(2.5075, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5937003352594268
# gzsl: unseen=0.4219 , seen=0.6495 , h=0.5115
# ____________________________________________________________________________________________________
# episode: 2200 loss tensor(2.2358, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6303066390016443
# gzsl: unseen=0.4852 , seen=0.6510 , h=0.5560
# ____________________________________________________________________________________________________
# episode: 2400 loss tensor(2.1440, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6239375549926107
# gzsl: unseen=0.4644 , seen=0.6685 , h=0.5481
# ____________________________________________________________________________________________________
# episode: 2600 loss tensor(2.0857, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6254601804729478
# gzsl: unseen=0.4793 , seen=0.6586 , h=0.5549
# ____________________________________________________________________________________________________
# episode: 2800 loss tensor(2.0262, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6319503763164251
# gzsl: unseen=0.4747 , seen=0.6856 , h=0.5610
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(2.0105, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.657749866298672
# gzsl: unseen=0.4985 , seen=0.6960 , h=0.5809
# ____________________________________________________________________________________________________
# episode: 3200 loss tensor(2.0159, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6709731722227545
# gzsl: unseen=0.5016 , seen=0.6953 , h=0.5828
# ____________________________________________________________________________________________________
# episode: 3400 loss tensor(2.3543, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6612169108432584
# gzsl: unseen=0.4935 , seen=0.6970 , h=0.5778
# ____________________________________________________________________________________________________
# episode: 3600 loss tensor(1.9967, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.649985476304731
# gzsl: unseen=0.5025 , seen=0.7071 , h=0.5875
# ____________________________________________________________________________________________________
# episode: 3800 loss tensor(2.1680, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6466141461275625
# gzsl: unseen=0.4975 , seen=0.7078 , h=0.5843
# ____________________________________________________________________________________________________
# episode: 4000 loss tensor(2.0735, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6740834869399727
# gzsl: unseen=0.5294 , seen=0.7112 , h=0.6069
# ____________________________________________________________________________________________________
# episode: 4200 loss tensor(1.8847, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6564444118663202
# gzsl: unseen=0.4938 , seen=0.7039 , h=0.5804
# ____________________________________________________________________________________________________
# episode: 4400 loss tensor(2.1101, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6738281961314466
# gzsl: unseen=0.5078 , seen=0.7097 , h=0.5920
# ____________________________________________________________________________________________________
# episode: 4600 loss tensor(1.4645, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6813730228058101
# gzsl: unseen=0.4972 , seen=0.7205 , h=0.5884
# ____________________________________________________________________________________________________
# episode: 4800 loss tensor(1.8472, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6579818331097412
# gzsl: unseen=0.4886 , seen=0.7139 , h=0.5801
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(2.0433, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6650651932342719
# gzsl: unseen=0.4798 , seen=0.7321 , h=0.5797
# ____________________________________________________________________________________________________
# episode: 5200 loss tensor(1.8067, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6746561733319212
# gzsl: unseen=0.5110 , seen=0.7127 , h=0.5952
# ____________________________________________________________________________________________________
# episode: 5400 loss tensor(1.7127, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6760395405138919
# gzsl: unseen=0.4831 , seen=0.7333 , h=0.5825
# ____________________________________________________________________________________________________
# episode: 5600 loss tensor(2.7498, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.681955322936321
# gzsl: unseen=0.4961 , seen=0.7334 , h=0.5919
# ____________________________________________________________________________________________________
# episode: 5800 loss tensor(1.6129, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6654031636711998
# gzsl: unseen=0.5201 , seen=0.7144 , h=0.6020
# ____________________________________________________________________________________________________
# episode: 6000 loss tensor(1.1677, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6703266729593929
# gzsl: unseen=0.4897 , seen=0.7280 , h=0.5855
# ____________________________________________________________________________________________________
# episode: 6200 loss tensor(0.9665, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6709570692746204
# gzsl: unseen=0.5042 , seen=0.7195 , h=0.5929
# ____________________________________________________________________________________________________
# episode: 6400 loss tensor(1.6805, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6467046052844716
# gzsl: unseen=0.4862 , seen=0.7324 , h=0.5844
# ____________________________________________________________________________________________________
# episode: 6600 loss tensor(1.9490, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6648313070703538
# gzsl: unseen=0.4946 , seen=0.7342 , h=0.5911
# ____________________________________________________________________________________________________
# episode: 6800 loss tensor(2.5095, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6547701658072247
# gzsl: unseen=0.4802 , seen=0.7318 , h=0.5799
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(1.5788, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6775504820004136
# gzsl: unseen=0.5035 , seen=0.7444 , h=0.6007
# ____________________________________________________________________________________________________
# episode: 7200 loss tensor(2.5983, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.681554396935551
# gzsl: unseen=0.5102 , seen=0.7457 , h=0.6058
# ____________________________________________________________________________________________________
# episode: 7400 loss tensor(2.2570, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6802216767865121
# gzsl: unseen=0.5111 , seen=0.7460 , h=0.6066
# ____________________________________________________________________________________________________
# episode: 7600 loss tensor(1.4291, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6885015641758817
# gzsl: unseen=0.5442 , seen=0.7381 , h=0.6265
# ____________________________________________________________________________________________________
# episode: 7800 loss tensor(2.0569, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6784221508130581
# gzsl: unseen=0.5173 , seen=0.7478 , h=0.6116
# ____________________________________________________________________________________________________
# episode: 8000 loss tensor(1.2896, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6718619541581285
# gzsl: unseen=0.5018 , seen=0.7441 , h=0.5994
# ____________________________________________________________________________________________________
# episode: 8200 loss tensor(1.5046, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6524567536260478
# gzsl: unseen=0.4793 , seen=0.7402 , h=0.5818
# ____________________________________________________________________________________________________
# episode: 8400 loss tensor(1.5327, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6680831488979655
# gzsl: unseen=0.4971 , seen=0.7396 , h=0.5946
# ____________________________________________________________________________________________________
# episode: 8600 loss tensor(1.9550, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6421267594073061
# gzsl: unseen=0.4781 , seen=0.7374 , h=0.5801
# ____________________________________________________________________________________________________
# episode: 8800 loss tensor(2.1560, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6599321273836416
# gzsl: unseen=0.4946 , seen=0.7530 , h=0.5971
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(1.1872, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6617603950330133
# gzsl: unseen=0.4895 , seen=0.7461 , h=0.5912
# ____________________________________________________________________________________________________
# episode: 9200 loss tensor(1.8449, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6547152343683189
# gzsl: unseen=0.4846 , seen=0.7531 , h=0.5897
# ____________________________________________________________________________________________________
# episode: 9400 loss tensor(2.4779, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6694410881680333
# gzsl: unseen=0.4936 , seen=0.7593 , h=0.5983
# ____________________________________________________________________________________________________
# episode: 9600 loss tensor(1.4337, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6707032107788494
# gzsl: unseen=0.5106 , seen=0.7486 , h=0.6071
# ____________________________________________________________________________________________________
# episode: 9800 loss tensor(1.6624, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6539889477458992
# gzsl: unseen=0.4983 , seen=0.7445 , h=0.5970
# ____________________________________________________________________________________________________
# episode: 10000 loss tensor(1.4996, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6548787479197165
# gzsl: unseen=0.4891 , seen=0.7621 , h=0.5959
# ____________________________________________________________________________________________________
# episode: 10200 loss tensor(2.0170, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6597251245736
# gzsl: unseen=0.4808 , seen=0.7557 , h=0.5877
# ____________________________________________________________________________________________________
# episode: 10400 loss tensor(1.5031, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6499965561945873
# gzsl: unseen=0.4961 , seen=0.7482 , h=0.5966
# ____________________________________________________________________________________________________
# episode: 10600 loss tensor(1.3885, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6611110703485233
# gzsl: unseen=0.4943 , seen=0.7486 , h=0.5955
# ____________________________________________________________________________________________________
# episode: 10800 loss tensor(2.3202, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6442318663550529
# gzsl: unseen=0.4862 , seen=0.7459 , h=0.5887
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(1.8416, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6731279041995583
# gzsl: unseen=0.5132 , seen=0.7591 , h=0.6124
# ____________________________________________________________________________________________________
# episode: 11200 loss tensor(1.4509, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6355221216224238
# gzsl: unseen=0.4719 , seen=0.7574 , h=0.5815
# ____________________________________________________________________________________________________
# episode: 11400 loss tensor(2.2818, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6319958659176155
# gzsl: unseen=0.4526 , seen=0.7552 , h=0.5660
# ____________________________________________________________________________________________________
# episode: 11600 loss tensor(1.2287, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6374163315525506
# gzsl: unseen=0.4918 , seen=0.7470 , h=0.5931
# ____________________________________________________________________________________________________
# episode: 11800 loss tensor(1.1687, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6431594670152713
# gzsl: unseen=0.4798 , seen=0.7549 , h=0.5867
# ____________________________________________________________________________________________________
# episode: 12000 loss tensor(2.0488, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6416075379405093
# gzsl: unseen=0.4944 , seen=0.7526 , h=0.5968
# ____________________________________________________________________________________________________
# episode: 12200 loss tensor(1.0193, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6533050041072773
# gzsl: unseen=0.4678 , seen=0.7609 , h=0.5794
# ____________________________________________________________________________________________________
# episode: 12400 loss tensor(1.6901, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6578251094907854
# gzsl: unseen=0.4678 , seen=0.7559 , h=0.5779
# ____________________________________________________________________________________________________
# episode: 12600 loss tensor(1.7508, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6557002452136034
# gzsl: unseen=0.4876 , seen=0.7567 , h=0.5931
# ____________________________________________________________________________________________________
# episode: 12800 loss tensor(2.1080, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6348256132693417
# gzsl: unseen=0.4554 , seen=0.7551 , h=0.5681
# ____________________________________________________________________________________________________
# episode: 13000 loss tensor(1.3399, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6406177024876781
# gzsl: unseen=0.4807 , seen=0.7499 , h=0.5858
# ____________________________________________________________________________________________________
# episode: 13200 loss tensor(2.3792, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6542902989182082
# gzsl: unseen=0.4736 , seen=0.7622 , h=0.5842
# ____________________________________________________________________________________________________
# episode: 13400 loss tensor(1.3913, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6518301325036252
# gzsl: unseen=0.4876 , seen=0.7735 , h=0.5981
# ____________________________________________________________________________________________________
# episode: 13600 loss tensor(1.9561, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6524295218817594
# gzsl: unseen=0.5020 , seen=0.7594 , h=0.6045
# ____________________________________________________________________________________________________
# episode: 13800 loss tensor(1.2669, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6458873735023702
# gzsl: unseen=0.4930 , seen=0.7520 , h=0.5956
# ____________________________________________________________________________________________________
# episode: 14000 loss tensor(3.0816, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6351377402341604
# gzsl: unseen=0.4615 , seen=0.7629 , h=0.5751
# ____________________________________________________________________________________________________
# episode: 14200 loss tensor(1.7139, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6452502436761709
# gzsl: unseen=0.4829 , seen=0.7673 , h=0.5927
# ____________________________________________________________________________________________________
# episode: 14400 loss tensor(3.1306, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6405517064722183
# gzsl: unseen=0.4820 , seen=0.7619 , h=0.5905
# ____________________________________________________________________________________________________
# episode: 14600 loss tensor(1.6259, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6312860274875332
# gzsl: unseen=0.4843 , seen=0.7579 , h=0.5909
# ____________________________________________________________________________________________________
# episode: 14800 loss tensor(1.5967, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6577543295615869
# gzsl: unseen=0.4836 , seen=0.7687 , h=0.5937
# ____________________________________________________________________________________________________
# episode: 15000 loss tensor(1.7253, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.649920058159808
# gzsl: unseen=0.4813 , seen=0.7619 , h=0.5899
# ____________________________________________________________________________________________________
# episode: 15200 loss tensor(1.8595, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6563037905857774
# gzsl: unseen=0.4984 , seen=0.7592 , h=0.6018
# ____________________________________________________________________________________________________
# episode: 15400 loss tensor(1.3114, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.658392175297595
# gzsl: unseen=0.5010 , seen=0.7657 , h=0.6057
# ____________________________________________________________________________________________________
# episode: 15600 loss tensor(1.7755, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6214354453346014
# gzsl: unseen=0.4429 , seen=0.7579 , h=0.5590
# ____________________________________________________________________________________________________
# episode: 15800 loss tensor(2.2780, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6375276186708818
# gzsl: unseen=0.4578 , seen=0.7620 , h=0.5720
# ____________________________________________________________________________________________________
# episode: 16000 loss tensor(2.1054, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6433108822964274
# gzsl: unseen=0.4820 , seen=0.7559 , h=0.5886
# ____________________________________________________________________________________________________
# episode: 16200 loss tensor(1.6162, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6421269339032832
# gzsl: unseen=0.4699 , seen=0.7657 , h=0.5824
# ____________________________________________________________________________________________________
# episode: 16400 loss tensor(1.7483, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6514189781871471
# gzsl: unseen=0.4712 , seen=0.7732 , h=0.5856
# ____________________________________________________________________________________________________
# episode: 16600 loss tensor(1.3844, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6361997746237138
# gzsl: unseen=0.4690 , seen=0.7718 , h=0.5834
# ____________________________________________________________________________________________________
# episode: 16800 loss tensor(2.6451, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6426831272252318
# gzsl: unseen=0.4838 , seen=0.7696 , h=0.5942
# ____________________________________________________________________________________________________
# episode: 17000 loss tensor(1.5675, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6473033264791808
# gzsl: unseen=0.4844 , seen=0.7695 , h=0.5946
# ____________________________________________________________________________________________________
# episode: 17200 loss tensor(1.1199, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6512307058498622
# gzsl: unseen=0.4895 , seen=0.7751 , h=0.6000
# ____________________________________________________________________________________________________
# episode: 17400 loss tensor(1.6801, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6355770480941834
# gzsl: unseen=0.4501 , seen=0.7737 , h=0.5691
# ____________________________________________________________________________________________________
# episode: 17600 loss tensor(0.7610, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6250732633994377
# gzsl: unseen=0.4653 , seen=0.7647 , h=0.5786
# ____________________________________________________________________________________________________
# episode: 17800 loss tensor(1.1577, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6396558364895487
# gzsl: unseen=0.4674 , seen=0.7657 , h=0.5804
# ____________________________________________________________________________________________________
# episode: 18000 loss tensor(2.4529, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6382285045876356
# gzsl: unseen=0.4641 , seen=0.7664 , h=0.5781
# ____________________________________________________________________________________________________
# episode: 18200 loss tensor(1.3943, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6292782659883801
# gzsl: unseen=0.4790 , seen=0.7675 , h=0.5899
# ____________________________________________________________________________________________________
# episode: 18400 loss tensor(1.6914, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6591900592019689
# gzsl: unseen=0.4824 , seen=0.7664 , h=0.5921
# ____________________________________________________________________________________________________
# episode: 18600 loss tensor(0.7052, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6495224067212021
# gzsl: unseen=0.4755 , seen=0.7705 , h=0.5880
# ____________________________________________________________________________________________________
# episode: 18800 loss tensor(2.2508, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.648033193721921
# gzsl: unseen=0.4712 , seen=0.7702 , h=0.5847
# ____________________________________________________________________________________________________
# episode: 19000 loss tensor(1.9357, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6280191592089146
# gzsl: unseen=0.4547 , seen=0.7804 , h=0.5746
# ____________________________________________________________________________________________________
# episode: 19200 loss tensor(0.8581, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6254580191856405
# gzsl: unseen=0.4493 , seen=0.7744 , h=0.5686
# ____________________________________________________________________________________________________
# episode: 19400 loss tensor(1.7807, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6155064307810514
# gzsl: unseen=0.4431 , seen=0.7596 , h=0.5597
# ____________________________________________________________________________________________________
# episode: 19600 loss tensor(1.6935, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6159833432673645
# gzsl: unseen=0.4422 , seen=0.7641 , h=0.5602
# ____________________________________________________________________________________________________
