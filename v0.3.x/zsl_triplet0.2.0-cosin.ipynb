# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os
from tensorboardX import SummaryWriter

# %%
BATCH_SIZE = 128
EPISODE = 100000
TEST_EPISODE = 1000
LEARNING_RATE =1e-3
Nom = 0
Weight_Deacy = 0
GPU = 0
Margin = 1

# %%
print("init dataset")
##################################参数##################################################################
dataroot = '../data'
dataset = 'AwA1_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'original_att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个

########################add negative pairs#######################
#x_negative = np.empty_like(x)
#x_negative_label = np.empty_like(train_label)
#print(x.shape[0])

#for i in range(x.shape[0]):
#    pick=np.random.choice(np.where(train_label[i]!=train_id)[0], replace=True)
#    x_negative[i] = x[pick]
#    x_negative_label[i] = train_label[pick]
    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
#train_negative_label = torch.from_numpy(x_negative_label).unsqueeze(1)
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
#print(all_attributes)
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net_3 import AttributeNetwork
from my_net_3 import TripletNetwork_cos
from my_net_3 import MetricNetwork

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(85,1024,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
metric_network = MetricNetwork(2048,1024,2048)
triplet_network = TripletNetwork_cos(attribute_network, metric_network)  #metric learning   
triplet_network.cuda(GPU)   
#attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
#优化器adam 学习率 正则1e-5

#attribute_network_scheduler = StepLR(attribute_network_optim, step_size=200000, gamma=0.5)
#学习率每200k步 乘0.5
#triplet_network_optim = torch.optim.Adam(triplet_network.parameters(), lr=LEARNING_RATE,weight_decay=Weight_Deacy)
#
triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE,momentum=0.9 , 
                                         weight_decay=Weight_Deacy)
triplet_network_scheduler = StepLR(triplet_network_optim , step_size=200000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = metric_network(Variable(batch_features_ext).cuda(GPU).float())  # 32*1024

        #print(batch_features_ext)

        sample_features = metric_network(attribute_network(Variable(sample_attributes).cuda(GPU).float()))
        sample_features_ext = sample_features.repeat(batch_size, 1)
        #print(sample_features_ext.shape)


        relations = F.cosine_similarity(batch_features_ext, sample_features_ext).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        #print(predict_labels)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
print(triplet_network)
# Out:
# TripletNetwork_cos(
#   (embeddingnet_att): AttributeNetwork(
#     (fc1): Linear(in_features=85, out_features=1024, bias=True)
#     (fc2): Linear(in_features=1024, out_features=2048, bias=True)
#   )
#   (embeddingnet): MetricNetwork(
#     (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#     (fc2): Linear(in_features=1024, out_features=2048, bias=True)
#   )
# )

# %%
print("training...")
last_accuracy = 0.0
writer = SummaryWriter()
for episode in range(EPISODE):
    #attribute_network.train()
    triplet_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    
    batch_features_negative = np.empty_like(batch_features.numpy())
    
    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_labels.numpy()]).squeeze(1)
    
    batch_features = Variable(batch_features).cuda(GPU).float()  # 32*2048
    
    for i in range(batch_features_negative.shape[0]):
        pick=np.random.choice(np.where(batch_labels.numpy()!=batch_labels.numpy()[i])[0], replace=True)
        batch_features_negative[i] = batch_features[pick]    

    batch_features_negative = torch.from_numpy(batch_features_negative)
    batch_features_negative = Variable(batch_features_negative).cuda(GPU).float()  # 32*2048
    
    #batch_attributes = attribute_network(Variable(batch_attributes).cuda(GPU))
    batch_attributes = Variable(batch_attributes).cuda(GPU)
    
    dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(batch_attributes, batch_features, batch_features_negative)
    
    criterion = nn.MarginRankingLoss(margin = Margin).cuda(GPU)
    
    target = torch.FloatTensor(dista.size()).fill_(-1).cuda(GPU)
    
    
    loss_triplet= criterion(dista, distb, target)
    loss_embedd = embedded_x.norm(2) + embedded_y.norm(2) + embedded_z.norm(2)
    loss = loss_triplet + Nom * loss_embedd

    # update
    triplet_network.zero_grad()
    loss.backward()
    triplet_network_optim.step()
    
    if (episode+1)%1000 == 0:
        print("episode:", episode+1, "loss", loss.data)
        writer.add_scalar('data/loss', loss, episode)
    if (episode+1)%1000 == 0:
        print("Testing...")
        #attribute_network.eval()
        zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(50), attributes)
        gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(50), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        print('zsl:', zsl_accuracy)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        print('_'*100)
        writer.add_scalar('data/zsl_accuracy', zsl_accuracy, episode)
        writer.add_scalar('data/gzsl_unseen_accuracy', gzsl_unseen_accuracy, episode)
        writer.add_scalar('data/gzsl_seen_accuracy', gzsl_seen_accuracy, episode)
        writer.add_scalar('data/H', H, episode)
writer.export_scalars_to_json("./test.json")
writer.close()
# Out:
# training...
# episode: 1000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.1088830255057168
# gzsl: unseen=0.0362 , seen=0.0147 , h=0.0209
# ____________________________________________________________________________________________________
# episode: 2000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.11046613896218117
# gzsl: unseen=0.0373 , seen=0.0165 , h=0.0229
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.11451187335092348
# gzsl: unseen=0.0387 , seen=0.0192 , h=0.0256
# ____________________________________________________________________________________________________
# episode: 4000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.11715039577836411
# gzsl: unseen=0.0399 , seen=0.0220 , h=0.0284
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.12014072119613017
# gzsl: unseen=0.0424 , seen=0.0242 , h=0.0308
# ____________________________________________________________________________________________________
# episode: 6000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.12137203166226913
# gzsl: unseen=0.0436 , seen=0.0252 , h=0.0320
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.1247141600703606
# gzsl: unseen=0.0447 , seen=0.0278 , h=0.0343
# ____________________________________________________________________________________________________
# episode: 8000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.12752858399296393
# gzsl: unseen=0.0457 , seen=0.0301 , h=0.0363
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.13051890941073
# gzsl: unseen=0.0459 , seen=0.0335 , h=0.0387
# ____________________________________________________________________________________________________
# episode: 10000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.13438874230430958
# gzsl: unseen=0.0473 , seen=0.0363 , h=0.0411
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.13773087071240106
# gzsl: unseen=0.0485 , seen=0.0393 , h=0.0435
# ____________________________________________________________________________________________________
# episode: 12000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.14142480211081795
# gzsl: unseen=0.0491 , seen=0.0422 , h=0.0454
# ____________________________________________________________________________________________________
# episode: 13000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.14494283201407213
# gzsl: unseen=0.0510 , seen=0.0458 , h=0.0483
# ____________________________________________________________________________________________________
# episode: 14000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.14722955145118732
# gzsl: unseen=0.0522 , seen=0.0494 , h=0.0508
# ____________________________________________________________________________________________________
# episode: 15000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.14969217238346527
# gzsl: unseen=0.0529 , seen=0.0520 , h=0.0525
# ____________________________________________________________________________________________________
# episode: 16000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.15338610378188214
# gzsl: unseen=0.0542 , seen=0.0551 , h=0.0546
# ____________________________________________________________________________________________________
# episode: 17000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.15620052770448548
# gzsl: unseen=0.0545 , seen=0.0587 , h=0.0565
# ____________________________________________________________________________________________________
# episode: 18000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.15919085312225154
# gzsl: unseen=0.0558 , seen=0.0601 , h=0.0579
# ____________________________________________________________________________________________________
# episode: 19000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.1642919964819701
# gzsl: unseen=0.0563 , seen=0.0635 , h=0.0597
# ____________________________________________________________________________________________________
# episode: 20000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.16710642040457344
# gzsl: unseen=0.0565 , seen=0.0662 , h=0.0609
# ____________________________________________________________________________________________________
# episode: 21000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.17097625329815302
# gzsl: unseen=0.0579 , seen=0.0692 , h=0.0630
# ____________________________________________________________________________________________________
# episode: 22000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.17537379067722075
# gzsl: unseen=0.0588 , seen=0.0730 , h=0.0651
# ____________________________________________________________________________________________________
# episode: 23000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.17783641160949867
# gzsl: unseen=0.0588 , seen=0.0789 , h=0.0673
# ____________________________________________________________________________________________________
# episode: 24000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.18170624450307826
# gzsl: unseen=0.0602 , seen=0.0835 , h=0.0699
# ____________________________________________________________________________________________________
# episode: 25000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.18452066842568163
# gzsl: unseen=0.0616 , seen=0.0879 , h=0.0724
# ____________________________________________________________________________________________________
# episode: 26000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.18698328935795955
# gzsl: unseen=0.0619 , seen=0.0918 , h=0.0739
# ____________________________________________________________________________________________________
# episode: 27000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.18891820580474933
# gzsl: unseen=0.0623 , seen=0.0974 , h=0.0760
# ____________________________________________________________________________________________________
# episode: 28000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.19120492524186455
# gzsl: unseen=0.0628 , seen=0.1025 , h=0.0779
# ____________________________________________________________________________________________________
# episode: 29000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.19349164467897978
# gzsl: unseen=0.0639 , seen=0.1067 , h=0.0799
# ____________________________________________________________________________________________________
# episode: 30000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.19665787159190853
# gzsl: unseen=0.0642 , seen=0.1119 , h=0.0816
# ____________________________________________________________________________________________________
# episode: 31000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.19894459102902376
# gzsl: unseen=0.0639 , seen=0.1174 , h=0.0827
# ____________________________________________________________________________________________________
# episode: 32000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.20035180299032543
# gzsl: unseen=0.0646 , seen=0.1210 , h=0.0842
# ____________________________________________________________________________________________________
# episode: 33000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.20246262093227793
# gzsl: unseen=0.0651 , seen=0.1253 , h=0.0857
# ____________________________________________________________________________________________________
# episode: 34000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.20474934036939313
# gzsl: unseen=0.0639 , seen=0.1305 , h=0.0857
# ____________________________________________________________________________________________________
# episode: 35000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2080914687774846
# gzsl: unseen=0.0647 , seen=0.1361 , h=0.0877
# ____________________________________________________________________________________________________
# episode: 36000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.21108179419525067
# gzsl: unseen=0.0649 , seen=0.1438 , h=0.0894
# ____________________________________________________________________________________________________
# episode: 37000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.21372031662269128
# gzsl: unseen=0.0660 , seen=0.1517 , h=0.0919
# ____________________________________________________________________________________________________
# episode: 38000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.21723834652594548
# gzsl: unseen=0.0675 , seen=0.1575 , h=0.0945
# ____________________________________________________________________________________________________
# episode: 39000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.22040457343887424
# gzsl: unseen=0.0658 , seen=0.1630 , h=0.0937
# ____________________________________________________________________________________________________
# episode: 40000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.22233948988566402
# gzsl: unseen=0.0674 , seen=0.1684 , h=0.0962
# ____________________________________________________________________________________________________
# episode: 41000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.22515391380826738
# gzsl: unseen=0.0668 , seen=0.1729 , h=0.0964
# ____________________________________________________________________________________________________
# episode: 42000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.22867194371152155
# gzsl: unseen=0.0667 , seen=0.1801 , h=0.0973
# ____________________________________________________________________________________________________
# episode: 43000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23025505716798592
# gzsl: unseen=0.0658 , seen=0.1866 , h=0.0973
# ____________________________________________________________________________________________________
# episode: 44000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2318381706244503
# gzsl: unseen=0.0668 , seen=0.1942 , h=0.0995
# ____________________________________________________________________________________________________
# episode: 45000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23482849604221637
# gzsl: unseen=0.0667 , seen=0.1999 , h=0.1000
# ____________________________________________________________________________________________________
# episode: 46000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23711521547933156
# gzsl: unseen=0.0675 , seen=0.2055 , h=0.1017
# ____________________________________________________________________________________________________
# episode: 47000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23852242744063323
# gzsl: unseen=0.0658 , seen=0.2116 , h=0.1004
# ____________________________________________________________________________________________________
# episode: 48000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24168865435356202
# gzsl: unseen=0.0649 , seen=0.2170 , h=0.0999
# ____________________________________________________________________________________________________
# episode: 49000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2439753737906772
# gzsl: unseen=0.0646 , seen=0.2227 , h=0.1001
# ____________________________________________________________________________________________________
# episode: 50000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24608619173262972
# gzsl: unseen=0.0647 , seen=0.2299 , h=0.1010
# ____________________________________________________________________________________________________
# episode: 51000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24678979771328055
# gzsl: unseen=0.0651 , seen=0.2348 , h=0.1019
# ____________________________________________________________________________________________________
# episode: 52000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24907651715039578
# gzsl: unseen=0.0644 , seen=0.2394 , h=0.1015
# ____________________________________________________________________________________________________
# episode: 53000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2515391380826737
# gzsl: unseen=0.0649 , seen=0.2461 , h=0.1027
# ____________________________________________________________________________________________________
# episode: 54000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25277044854881264
# gzsl: unseen=0.0653 , seen=0.2505 , h=0.1035
# ____________________________________________________________________________________________________
# episode: 55000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25488126649076515
# gzsl: unseen=0.0646 , seen=0.2547 , h=0.1030
# ____________________________________________________________________________________________________
# episode: 56000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2554089709762533
# gzsl: unseen=0.0644 , seen=0.2582 , h=0.1031
# ____________________________________________________________________________________________________
# episode: 57000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25716798592788037
# gzsl: unseen=0.0642 , seen=0.2632 , h=0.1032
# ____________________________________________________________________________________________________
# episode: 58000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25875109938434476
# gzsl: unseen=0.0639 , seen=0.2721 , h=0.1034
# ____________________________________________________________________________________________________
# episode: 59000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2591029023746702
# gzsl: unseen=0.0633 , seen=0.2757 , h=0.1030
# ____________________________________________________________________________________________________
# episode: 60000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2613896218117854
# gzsl: unseen=0.0631 , seen=0.2806 , h=0.1031
# ____________________________________________________________________________________________________
# episode: 61000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26402814423922605
# gzsl: unseen=0.0631 , seen=0.2844 , h=0.1033
# ____________________________________________________________________________________________________
# episode: 62000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26596306068601583
# gzsl: unseen=0.0607 , seen=0.2896 , h=0.1003
# ____________________________________________________________________________________________________
# episode: 63000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2663148636763413
# gzsl: unseen=0.0617 , seen=0.2945 , h=0.1021
# ____________________________________________________________________________________________________
# episode: 64000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26772207563764294
# gzsl: unseen=0.0610 , seen=0.3001 , h=0.1014
# ____________________________________________________________________________________________________
# episode: 65000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27071240105540895
# gzsl: unseen=0.0600 , seen=0.3050 , h=0.1002
# ____________________________________________________________________________________________________
# episode: 66000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2717678100263852
# gzsl: unseen=0.0589 , seen=0.3094 , h=0.0990
# ____________________________________________________________________________________________________
# episode: 67000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27299912049252417
# gzsl: unseen=0.0595 , seen=0.3130 , h=0.0999
# ____________________________________________________________________________________________________
# episode: 68000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2752858399296394
# gzsl: unseen=0.0586 , seen=0.3211 , h=0.0991
# ____________________________________________________________________________________________________
# episode: 69000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2763412489006157
# gzsl: unseen=0.0577 , seen=0.3249 , h=0.0980
# ____________________________________________________________________________________________________
# episode: 70000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2775725593667546
# gzsl: unseen=0.0568 , seen=0.3292 , h=0.0969
# ____________________________________________________________________________________________________
# episode: 71000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27792436235708
# gzsl: unseen=0.0563 , seen=0.3332 , h=0.0963
# ____________________________________________________________________________________________________
# episode: 72000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27862796833773085
# gzsl: unseen=0.0545 , seen=0.3397 , h=0.0940
# ____________________________________________________________________________________________________
# episode: 73000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2796833773087071
# gzsl: unseen=0.0542 , seen=0.3443 , h=0.0936
# ____________________________________________________________________________________________________
# episode: 74000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2816182937554969
# gzsl: unseen=0.0544 , seen=0.3499 , h=0.0941
# ____________________________________________________________________________________________________
# episode: 75000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2837291116974494
# gzsl: unseen=0.0542 , seen=0.3544 , h=0.0940
# ____________________________________________________________________________________________________
# episode: 76000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2854881266490765
# gzsl: unseen=0.0528 , seen=0.3582 , h=0.0920
# ____________________________________________________________________________________________________
# episode: 77000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2872471416007036
# gzsl: unseen=0.0524 , seen=0.3608 , h=0.0915
# ____________________________________________________________________________________________________
# episode: 78000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.288830255057168
# gzsl: unseen=0.0536 , seen=0.3643 , h=0.0935
# ____________________________________________________________________________________________________
# episode: 79000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2907651715039578
# gzsl: unseen=0.0522 , seen=0.3687 , h=0.0915
# ____________________________________________________________________________________________________
# episode: 80000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2911169744942832
# gzsl: unseen=0.0498 , seen=0.3733 , h=0.0878
# ____________________________________________________________________________________________________
# episode: 81000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2928759894459103
# gzsl: unseen=0.0477 , seen=0.3768 , h=0.0846
# ____________________________________________________________________________________________________
# episode: 82000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2932277924362357
# gzsl: unseen=0.0478 , seen=0.3784 , h=0.0849
# ____________________________________________________________________________________________________
# episode: 83000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.29445910290237465
# gzsl: unseen=0.0475 , seen=0.3824 , h=0.0845
# ____________________________________________________________________________________________________
# episode: 84000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2967458223394899
# gzsl: unseen=0.0449 , seen=0.3854 , h=0.0804
# ____________________________________________________________________________________________________
# episode: 85000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2974494283201407
# gzsl: unseen=0.0438 , seen=0.3899 , h=0.0788
# ____________________________________________________________________________________________________
# episode: 86000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2988566402814424
# gzsl: unseen=0.0433 , seen=0.3919 , h=0.0779
# ____________________________________________________________________________________________________
# episode: 87000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.29938434476693054
# gzsl: unseen=0.0420 , seen=0.3951 , h=0.0760
# ____________________________________________________________________________________________________
# episode: 88000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.30043975373790677
# gzsl: unseen=0.0417 , seen=0.3971 , h=0.0755
# ____________________________________________________________________________________________________
# episode: 89000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3016710642040457
# gzsl: unseen=0.0401 , seen=0.3998 , h=0.0729
# ____________________________________________________________________________________________________
# episode: 90000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3016710642040457
# gzsl: unseen=0.0399 , seen=0.4016 , h=0.0726
# ____________________________________________________________________________________________________
# episode: 91000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3021987686895339
# gzsl: unseen=0.0389 , seen=0.4040 , h=0.0709
# ____________________________________________________________________________________________________
# episode: 92000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3034300791556728
# gzsl: unseen=0.0371 , seen=0.4070 , h=0.0680
# ____________________________________________________________________________________________________
# episode: 93000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.30413368513632366
# gzsl: unseen=0.0375 , seen=0.4102 , h=0.0687
# ____________________________________________________________________________________________________
# episode: 94000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.30554089709762533
# gzsl: unseen=0.0359 , seen=0.4121 , h=0.0660
# ____________________________________________________________________________________________________
# episode: 95000 loss tensor(1.0000, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3074758135444151
# gzsl: unseen=0.0359 , seen=0.4153 , h=0.0661
# ____________________________________________________________________________________________________
# episode: 96000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3088830255057168
# gzsl: unseen=0.0348 , seen=0.4159 , h=0.0643
# ____________________________________________________________________________________________________
# episode: 97000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3101143359718558
# gzsl: unseen=0.0341 , seen=0.4175 , h=0.0631
# ____________________________________________________________________________________________________
# episode: 98000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3090589270008795
# gzsl: unseen=0.0338 , seen=0.4209 , h=0.0625
# ____________________________________________________________________________________________________
# episode: 99000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31152154793315745
# gzsl: unseen=0.0327 , seen=0.4254 , h=0.0608
# ____________________________________________________________________________________________________
# episode: 100000 loss tensor(0.9999, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31187335092348284
# gzsl: unseen=0.0329 , seen=0.4258 , h=0.0611
# ____________________________________________________________________________________________________
