# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os
from My_Loss import HardTripletLoss
from My_Loss import HardTripletLoss_D
from tensorboardX import SummaryWriter

# %%
BATCH_SIZE = 64
EPISODE = 50000
TEST_EPISODE = 1000
LEARNING_RATE =1e-5
Weight_Deacy = 0
GPU = 0
Margin = 3

# %%
print("init dataset")
##################################参数##################################################################
dataroot = '../data'
dataset = 'AwA1_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'original_att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个


    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net_3 import AttributeNetwork
from my_net_3 import MetricNetwork

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(85,1024,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
metric_network = MetricNetwork(2048,1024,2048)

attribute_network.cuda(GPU) 
metric_network.cuda(GPU)

#学习率每200k步 乘0.5
attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE,weight_decay=Weight_Deacy)
metric_network_optim = torch.optim.Adam(metric_network.parameters(), lr=LEARNING_RATE,weight_decay=Weight_Deacy)
#
#triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE,momentum=0.9 , 
#                                         weight_decay=Weight_Deacy)

attribute_network_scheduler = StepLR(attribute_network_optim , step_size=20000 , gamma=0.5)
metric_network_scheduler = StepLR(metric_network_optim , step_size=20000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = metric_network(Variable(batch_features_ext).cuda(GPU).float())  # 32*1024


        sample_features = metric_network(attribute_network(Variable(sample_attributes).cuda(GPU).float()))
        sample_features_ext = sample_features.repeat(batch_size, 1)


        relations = F.pairwise_distance(batch_features_ext, sample_features_ext, 2).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
def compute_accuracy_per_class(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0
    #print(test_features.size())
    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]
    per_class_num = np.zeros(class_num)
    per_class_true= np.zeros(class_num)

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = metric_network(Variable(batch_features_ext).cuda(GPU).float())  # 32*1024


        sample_features = metric_network(attribute_network(Variable(sample_attributes).cuda(GPU).float()))
        sample_features_ext = sample_features.repeat(batch_size, 1)


        relations = F.pairwise_distance(batch_features_ext, sample_features_ext, 2).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels_id, batch_per_num = np.unique(re_batch_labels , return_counts=True) 
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)
        
        for each in range(re_batch_labels_id.size):
            #print(re_batch_labels_id[each])
            #print(batch_per_num[each])
            per_class_num[re_batch_labels_id[each]] = per_class_num[re_batch_labels_id[each]] + batch_per_num[each]
        #print(re_batch_labels_id)
        #print('-'*100)
        #print(batch_per_num)
        #print('-'*100)


        _, predict_labels = torch.min(relations.data, 1)
        for j in range(batch_size):
            if predict_labels[j] == re_batch_labels[j]:
                per_class_true[re_batch_labels[j]] = per_class_true[re_batch_labels[j]] + 1
            
        
        
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    per_accuracy = per_class_true[np.nonzero(per_class_num)] / per_class_num[np.nonzero(per_class_num)]
    

    test_accuracy = np.sum(per_accuracy)/1.0/np.count_nonzero(per_class_num)
    test_accuracy2 = total_rewards/1.0/test_size
    #print(np.count_nonzero(per_class_num))
    return  test_accuracy, test_accuracy2

# %%
print("training...")
last_accuracy = 0.0
loss_zero_num =0
#writer = SummaryWriter()
for episode in range(EPISODE):

    attribute_network_scheduler.step(episode)
    metric_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    batch_id = np.unique(batch_labels)

    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_id]).squeeze(1)
    batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(batch_id.size, 0))
    batch_attributes_ext = batch_attributes.repeat(BATCH_SIZE, 1)

    batch_features_ext = Variable(batch_features_ext).cuda(GPU).float()  # 32*2048
    batch_attributes_ext = Variable(batch_attributes_ext).cuda(GPU)


    re_batch_labels = []
    for label in batch_labels.numpy():
        index = np.argwhere(batch_id == label)
        re_batch_labels.append(index[0][0])
    re_batch_labels = torch.cuda.LongTensor(re_batch_labels)
    re_batch_labels = Variable(re_batch_labels).cuda(GPU)
    

    criterion = HardTripletLoss_D(margin = Margin).cuda(GPU)
    triplet_loss= criterion(metric_network(attribute_network(batch_attributes_ext)), 
                            metric_network(batch_features_ext), re_batch_labels)
    if triplet_loss == 0:
        loss_zero_num = loss_zero_num + 1
    
    
    attribute_network.zero_grad()
    metric_network.zero_grad()
    
    triplet_loss.backward()
    
    attribute_network_optim.step()
    metric_network_optim.step()

    
    if (episode+1)%200 == 0 or episode==0:
        print("episode:", episode+1, "loss", triplet_loss)
        print('loss_zero_number= ',loss_zero_num)
        loss_zero_num = 0
        #writer.add_scalar('data/loss', triplet_loss, episode)
    if (episode+1)%200 == 0 or episode==0:
        print("Testing...")
        #attribute_network.eval()
        zsl_accuracy, zsl_accuracy2 = compute_accuracy_per_class(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy , gzsl_unseen_accuracy2= compute_accuracy_per_class(test_features, test_label, np.arange(50), attributes)
        gzsl_seen_accuracy ,gzsl_seen_accuracy2 = compute_accuracy_per_class(test_seen_features, test_seen_label, np.arange(50), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        H2 = 2 * gzsl_seen_accuracy2 * gzsl_unseen_accuracy2 / (gzsl_unseen_accuracy2 + gzsl_seen_accuracy2)
        print('zsl:', zsl_accuracy)
        #print('zsl:', zsl_accuracy2)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        #print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy2 , gzsl_seen_accuracy2, H2))
        print('_'*100)
        #writer.add_scalar('data/zsl_accuracy', zsl_accuracy, episode)
        #writer.add_scalar('data/gzsl_unseen_accuracy', gzsl_unseen_accuracy, episode)
        #writer.add_scalar('data/gzsl_seen_accuracy', gzsl_seen_accuracy, episode)
        #writer.add_scalar('data/H', H, episode)
#writer.export_scalars_to_json("./test.json")
#writer.close()
# Out:
# training...
# episode: 1 loss tensor(6.2822, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.05382516253762848
# gzsl: unseen=0.0000 , seen=0.0257 , h=0.0000
# ____________________________________________________________________________________________________
# episode: 200 loss tensor(5.9829, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2569264063340567
# gzsl: unseen=0.1298 , seen=0.6283 , h=0.2152
# ____________________________________________________________________________________________________
# episode: 400 loss tensor(5.8518, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.297974843852525
# gzsl: unseen=0.2364 , seen=0.6844 , h=0.3514
# ____________________________________________________________________________________________________
# episode: 600 loss tensor(5.7220, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.39617072562961275
# gzsl: unseen=0.3178 , seen=0.5822 , h=0.4112
# ____________________________________________________________________________________________________
# episode: 800 loss tensor(5.6143, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.4224658905391755
# gzsl: unseen=0.3144 , seen=0.5566 , h=0.4018
# ____________________________________________________________________________________________________
# episode: 1000 loss tensor(5.5359, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5563007908951666
# gzsl: unseen=0.4262 , seen=0.6279 , h=0.5078
# ____________________________________________________________________________________________________
# episode: 1200 loss tensor(5.2786, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.580363316642404
# gzsl: unseen=0.4470 , seen=0.6305 , h=0.5231
# ____________________________________________________________________________________________________
# episode: 1400 loss tensor(5.2985, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6090069112129934
# gzsl: unseen=0.4921 , seen=0.6203 , h=0.5488
# ____________________________________________________________________________________________________
# episode: 1600 loss tensor(4.9174, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6324645416137844
# gzsl: unseen=0.5474 , seen=0.6200 , h=0.5815
# ____________________________________________________________________________________________________
# episode: 1800 loss tensor(4.7606, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.650520733941369
# gzsl: unseen=0.5598 , seen=0.6191 , h=0.5879
# ____________________________________________________________________________________________________
# episode: 2000 loss tensor(4.7017, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6290138085005574
# gzsl: unseen=0.5226 , seen=0.6323 , h=0.5722
# ____________________________________________________________________________________________________
# episode: 2200 loss tensor(4.7582, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6464772535247231
# gzsl: unseen=0.5530 , seen=0.6427 , h=0.5945
# ____________________________________________________________________________________________________
# episode: 2400 loss tensor(3.8527, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6567136420351473
# gzsl: unseen=0.5677 , seen=0.6432 , h=0.6031
# ____________________________________________________________________________________________________
# episode: 2600 loss tensor(3.9116, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6624229122276108
# gzsl: unseen=0.5991 , seen=0.6440 , h=0.6207
# ____________________________________________________________________________________________________
# episode: 2800 loss tensor(3.7144, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6651684045074565
# gzsl: unseen=0.5847 , seen=0.6538 , h=0.6173
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(3.9551, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6692449390307166
# gzsl: unseen=0.5959 , seen=0.6634 , h=0.6279
# ____________________________________________________________________________________________________
# episode: 3200 loss tensor(4.3164, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6358846865260794
# gzsl: unseen=0.5200 , seen=0.6798 , h=0.5892
# ____________________________________________________________________________________________________
# episode: 3400 loss tensor(3.9555, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6564662186047058
# gzsl: unseen=0.5756 , seen=0.6667 , h=0.6178
# ____________________________________________________________________________________________________
# episode: 3600 loss tensor(4.0652, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6617497235144199
# gzsl: unseen=0.5696 , seen=0.6778 , h=0.6190
# ____________________________________________________________________________________________________
# episode: 3800 loss tensor(3.3009, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.656543942371966
# gzsl: unseen=0.5723 , seen=0.6926 , h=0.6267
# ____________________________________________________________________________________________________
# episode: 4000 loss tensor(4.4363, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6597345230368258
# gzsl: unseen=0.5679 , seen=0.6953 , h=0.6252
# ____________________________________________________________________________________________________
# episode: 4200 loss tensor(3.2910, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.662871344444686
# gzsl: unseen=0.5797 , seen=0.6924 , h=0.6311
# ____________________________________________________________________________________________________
# episode: 4400 loss tensor(3.0553, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6660991059100114
# gzsl: unseen=0.5805 , seen=0.7158 , h=0.6411
# ____________________________________________________________________________________________________
# episode: 4600 loss tensor(3.2617, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6587887421211641
# gzsl: unseen=0.5734 , seen=0.7113 , h=0.6349
# ____________________________________________________________________________________________________
# episode: 4800 loss tensor(4.0180, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6589088484485075
# gzsl: unseen=0.5756 , seen=0.7113 , h=0.6363
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(4.0727, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6551764211453175
# gzsl: unseen=0.5656 , seen=0.7250 , h=0.6355
# ____________________________________________________________________________________________________
# episode: 5200 loss tensor(3.4935, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.669764480266861
# gzsl: unseen=0.5903 , seen=0.7215 , h=0.6494
# ____________________________________________________________________________________________________
# episode: 5400 loss tensor(3.9034, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6656259886724456
# gzsl: unseen=0.5735 , seen=0.7297 , h=0.6422
# ____________________________________________________________________________________________________
# episode: 5600 loss tensor(4.2297, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6673957167660672
# gzsl: unseen=0.5593 , seen=0.7332 , h=0.6345
# ____________________________________________________________________________________________________
# episode: 5800 loss tensor(3.2086, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6610354879200463
# gzsl: unseen=0.5727 , seen=0.7345 , h=0.6436
# ____________________________________________________________________________________________________
# episode: 6000 loss tensor(3.4322, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6557798668289936
# gzsl: unseen=0.5707 , seen=0.7417 , h=0.6451
# ____________________________________________________________________________________________________
# episode: 6200 loss tensor(3.2252, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6651934957798339
# gzsl: unseen=0.5757 , seen=0.7310 , h=0.6442
# ____________________________________________________________________________________________________
# episode: 6400 loss tensor(3.9814, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6683783952160136
# gzsl: unseen=0.5731 , seen=0.7494 , h=0.6495
# ____________________________________________________________________________________________________
# episode: 6600 loss tensor(4.4125, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6634253930005214
# gzsl: unseen=0.5834 , seen=0.7459 , h=0.6547
# ____________________________________________________________________________________________________
# episode: 6800 loss tensor(4.4371, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6683681436255351
# gzsl: unseen=0.5833 , seen=0.7372 , h=0.6513
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(4.1829, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6748844909471929
# gzsl: unseen=0.5719 , seen=0.7509 , h=0.6493
# ____________________________________________________________________________________________________
# episode: 7200 loss tensor(3.0659, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6712646045861813
# gzsl: unseen=0.5752 , seen=0.7527 , h=0.6521
# ____________________________________________________________________________________________________
# episode: 7400 loss tensor(3.8165, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6845970928557351
# gzsl: unseen=0.5943 , seen=0.7364 , h=0.6578
# ____________________________________________________________________________________________________
# episode: 7600 loss tensor(3.7413, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6735145929631763
# gzsl: unseen=0.5852 , seen=0.7468 , h=0.6562
# ____________________________________________________________________________________________________
# episode: 7800 loss tensor(3.8192, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6679065574301049
# gzsl: unseen=0.5756 , seen=0.7492 , h=0.6510
# ____________________________________________________________________________________________________
# episode: 8000 loss tensor(3.1801, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6644574307359269
# gzsl: unseen=0.5702 , seen=0.7588 , h=0.6511
# ____________________________________________________________________________________________________
# episode: 8200 loss tensor(2.8300, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6674503039764162
# gzsl: unseen=0.5809 , seen=0.7599 , h=0.6584
# ____________________________________________________________________________________________________
# episode: 8400 loss tensor(4.6625, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6700839626201852
# gzsl: unseen=0.5768 , seen=0.7516 , h=0.6527
# ____________________________________________________________________________________________________
# episode: 8600 loss tensor(3.5319, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6591117267951583
# gzsl: unseen=0.5669 , seen=0.7593 , h=0.6492
# ____________________________________________________________________________________________________
# episode: 8800 loss tensor(4.5834, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6758761500082701
# gzsl: unseen=0.5888 , seen=0.7533 , h=0.6610
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(3.1396, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6607494807829924
# gzsl: unseen=0.5647 , seen=0.7741 , h=0.6531
# ____________________________________________________________________________________________________
# episode: 9200 loss tensor(4.4281, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6655032464733424
# gzsl: unseen=0.5683 , seen=0.7616 , h=0.6509
# ____________________________________________________________________________________________________
# episode: 9400 loss tensor(3.4841, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6711270090825897
# gzsl: unseen=0.5758 , seen=0.7715 , h=0.6594
# ____________________________________________________________________________________________________
# episode: 9600 loss tensor(4.5675, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6669678265479838
# gzsl: unseen=0.5774 , seen=0.7612 , h=0.6567
# ____________________________________________________________________________________________________
# episode: 9800 loss tensor(3.4320, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6706757053371474
# gzsl: unseen=0.5582 , seen=0.7816 , h=0.6513
# ____________________________________________________________________________________________________
# episode: 10000 loss tensor(3.6797, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6591246196636519
# gzsl: unseen=0.5679 , seen=0.7731 , h=0.6548
# ____________________________________________________________________________________________________
# episode: 10200 loss tensor(3.8590, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6534129251709773
# gzsl: unseen=0.5576 , seen=0.7704 , h=0.6469
# ____________________________________________________________________________________________________
# episode: 10400 loss tensor(3.0835, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6571059900950734
# gzsl: unseen=0.5447 , seen=0.7749 , h=0.6398
# ____________________________________________________________________________________________________
# episode: 10600 loss tensor(3.3194, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6614196134628512
# gzsl: unseen=0.5629 , seen=0.7771 , h=0.6529
# ____________________________________________________________________________________________________
# episode: 10800 loss tensor(4.5342, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6653838329310455
# gzsl: unseen=0.5675 , seen=0.7721 , h=0.6542
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(3.9851, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6655951568388456
# gzsl: unseen=0.5628 , seen=0.7784 , h=0.6533
# ____________________________________________________________________________________________________
# episode: 11200 loss tensor(4.0501, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6676606029518374
# gzsl: unseen=0.5765 , seen=0.7816 , h=0.6635
# ____________________________________________________________________________________________________
# episode: 11400 loss tensor(3.4431, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6647201985215936
# gzsl: unseen=0.5699 , seen=0.7799 , h=0.6586
# ____________________________________________________________________________________________________
# episode: 11600 loss tensor(2.3831, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6722857391639668
# gzsl: unseen=0.5754 , seen=0.7710 , h=0.6590
# ____________________________________________________________________________________________________
# episode: 11800 loss tensor(5.2357, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6593762323749468
# gzsl: unseen=0.5615 , seen=0.7814 , h=0.6534
# ____________________________________________________________________________________________________
# episode: 12000 loss tensor(4.7216, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.666368762469268
# gzsl: unseen=0.5622 , seen=0.7756 , h=0.6519
# ____________________________________________________________________________________________________
# episode: 12200 loss tensor(4.1344, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6467532892836555
# gzsl: unseen=0.5511 , seen=0.7820 , h=0.6466
# ____________________________________________________________________________________________________
# episode: 12400 loss tensor(3.0035, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6562652519931594
# gzsl: unseen=0.5509 , seen=0.7879 , h=0.6485
# ____________________________________________________________________________________________________
# episode: 12600 loss tensor(2.2434, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6514818553382916
# gzsl: unseen=0.5496 , seen=0.7798 , h=0.6448
# ____________________________________________________________________________________________________
# episode: 12800 loss tensor(4.9660, device='cuda:0')
# loss_zero_number=  0
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6482846815503243
# gzsl: unseen=0.5364 , seen=0.7866 , h=0.6378
# ____________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-70ffebf19bf9> in <module>()
#      31     criterion = HardTripletLoss_D(margin = Margin).cuda(GPU)
#      32     triplet_loss= criterion(metric_network(attribute_network(batch_attributes_ext)),
# ---> 33                             metric_network(batch_features_ext), re_batch_labels)
#      34     if triplet_loss == 0:
#      35         loss_zero_num = loss_zero_num + 1
#
# /workspace/wanghai/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /workspace/wanghai/My_ZSL/v0.3.x/My_Loss.py in forward(self, attributes, embeddings, labels)
#     127
#     128         # Get the hardest negative pairs
# --> 129         mask_neg=_get_anchor_negative_triplet_mask(relations, labels).float()
#     130         #print(mask_neg)
#     131         max_anchor_negative_dist, _ = torch.max(relations, 0 , keepdim=True)
#
# /workspace/wanghai/My_ZSL/v0.3.x/My_Loss.py in _get_anchor_negative_triplet_mask(relations, labels)
#     193     device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#     194     # Check if labels[i] != labels[k]
# --> 195     mask_neg = torch.ones_like(relations).to(device).byte()
#     196     #print('-'*100)
#     197     for i in range(relations.size()[0]):
#
# KeyboardInterrupt:
