# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os

# %%
BATCH_SIZE = 64
EPISODE = 500000
TEST_EPISODE = 1000
LEARNING_RATE =1e-2
GPU = 0
Margin = 1

# %%
print("init dataset")
##################################参数##################################################################
dataroot = './data'
dataset = 'APY_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个

########################add negative pairs#######################
#x_negative = np.empty_like(x)
#x_negative_label = np.empty_like(train_label)
#print(x.shape[0])

#for i in range(x.shape[0]):
#    pick=np.random.choice(np.where(train_label[i]!=train_id)[0], replace=True)
#    x_negative[i] = x[pick]
#    x_negative_label[i] = train_label[pick]
    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
#train_negative_label = torch.from_numpy(x_negative_label).unsqueeze(1)
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
#print(all_attributes)
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net import AttributeNetwork
from my_net import TripletNetwork_cos

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(64,1600,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
triplet_network = TripletNetwork_cos(attribute_network)  #metric learning   
triplet_network.cuda(GPU)   
#attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
#优化器adam 学习率 正则1e-5

#attribute_network_scheduler = StepLR(attribute_network_optim, step_size=200000, gamma=0.5)
#学习率每200k步 乘0.5
#triplet_network_optim = torch.optim.Adam(triplet_network.parameters(), lr=LEARNING_RATE)
#
triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE, momentum=0.5)
triplet_network_scheduler = StepLR(triplet_network_optim , step_size=200000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = Variable(batch_features_ext).cuda(GPU).float()  # 32*1024

        #print(batch_features_ext)

        sample_features = attribute_network(Variable(sample_attributes).cuda(GPU).float())
        sample_features_ext = sample_features.repeat(batch_size, 1)
        #print(sample_features_ext.shape)


        relations = F.cosine_similarity(batch_features_ext, sample_features_ext).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        #print(predict_labels)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
print("training...")
last_accuracy = 0.0
for episode in range(EPISODE):
   
    triplet_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    
    batch_features_negative = np.empty_like(batch_features.numpy())
    
    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_labels.numpy()]).squeeze(1)
    
    batch_features = Variable(batch_features).cuda(GPU).float()  # 32*2048
    
    for i in range(batch_features_negative.shape[0]):
        pick=np.random.choice(np.where(batch_labels.numpy()[i]!=train_id)[0], replace=True)
        batch_features_negative[i] = x[pick]    
    
    batch_features_negative = torch.from_numpy(batch_features_negative)
    batch_features_negative = Variable(batch_features_negative).cuda(GPU).float()  # 32*2048
    
    #batch_attributes = attribute_network(Variable(batch_attributes).cuda(GPU))
    batch_attributes = Variable(batch_attributes).cuda(GPU)
    
    dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(batch_attributes, batch_features, batch_features_negative)
    
    criterion = nn.MarginRankingLoss(margin = Margin).cuda(GPU)
    
    target = torch.FloatTensor(dista.size()).fill_(-1).cuda(GPU)
    
    
    loss_triplet= criterion(dista, distb, target)
    loss_embedd = embedded_x.norm(2) + embedded_y.norm(2) + embedded_z.norm(2)
    loss = loss_triplet #+ 0.001 * loss_embedd

    # update
    triplet_network.zero_grad()
    loss.backward()
    triplet_network_optim.step()
    
    if (episode+1)%1000 == 0:
        print("episode:", episode+1, "loss", loss.data)
    if (episode+1)%2000 == 0:
        print("Testing...")
        zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(32), attributes)
        gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(32), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        print('zsl:', zsl_accuracy)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        print('_'*100)
# Out:
# training...
# episode: 1000 loss tensor(1.0121, device='cuda:0')
# episode: 2000 loss tensor(1.0109, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0668854114083796
# gzsl: unseen=0.0237 , seen=0.0762 , h=0.0362
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(1.0229, device='cuda:0')
# episode: 4000 loss tensor(1.0119, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07710752145381121
# gzsl: unseen=0.0274 , seen=0.1773 , h=0.0474
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(1.0138, device='cuda:0')
# episode: 6000 loss tensor(1.0278, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.08329126703685008
# gzsl: unseen=0.0268 , seen=0.2738 , h=0.0487
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(1.0006, device='cuda:0')
# episode: 8000 loss tensor(0.9864, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.08985360928823827
# gzsl: unseen=0.0227 , seen=0.3513 , h=0.0427
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(1.0051, device='cuda:0')
# episode: 10000 loss tensor(0.9946, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.09376577486118122
# gzsl: unseen=0.0213 , seen=0.4194 , h=0.0406
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(0.9986, device='cuda:0')
# episode: 12000 loss tensor(1.0031, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.09502776375567895
# gzsl: unseen=0.0197 , seen=0.4666 , h=0.0378
# ____________________________________________________________________________________________________
# episode: 13000 loss tensor(1.0056, device='cuda:0')
# episode: 14000 loss tensor(0.9866, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.09717314487632508
# gzsl: unseen=0.0173 , seen=0.4956 , h=0.0334
# ____________________________________________________________________________________________________
# episode: 15000 loss tensor(0.9874, device='cuda:0')
# episode: 16000 loss tensor(0.9845, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0952801615345785
# gzsl: unseen=0.0150 , seen=0.5266 , h=0.0292
# ____________________________________________________________________________________________________
# episode: 17000 loss tensor(1.0003, device='cuda:0')
# episode: 18000 loss tensor(1.0057, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.09326097930338213
# gzsl: unseen=0.0120 , seen=0.5489 , h=0.0235
# ____________________________________________________________________________________________________
# episode: 19000 loss tensor(0.9966, device='cuda:0')
# episode: 20000 loss tensor(0.9701, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.08960121150933872
# gzsl: unseen=0.0092 , seen=0.5597 , h=0.0181
# ____________________________________________________________________________________________________
# episode: 21000 loss tensor(0.9891, device='cuda:0')
# episode: 22000 loss tensor(0.9964, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.08430085815244825
# gzsl: unseen=0.0087 , seen=0.5590 , h=0.0171
# ____________________________________________________________________________________________________
# episode: 23000 loss tensor(0.9898, device='cuda:0')
# episode: 24000 loss tensor(0.9841, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07887430590610803
# gzsl: unseen=0.0092 , seen=0.5374 , h=0.0181
# ____________________________________________________________________________________________________
# episode: 25000 loss tensor(0.9659, device='cuda:0')
# episode: 26000 loss tensor(0.9668, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07319535588086824
# gzsl: unseen=0.0100 , seen=0.5118 , h=0.0196
# ____________________________________________________________________________________________________
# episode: 27000 loss tensor(0.9607, device='cuda:0')
# episode: 28000 loss tensor(0.9898, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06814740030287733
# gzsl: unseen=0.0101 , seen=0.4767 , h=0.0198
# ____________________________________________________________________________________________________
# episode: 29000 loss tensor(0.9749, device='cuda:0')
# episode: 30000 loss tensor(0.9674, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06120646138313983
# gzsl: unseen=0.0100 , seen=0.4437 , h=0.0195
# ____________________________________________________________________________________________________
# episode: 31000 loss tensor(0.9646, device='cuda:0')
# episode: 32000 loss tensor(0.9518, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05628470469459869
# gzsl: unseen=0.0100 , seen=0.4005 , h=0.0195
# ____________________________________________________________________________________________________
# episode: 33000 loss tensor(0.9383, device='cuda:0')
# episode: 34000 loss tensor(0.9679, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05060575466935891
# gzsl: unseen=0.0087 , seen=0.3742 , h=0.0170
# ____________________________________________________________________________________________________
# episode: 35000 loss tensor(0.9415, device='cuda:0')
# episode: 36000 loss tensor(0.9610, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04669358909641595
# gzsl: unseen=0.0072 , seen=0.3439 , h=0.0141
# ____________________________________________________________________________________________________
# episode: 37000 loss tensor(0.9298, device='cuda:0')
# episode: 38000 loss tensor(0.9637, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04353861686017163
# gzsl: unseen=0.0063 , seen=0.3203 , h=0.0124
# ____________________________________________________________________________________________________
# episode: 39000 loss tensor(0.9457, device='cuda:0')
# episode: 40000 loss tensor(0.9354, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04076224129227663
# gzsl: unseen=0.0050 , seen=0.2994 , h=0.0099
# ____________________________________________________________________________________________________
# episode: 41000 loss tensor(0.9322, device='cuda:0')
# episode: 42000 loss tensor(0.9268, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03836446239273095
# gzsl: unseen=0.0035 , seen=0.2751 , h=0.0070
# ____________________________________________________________________________________________________
# episode: 43000 loss tensor(0.9259, device='cuda:0')
# episode: 44000 loss tensor(0.9100, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.036976274608783444
# gzsl: unseen=0.0032 , seen=0.2569 , h=0.0062
# ____________________________________________________________________________________________________
# episode: 45000 loss tensor(0.9223, device='cuda:0')
# episode: 46000 loss tensor(0.9146, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03558808682483594
# gzsl: unseen=0.0027 , seen=0.2421 , h=0.0052
# ____________________________________________________________________________________________________
# episode: 47000 loss tensor(0.9386, device='cuda:0')
# episode: 48000 loss tensor(0.9365, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0353356890459364
# gzsl: unseen=0.0023 , seen=0.2353 , h=0.0045
# ____________________________________________________________________________________________________
# episode: 49000 loss tensor(0.9110, device='cuda:0')
# episode: 50000 loss tensor(0.9359, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.034957092377587075
# gzsl: unseen=0.0019 , seen=0.2266 , h=0.0038
# ____________________________________________________________________________________________________
# episode: 51000 loss tensor(0.9189, device='cuda:0')
# episode: 52000 loss tensor(0.9028, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03457849570923776
# gzsl: unseen=0.0018 , seen=0.2225 , h=0.0035
# ____________________________________________________________________________________________________
# episode: 53000 loss tensor(0.9002, device='cuda:0')
# episode: 54000 loss tensor(0.8987, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03457849570923776
# gzsl: unseen=0.0018 , seen=0.2171 , h=0.0035
# ____________________________________________________________________________________________________
# episode: 55000 loss tensor(0.9154, device='cuda:0')
# episode: 56000 loss tensor(0.8921, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03445229681978799
# gzsl: unseen=0.0019 , seen=0.2151 , h=0.0038
# ____________________________________________________________________________________________________
# episode: 57000 loss tensor(0.9129, device='cuda:0')
# episode: 58000 loss tensor(0.8990, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03470469459868753
# gzsl: unseen=0.0019 , seen=0.2131 , h=0.0038
# ____________________________________________________________________________________________________
# episode: 59000 loss tensor(0.8963, device='cuda:0')
# episode: 60000 loss tensor(0.8962, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03546188793538617
# gzsl: unseen=0.0020 , seen=0.2151 , h=0.0040
# ____________________________________________________________________________________________________
# episode: 61000 loss tensor(0.8959, device='cuda:0')
# episode: 62000 loss tensor(0.8831, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03558808682483594
# gzsl: unseen=0.0021 , seen=0.2131 , h=0.0042
# ____________________________________________________________________________________________________
# episode: 63000 loss tensor(0.8769, device='cuda:0')
# episode: 64000 loss tensor(0.8893, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03596668349318526
# gzsl: unseen=0.0021 , seen=0.2117 , h=0.0042
# ____________________________________________________________________________________________________
# episode: 65000 loss tensor(0.8658, device='cuda:0')
# episode: 66000 loss tensor(0.8839, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0367238768298839
# gzsl: unseen=0.0023 , seen=0.2124 , h=0.0045
# ____________________________________________________________________________________________________
# episode: 67000 loss tensor(0.8600, device='cuda:0')
# episode: 68000 loss tensor(0.8961, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03722867238768299
# gzsl: unseen=0.0027 , seen=0.2117 , h=0.0052
# ____________________________________________________________________________________________________
# episode: 69000 loss tensor(0.9009, device='cuda:0')
# episode: 70000 loss tensor(0.8628, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03836446239273095
# gzsl: unseen=0.0030 , seen=0.2097 , h=0.0060
# ____________________________________________________________________________________________________
# episode: 71000 loss tensor(0.8932, device='cuda:0')
# episode: 72000 loss tensor(0.8958, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.038995456839979806
# gzsl: unseen=0.0038 , seen=0.2084 , h=0.0074
# ____________________________________________________________________________________________________
# episode: 73000 loss tensor(0.8644, device='cuda:0')
# episode: 74000 loss tensor(0.8942, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0395002523977789
# gzsl: unseen=0.0044 , seen=0.2090 , h=0.0087
# ____________________________________________________________________________________________________
# episode: 75000 loss tensor(0.8771, device='cuda:0')
# episode: 76000 loss tensor(0.8932, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.03962645128722867
# gzsl: unseen=0.0053 , seen=0.2104 , h=0.0103
# ____________________________________________________________________________________________________
# episode: 77000 loss tensor(0.8838, device='cuda:0')
# episode: 78000 loss tensor(0.8595, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04038364462392731
# gzsl: unseen=0.0062 , seen=0.2097 , h=0.0120
# ____________________________________________________________________________________________________
# episode: 79000 loss tensor(0.8494, device='cuda:0')
# episode: 80000 loss tensor(0.8710, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04076224129227663
# gzsl: unseen=0.0066 , seen=0.2104 , h=0.0127
# ____________________________________________________________________________________________________
# episode: 81000 loss tensor(0.8817, device='cuda:0')
# episode: 82000 loss tensor(0.8755, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.041140837960625946
# gzsl: unseen=0.0072 , seen=0.2117 , h=0.0139
# ____________________________________________________________________________________________________
# episode: 83000 loss tensor(0.8727, device='cuda:0')
# episode: 84000 loss tensor(0.8578, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04164563351842504
# gzsl: unseen=0.0078 , seen=0.2117 , h=0.0151
# ____________________________________________________________________________________________________
# episode: 85000 loss tensor(0.8829, device='cuda:0')
# episode: 86000 loss tensor(0.8869, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0422766279656739
# gzsl: unseen=0.0082 , seen=0.2117 , h=0.0158
# ____________________________________________________________________________________________________
# episode: 87000 loss tensor(0.8676, device='cuda:0')
# episode: 88000 loss tensor(0.8799, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04265522463402322
# gzsl: unseen=0.0095 , seen=0.2138 , h=0.0181
# ____________________________________________________________________________________________________
# episode: 89000 loss tensor(0.8872, device='cuda:0')
# episode: 90000 loss tensor(0.8718, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.042907622412922765
# gzsl: unseen=0.0100 , seen=0.2151 , h=0.0191
# ____________________________________________________________________________________________________
# episode: 91000 loss tensor(0.8734, device='cuda:0')
# episode: 92000 loss tensor(0.8698, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04328621908127209
# gzsl: unseen=0.0109 , seen=0.2212 , h=0.0207
# ____________________________________________________________________________________________________
# episode: 93000 loss tensor(0.8732, device='cuda:0')
# episode: 94000 loss tensor(0.8699, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.044169611307420496
# gzsl: unseen=0.0117 , seen=0.2212 , h=0.0223
# ____________________________________________________________________________________________________
# episode: 95000 loss tensor(0.8507, device='cuda:0')
# episode: 96000 loss tensor(0.8743, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04480060575466936
# gzsl: unseen=0.0126 , seen=0.2239 , h=0.0239
# ____________________________________________________________________________________________________
# episode: 97000 loss tensor(0.8715, device='cuda:0')
# episode: 98000 loss tensor(0.8523, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04530540131246845
# gzsl: unseen=0.0133 , seen=0.2279 , h=0.0250
# ____________________________________________________________________________________________________
# episode: 99000 loss tensor(0.8661, device='cuda:0')
# episode: 100000 loss tensor(0.8716, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04555779909136799
# gzsl: unseen=0.0140 , seen=0.2313 , h=0.0264
# ____________________________________________________________________________________________________
# episode: 101000 loss tensor(0.8594, device='cuda:0')
# episode: 102000 loss tensor(0.8726, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.046062594649167087
# gzsl: unseen=0.0146 , seen=0.2326 , h=0.0275
# ____________________________________________________________________________________________________
# episode: 103000 loss tensor(0.8802, device='cuda:0')
# episode: 104000 loss tensor(0.8734, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04656739020696618
# gzsl: unseen=0.0155 , seen=0.2320 , h=0.0291
# ____________________________________________________________________________________________________
# episode: 105000 loss tensor(0.8647, device='cuda:0')
# episode: 106000 loss tensor(0.8696, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.046819787985865724
# gzsl: unseen=0.0159 , seen=0.2306 , h=0.0298
# ____________________________________________________________________________________________________
# episode: 107000 loss tensor(0.8590, device='cuda:0')
# episode: 108000 loss tensor(0.8713, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04707218576476527
# gzsl: unseen=0.0164 , seen=0.2333 , h=0.0307
# ____________________________________________________________________________________________________
# episode: 109000 loss tensor(0.8678, device='cuda:0')
# episode: 110000 loss tensor(0.8584, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04795557799091368
# gzsl: unseen=0.0170 , seen=0.2387 , h=0.0318
# ____________________________________________________________________________________________________
# episode: 111000 loss tensor(0.8571, device='cuda:0')
# episode: 112000 loss tensor(0.8670, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04820797576981323
# gzsl: unseen=0.0172 , seen=0.2421 , h=0.0321
# ____________________________________________________________________________________________________
# episode: 113000 loss tensor(0.8559, device='cuda:0')
# episode: 114000 loss tensor(0.8620, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04820797576981323
# gzsl: unseen=0.0174 , seen=0.2454 , h=0.0325
# ____________________________________________________________________________________________________
# episode: 115000 loss tensor(0.8658, device='cuda:0')
# episode: 116000 loss tensor(0.8700, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.048334174659263
# gzsl: unseen=0.0174 , seen=0.2502 , h=0.0326
# ____________________________________________________________________________________________________
# episode: 117000 loss tensor(0.8498, device='cuda:0')
# episode: 118000 loss tensor(0.8569, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.048965169106511865
# gzsl: unseen=0.0178 , seen=0.2515 , h=0.0332
# ____________________________________________________________________________________________________
# episode: 119000 loss tensor(0.8339, device='cuda:0')
# episode: 120000 loss tensor(0.8402, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.048965169106511865
# gzsl: unseen=0.0182 , seen=0.2562 , h=0.0339
# ____________________________________________________________________________________________________
# episode: 121000 loss tensor(0.8538, device='cuda:0')
# episode: 122000 loss tensor(0.8564, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.048965169106511865
# gzsl: unseen=0.0184 , seen=0.2610 , h=0.0344
# ____________________________________________________________________________________________________
# episode: 123000 loss tensor(0.8623, device='cuda:0')
# episode: 124000 loss tensor(0.8583, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.049091367995961636
# gzsl: unseen=0.0188 , seen=0.2657 , h=0.0351
# ____________________________________________________________________________________________________
# episode: 125000 loss tensor(0.8601, device='cuda:0')
# episode: 126000 loss tensor(0.8649, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.049091367995961636
# gzsl: unseen=0.0189 , seen=0.2704 , h=0.0354
# ____________________________________________________________________________________________________
# episode: 127000 loss tensor(0.8651, device='cuda:0')
# episode: 128000 loss tensor(0.8705, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.04946996466431095
# gzsl: unseen=0.0191 , seen=0.2744 , h=0.0356
# ____________________________________________________________________________________________________
# episode: 129000 loss tensor(0.8497, device='cuda:0')
# episode: 130000 loss tensor(0.8630, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0497223624432105
# gzsl: unseen=0.0188 , seen=0.2825 , h=0.0353
# ____________________________________________________________________________________________________
# episode: 131000 loss tensor(0.8606, device='cuda:0')
# episode: 132000 loss tensor(0.8536, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.049974760222110046
# gzsl: unseen=0.0183 , seen=0.2859 , h=0.0344
# ____________________________________________________________________________________________________
# episode: 133000 loss tensor(0.8657, device='cuda:0')
# episode: 134000 loss tensor(0.8430, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05022715800100959
# gzsl: unseen=0.0174 , seen=0.2920 , h=0.0329
# ____________________________________________________________________________________________________
# episode: 135000 loss tensor(0.8389, device='cuda:0')
# episode: 136000 loss tensor(0.8447, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05060575466935891
# gzsl: unseen=0.0170 , seen=0.3014 , h=0.0323
# ____________________________________________________________________________________________________
# episode: 137000 loss tensor(0.8599, device='cuda:0')
# episode: 138000 loss tensor(0.8732, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05047955577990914
# gzsl: unseen=0.0168 , seen=0.3095 , h=0.0318
# ____________________________________________________________________________________________________
# episode: 139000 loss tensor(0.8548, device='cuda:0')
# episode: 140000 loss tensor(0.8308, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05073195355880868
# gzsl: unseen=0.0165 , seen=0.3142 , h=0.0314
# ____________________________________________________________________________________________________
# episode: 141000 loss tensor(0.8716, device='cuda:0')
# episode: 142000 loss tensor(0.8480, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05098435133770823
# gzsl: unseen=0.0158 , seen=0.3183 , h=0.0301
# ____________________________________________________________________________________________________
# episode: 143000 loss tensor(0.8515, device='cuda:0')
# episode: 144000 loss tensor(0.8542, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05123674911660778
# gzsl: unseen=0.0143 , seen=0.3203 , h=0.0273
# ____________________________________________________________________________________________________
# episode: 145000 loss tensor(0.8478, device='cuda:0')
# episode: 146000 loss tensor(0.8430, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.052120141342756186
# gzsl: unseen=0.0133 , seen=0.3264 , h=0.0255
# ____________________________________________________________________________________________________
# episode: 147000 loss tensor(0.8551, device='cuda:0')
# episode: 148000 loss tensor(0.8745, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.052751135790005045
# gzsl: unseen=0.0130 , seen=0.3324 , h=0.0250
# ____________________________________________________________________________________________________
# episode: 149000 loss tensor(0.8545, device='cuda:0')
# episode: 150000 loss tensor(0.8357, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05350832912670368
# gzsl: unseen=0.0121 , seen=0.3392 , h=0.0234
# ____________________________________________________________________________________________________
# episode: 151000 loss tensor(0.8433, device='cuda:0')
# episode: 152000 loss tensor(0.8359, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05426552246340232
# gzsl: unseen=0.0116 , seen=0.3405 , h=0.0225
# ____________________________________________________________________________________________________
# episode: 153000 loss tensor(0.8456, device='cuda:0')
# episode: 154000 loss tensor(0.8494, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05451792024230187
# gzsl: unseen=0.0109 , seen=0.3439 , h=0.0210
# ____________________________________________________________________________________________________
# episode: 155000 loss tensor(0.8544, device='cuda:0')
# episode: 156000 loss tensor(0.8423, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05464411913175164
# gzsl: unseen=0.0102 , seen=0.3506 , h=0.0199
# ____________________________________________________________________________________________________
# episode: 157000 loss tensor(0.8494, device='cuda:0')
# episode: 158000 loss tensor(0.8514, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05514891468955073
# gzsl: unseen=0.0093 , seen=0.3560 , h=0.0182
# ____________________________________________________________________________________________________
# episode: 159000 loss tensor(0.8457, device='cuda:0')
# episode: 160000 loss tensor(0.8378, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05540131246845028
# gzsl: unseen=0.0091 , seen=0.3601 , h=0.0177
# ____________________________________________________________________________________________________
# episode: 161000 loss tensor(0.8388, device='cuda:0')
# episode: 162000 loss tensor(0.8376, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05565371024734982
# gzsl: unseen=0.0087 , seen=0.3594 , h=0.0170
# ____________________________________________________________________________________________________
# episode: 163000 loss tensor(0.8473, device='cuda:0')
# episode: 164000 loss tensor(0.8360, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05603230691569914
# gzsl: unseen=0.0076 , seen=0.3655 , h=0.0148
# ____________________________________________________________________________________________________
# episode: 165000 loss tensor(0.8390, device='cuda:0')
# episode: 166000 loss tensor(0.8359, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05628470469459869
# gzsl: unseen=0.0071 , seen=0.3668 , h=0.0139
# ____________________________________________________________________________________________________
# episode: 167000 loss tensor(0.8364, device='cuda:0')
# episode: 168000 loss tensor(0.8350, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05590610802624937
# gzsl: unseen=0.0066 , seen=0.3682 , h=0.0129
# ____________________________________________________________________________________________________
# episode: 169000 loss tensor(0.8459, device='cuda:0')
# episode: 170000 loss tensor(0.8345, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05603230691569914
# gzsl: unseen=0.0062 , seen=0.3742 , h=0.0122
# ____________________________________________________________________________________________________
# episode: 171000 loss tensor(0.8333, device='cuda:0')
# episode: 172000 loss tensor(0.8537, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05628470469459869
# gzsl: unseen=0.0058 , seen=0.3810 , h=0.0114
# ____________________________________________________________________________________________________
# episode: 173000 loss tensor(0.8365, device='cuda:0')
# episode: 174000 loss tensor(0.8337, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05628470469459869
# gzsl: unseen=0.0056 , seen=0.3823 , h=0.0109
# ____________________________________________________________________________________________________
# episode: 175000 loss tensor(0.8342, device='cuda:0')
# episode: 176000 loss tensor(0.8410, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05641090358404846
# gzsl: unseen=0.0056 , seen=0.3918 , h=0.0110
# ____________________________________________________________________________________________________
# episode: 177000 loss tensor(0.8307, device='cuda:0')
# episode: 178000 loss tensor(0.8338, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056915699141847555
# gzsl: unseen=0.0053 , seen=0.3985 , h=0.0105
# ____________________________________________________________________________________________________
# episode: 179000 loss tensor(0.8503, device='cuda:0')
# episode: 180000 loss tensor(0.8429, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.057041898031297326
# gzsl: unseen=0.0050 , seen=0.4026 , h=0.0100
# ____________________________________________________________________________________________________
# episode: 181000 loss tensor(0.8325, device='cuda:0')
# episode: 182000 loss tensor(0.8419, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056915699141847555
# gzsl: unseen=0.0049 , seen=0.4059 , h=0.0097
# ____________________________________________________________________________________________________
# episode: 183000 loss tensor(0.8335, device='cuda:0')
# episode: 184000 loss tensor(0.8452, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056915699141847555
# gzsl: unseen=0.0048 , seen=0.4113 , h=0.0095
# ____________________________________________________________________________________________________
# episode: 185000 loss tensor(0.8337, device='cuda:0')
# episode: 186000 loss tensor(0.8480, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056663301362948004
# gzsl: unseen=0.0044 , seen=0.4154 , h=0.0087
# ____________________________________________________________________________________________________
# episode: 187000 loss tensor(0.8458, device='cuda:0')
# episode: 188000 loss tensor(0.8526, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05742049469964664
# gzsl: unseen=0.0042 , seen=0.4194 , h=0.0082
# ____________________________________________________________________________________________________
# episode: 189000 loss tensor(0.8356, device='cuda:0')
# episode: 190000 loss tensor(0.8430, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056915699141847555
# gzsl: unseen=0.0042 , seen=0.4241 , h=0.0082
# ____________________________________________________________________________________________________
# episode: 191000 loss tensor(0.8362, device='cuda:0')
# episode: 192000 loss tensor(0.8294, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05615850580514892
# gzsl: unseen=0.0042 , seen=0.4262 , h=0.0082
# ____________________________________________________________________________________________________
# episode: 193000 loss tensor(0.8429, device='cuda:0')
# episode: 194000 loss tensor(0.8222, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05615850580514892
# gzsl: unseen=0.0037 , seen=0.4316 , h=0.0073
# ____________________________________________________________________________________________________
# episode: 195000 loss tensor(0.8344, device='cuda:0')
# episode: 196000 loss tensor(0.8269, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05615850580514892
# gzsl: unseen=0.0034 , seen=0.4349 , h=0.0068
# ____________________________________________________________________________________________________
# episode: 197000 loss tensor(0.8441, device='cuda:0')
# episode: 198000 loss tensor(0.8500, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05641090358404846
# gzsl: unseen=0.0033 , seen=0.4383 , h=0.0065
# ____________________________________________________________________________________________________
# episode: 199000 loss tensor(0.8407, device='cuda:0')
# episode: 200000 loss tensor(0.8505, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05615850580514892
# gzsl: unseen=0.0032 , seen=0.4464 , h=0.0063
# ____________________________________________________________________________________________________
# episode: 201000 loss tensor(0.8302, device='cuda:0')
# episode: 202000 loss tensor(0.8276, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05615850580514892
# gzsl: unseen=0.0032 , seen=0.4477 , h=0.0063
# ____________________________________________________________________________________________________
# episode: 203000 loss tensor(0.8375, device='cuda:0')
# episode: 204000 loss tensor(0.8280, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05603230691569914
# gzsl: unseen=0.0030 , seen=0.4471 , h=0.0060
# ____________________________________________________________________________________________________
# episode: 205000 loss tensor(0.8247, device='cuda:0')
# episode: 206000 loss tensor(0.8328, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05615850580514892
# gzsl: unseen=0.0029 , seen=0.4491 , h=0.0058
# ____________________________________________________________________________________________________
# episode: 207000 loss tensor(0.8244, device='cuda:0')
# episode: 208000 loss tensor(0.8440, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05653710247349823
# gzsl: unseen=0.0029 , seen=0.4518 , h=0.0058
# ____________________________________________________________________________________________________
# episode: 209000 loss tensor(0.8411, device='cuda:0')
# episode: 210000 loss tensor(0.8355, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05653710247349823
# gzsl: unseen=0.0029 , seen=0.4518 , h=0.0058
# ____________________________________________________________________________________________________
# episode: 211000 loss tensor(0.8391, device='cuda:0')
# episode: 212000 loss tensor(0.8538, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056915699141847555
# gzsl: unseen=0.0029 , seen=0.4511 , h=0.0058
# ____________________________________________________________________________________________________
# episode: 213000 loss tensor(0.8240, device='cuda:0')
# episode: 214000 loss tensor(0.8288, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056789500252397776
# gzsl: unseen=0.0028 , seen=0.4538 , h=0.0055
# ____________________________________________________________________________________________________
# episode: 215000 loss tensor(0.8244, device='cuda:0')
# episode: 216000 loss tensor(0.8358, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056663301362948004
# gzsl: unseen=0.0027 , seen=0.4565 , h=0.0053
# ____________________________________________________________________________________________________
# episode: 217000 loss tensor(0.8266, device='cuda:0')
# episode: 218000 loss tensor(0.8306, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056789500252397776
# gzsl: unseen=0.0027 , seen=0.4579 , h=0.0053
# ____________________________________________________________________________________________________
# episode: 219000 loss tensor(0.8417, device='cuda:0')
# episode: 220000 loss tensor(0.8466, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05653710247349823
# gzsl: unseen=0.0025 , seen=0.4599 , h=0.0050
# ____________________________________________________________________________________________________
# episode: 221000 loss tensor(0.8317, device='cuda:0')
# episode: 222000 loss tensor(0.8274, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056789500252397776
# gzsl: unseen=0.0024 , seen=0.4612 , h=0.0048
# ____________________________________________________________________________________________________
# episode: 223000 loss tensor(0.8340, device='cuda:0')
# episode: 224000 loss tensor(0.8137, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.056915699141847555
# gzsl: unseen=0.0024 , seen=0.4646 , h=0.0048
# ____________________________________________________________________________________________________
# episode: 225000 loss tensor(0.8307, device='cuda:0')
# episode: 226000 loss tensor(0.8260, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.057041898031297326
# gzsl: unseen=0.0024 , seen=0.4653 , h=0.0048
# ____________________________________________________________________________________________________
# episode: 227000 loss tensor(0.8374, device='cuda:0')
# episode: 228000 loss tensor(0.8396, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0571680969207471
# gzsl: unseen=0.0024 , seen=0.4659 , h=0.0048
# ____________________________________________________________________________________________________
# episode: 229000 loss tensor(0.8193, device='cuda:0')
# episode: 230000 loss tensor(0.8290, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.057041898031297326
# gzsl: unseen=0.0023 , seen=0.4680 , h=0.0045
# ____________________________________________________________________________________________________
# episode: 231000 loss tensor(0.8249, device='cuda:0')
# episode: 232000 loss tensor(0.8355, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0571680969207471
# gzsl: unseen=0.0023 , seen=0.4700 , h=0.0045
# ____________________________________________________________________________________________________
# episode: 233000 loss tensor(0.8417, device='cuda:0')
# episode: 234000 loss tensor(0.8308, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05742049469964664
# gzsl: unseen=0.0024 , seen=0.4700 , h=0.0048
# ____________________________________________________________________________________________________
# episode: 235000 loss tensor(0.8529, device='cuda:0')
# episode: 236000 loss tensor(0.8558, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05767289247854619
# gzsl: unseen=0.0021 , seen=0.4720 , h=0.0043
# ____________________________________________________________________________________________________
# episode: 237000 loss tensor(0.8423, device='cuda:0')
# episode: 238000 loss tensor(0.8571, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05754669358909641
# gzsl: unseen=0.0020 , seen=0.4720 , h=0.0040
# ____________________________________________________________________________________________________
# episode: 239000 loss tensor(0.8436, device='cuda:0')
# episode: 240000 loss tensor(0.8243, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05767289247854619
# gzsl: unseen=0.0019 , seen=0.4720 , h=0.0038
# ____________________________________________________________________________________________________
# episode: 241000 loss tensor(0.8506, device='cuda:0')
# episode: 242000 loss tensor(0.8287, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05767289247854619
# gzsl: unseen=0.0018 , seen=0.4734 , h=0.0035
# ____________________________________________________________________________________________________
# episode: 243000 loss tensor(0.8310, device='cuda:0')
# episode: 244000 loss tensor(0.8239, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.057799091367995964
# gzsl: unseen=0.0018 , seen=0.4727 , h=0.0035
# ____________________________________________________________________________________________________
# episode: 245000 loss tensor(0.8222, device='cuda:0')
# episode: 246000 loss tensor(0.8315, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.057799091367995964
# gzsl: unseen=0.0016 , seen=0.4720 , h=0.0033
# ____________________________________________________________________________________________________
# episode: 247000 loss tensor(0.8263, device='cuda:0')
# episode: 248000 loss tensor(0.8305, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.057799091367995964
# gzsl: unseen=0.0014 , seen=0.4727 , h=0.0028
# ____________________________________________________________________________________________________
# episode: 249000 loss tensor(0.8388, device='cuda:0')
# episode: 250000 loss tensor(0.8192, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.057799091367995964
# gzsl: unseen=0.0014 , seen=0.4734 , h=0.0028
# ____________________________________________________________________________________________________
# episode: 251000 loss tensor(0.8295, device='cuda:0')
# episode: 252000 loss tensor(0.8278, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.057925290257445736
# gzsl: unseen=0.0014 , seen=0.4734 , h=0.0028
# ____________________________________________________________________________________________________
# episode: 253000 loss tensor(0.8183, device='cuda:0')
# episode: 254000 loss tensor(0.8211, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05805148914689551
# gzsl: unseen=0.0014 , seen=0.4747 , h=0.0028
# ____________________________________________________________________________________________________
# episode: 255000 loss tensor(0.8261, device='cuda:0')
# episode: 256000 loss tensor(0.8416, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05817768803634528
# gzsl: unseen=0.0013 , seen=0.4788 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 257000 loss tensor(0.8470, device='cuda:0')
# episode: 258000 loss tensor(0.8205, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05843008581524482
# gzsl: unseen=0.0013 , seen=0.4788 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 259000 loss tensor(0.8360, device='cuda:0')
# episode: 260000 loss tensor(0.8202, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05843008581524482
# gzsl: unseen=0.0011 , seen=0.4794 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 261000 loss tensor(0.8441, device='cuda:0')
# episode: 262000 loss tensor(0.8276, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0585562847046946
# gzsl: unseen=0.0011 , seen=0.4842 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 263000 loss tensor(0.8417, device='cuda:0')
# episode: 264000 loss tensor(0.8281, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05868248359414437
# gzsl: unseen=0.0009 , seen=0.4855 , h=0.0018
# ____________________________________________________________________________________________________
# episode: 265000 loss tensor(0.8232, device='cuda:0')
# episode: 266000 loss tensor(0.8308, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05868248359414437
# gzsl: unseen=0.0009 , seen=0.4862 , h=0.0018
# ____________________________________________________________________________________________________
# episode: 267000 loss tensor(0.8379, device='cuda:0')
# episode: 268000 loss tensor(0.8352, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.058808682483594145
# gzsl: unseen=0.0006 , seen=0.4882 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 269000 loss tensor(0.8471, device='cuda:0')
# episode: 270000 loss tensor(0.8533, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05943967693084301
# gzsl: unseen=0.0006 , seen=0.4902 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 271000 loss tensor(0.8232, device='cuda:0')
# episode: 272000 loss tensor(0.8332, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05918727915194346
# gzsl: unseen=0.0006 , seen=0.4909 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 273000 loss tensor(0.8325, device='cuda:0')
# episode: 274000 loss tensor(0.8188, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05906108026249369
# gzsl: unseen=0.0006 , seen=0.4909 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 275000 loss tensor(0.8296, device='cuda:0')
# episode: 276000 loss tensor(0.8348, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05906108026249369
# gzsl: unseen=0.0008 , seen=0.4956 , h=0.0015
# ____________________________________________________________________________________________________
# episode: 277000 loss tensor(0.8095, device='cuda:0')
# episode: 278000 loss tensor(0.8258, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05906108026249369
# gzsl: unseen=0.0008 , seen=0.4970 , h=0.0015
# ____________________________________________________________________________________________________
# episode: 279000 loss tensor(0.8296, device='cuda:0')
# episode: 280000 loss tensor(0.8512, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.05931347804139324
# gzsl: unseen=0.0006 , seen=0.5003 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 281000 loss tensor(0.8530, device='cuda:0')
# episode: 282000 loss tensor(0.8353, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06007067137809187
# gzsl: unseen=0.0006 , seen=0.4990 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 283000 loss tensor(0.8358, device='cuda:0')
# episode: 284000 loss tensor(0.8233, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06007067137809187
# gzsl: unseen=0.0006 , seen=0.4997 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 285000 loss tensor(0.8207, device='cuda:0')
# episode: 286000 loss tensor(0.8200, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06007067137809187
# gzsl: unseen=0.0006 , seen=0.5003 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 287000 loss tensor(0.8338, device='cuda:0')
# episode: 288000 loss tensor(0.8370, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06007067137809187
# gzsl: unseen=0.0006 , seen=0.4997 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 289000 loss tensor(0.8270, device='cuda:0')
# episode: 290000 loss tensor(0.8160, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06019687026754165
# gzsl: unseen=0.0006 , seen=0.4997 , h=0.0013
# ____________________________________________________________________________________________________
# episode: 291000 loss tensor(0.8387, device='cuda:0')
# episode: 292000 loss tensor(0.8335, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06032306915699142
# ...
# gzsl: unseen=0.0010 , seen=0.5280 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 405000 loss tensor(0.8126, device='cuda:0')
# episode: 406000 loss tensor(0.8309, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06726400807672893
# gzsl: unseen=0.0010 , seen=0.5280 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 407000 loss tensor(0.8407, device='cuda:0')
# episode: 408000 loss tensor(0.8182, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06726400807672893
# gzsl: unseen=0.0010 , seen=0.5280 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 409000 loss tensor(0.8214, device='cuda:0')
# episode: 410000 loss tensor(0.8245, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0673902069661787
# gzsl: unseen=0.0010 , seen=0.5273 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 411000 loss tensor(0.8150, device='cuda:0')
# episode: 412000 loss tensor(0.8328, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0673902069661787
# gzsl: unseen=0.0010 , seen=0.5280 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 413000 loss tensor(0.8107, device='cuda:0')
# episode: 414000 loss tensor(0.7954, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0673902069661787
# gzsl: unseen=0.0010 , seen=0.5266 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 415000 loss tensor(0.8033, device='cuda:0')
# episode: 416000 loss tensor(0.8247, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06751640585562847
# gzsl: unseen=0.0010 , seen=0.5273 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 417000 loss tensor(0.8163, device='cuda:0')
# episode: 418000 loss tensor(0.7902, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06751640585562847
# gzsl: unseen=0.0010 , seen=0.5280 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 419000 loss tensor(0.8141, device='cuda:0')
# episode: 420000 loss tensor(0.8125, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06751640585562847
# gzsl: unseen=0.0010 , seen=0.5280 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 421000 loss tensor(0.8268, device='cuda:0')
# episode: 422000 loss tensor(0.8202, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06751640585562847
# gzsl: unseen=0.0010 , seen=0.5287 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 423000 loss tensor(0.7951, device='cuda:0')
# episode: 424000 loss tensor(0.8161, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06764260474507824
# gzsl: unseen=0.0010 , seen=0.5273 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 425000 loss tensor(0.8264, device='cuda:0')
# episode: 426000 loss tensor(0.8271, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06776880363452802
# gzsl: unseen=0.0010 , seen=0.5287 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 427000 loss tensor(0.7950, device='cuda:0')
# episode: 428000 loss tensor(0.8133, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06764260474507824
# gzsl: unseen=0.0011 , seen=0.5293 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 429000 loss tensor(0.8328, device='cuda:0')
# episode: 430000 loss tensor(0.8146, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06789500252397779
# gzsl: unseen=0.0011 , seen=0.5287 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 431000 loss tensor(0.8276, device='cuda:0')
# episode: 432000 loss tensor(0.8274, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06789500252397779
# gzsl: unseen=0.0011 , seen=0.5280 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 433000 loss tensor(0.8134, device='cuda:0')
# episode: 434000 loss tensor(0.8244, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0682735991923271
# gzsl: unseen=0.0011 , seen=0.5280 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 435000 loss tensor(0.8351, device='cuda:0')
# episode: 436000 loss tensor(0.8442, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06839979808177687
# gzsl: unseen=0.0011 , seen=0.5280 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 437000 loss tensor(0.8082, device='cuda:0')
# episode: 438000 loss tensor(0.8373, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06839979808177687
# gzsl: unseen=0.0011 , seen=0.5287 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 439000 loss tensor(0.8115, device='cuda:0')
# episode: 440000 loss tensor(0.8264, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06852599697122665
# gzsl: unseen=0.0011 , seen=0.5293 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 441000 loss tensor(0.8104, device='cuda:0')
# episode: 442000 loss tensor(0.8185, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06865219586067643
# gzsl: unseen=0.0011 , seen=0.5287 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 443000 loss tensor(0.8385, device='cuda:0')
# episode: 444000 loss tensor(0.8065, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06865219586067643
# gzsl: unseen=0.0011 , seen=0.5300 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 445000 loss tensor(0.8083, device='cuda:0')
# episode: 446000 loss tensor(0.8393, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06915699141847552
# gzsl: unseen=0.0011 , seen=0.5293 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 447000 loss tensor(0.8086, device='cuda:0')
# episode: 448000 loss tensor(0.8424, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06928319030792529
# gzsl: unseen=0.0011 , seen=0.5280 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 449000 loss tensor(0.8308, device='cuda:0')
# episode: 450000 loss tensor(0.8228, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06953558808682483
# gzsl: unseen=0.0011 , seen=0.5280 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 451000 loss tensor(0.8269, device='cuda:0')
# episode: 452000 loss tensor(0.7899, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.06978798586572438
# gzsl: unseen=0.0013 , seen=0.5273 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 453000 loss tensor(0.8277, device='cuda:0')
# episode: 454000 loss tensor(0.8236, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07016658253407371
# gzsl: unseen=0.0011 , seen=0.5273 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 455000 loss tensor(0.8189, device='cuda:0')
# episode: 456000 loss tensor(0.8182, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07029278142352348
# gzsl: unseen=0.0011 , seen=0.5280 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 457000 loss tensor(0.8083, device='cuda:0')
# episode: 458000 loss tensor(0.8285, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07054517920242302
# gzsl: unseen=0.0011 , seen=0.5280 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 459000 loss tensor(0.8171, device='cuda:0')
# episode: 460000 loss tensor(0.8479, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07054517920242302
# gzsl: unseen=0.0011 , seen=0.5280 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 461000 loss tensor(0.8019, device='cuda:0')
# episode: 462000 loss tensor(0.8320, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0706713780918728
# gzsl: unseen=0.0011 , seen=0.5280 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 463000 loss tensor(0.8082, device='cuda:0')
# episode: 464000 loss tensor(0.8446, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07092377587077234
# gzsl: unseen=0.0011 , seen=0.5287 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 465000 loss tensor(0.8088, device='cuda:0')
# episode: 466000 loss tensor(0.8371, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07104997476022211
# gzsl: unseen=0.0011 , seen=0.5314 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 467000 loss tensor(0.8199, device='cuda:0')
# episode: 468000 loss tensor(0.8333, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07117617364967188
# gzsl: unseen=0.0011 , seen=0.5314 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 469000 loss tensor(0.8420, device='cuda:0')
# episode: 470000 loss tensor(0.8026, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07117617364967188
# gzsl: unseen=0.0011 , seen=0.5320 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 471000 loss tensor(0.8312, device='cuda:0')
# episode: 472000 loss tensor(0.8145, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07130237253912165
# gzsl: unseen=0.0011 , seen=0.5334 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 473000 loss tensor(0.8051, device='cuda:0')
# episode: 474000 loss tensor(0.8410, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07130237253912165
# gzsl: unseen=0.0011 , seen=0.5334 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 475000 loss tensor(0.8159, device='cuda:0')
# episode: 476000 loss tensor(0.8189, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07130237253912165
# gzsl: unseen=0.0011 , seen=0.5334 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 477000 loss tensor(0.8113, device='cuda:0')
# episode: 478000 loss tensor(0.8215, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07142857142857142
# gzsl: unseen=0.0011 , seen=0.5341 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 479000 loss tensor(0.8154, device='cuda:0')
# episode: 480000 loss tensor(0.8370, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07180716809692075
# gzsl: unseen=0.0011 , seen=0.5347 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 481000 loss tensor(0.8104, device='cuda:0')
# episode: 482000 loss tensor(0.8229, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.0720595658758203
# gzsl: unseen=0.0011 , seen=0.5347 , h=0.0023
# ____________________________________________________________________________________________________
# episode: 483000 loss tensor(0.8421, device='cuda:0')
# episode: 484000 loss tensor(0.8096, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07218576476527007
# gzsl: unseen=0.0013 , seen=0.5347 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 485000 loss tensor(0.8203, device='cuda:0')
# episode: 486000 loss tensor(0.8144, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07231196365471984
# gzsl: unseen=0.0013 , seen=0.5354 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 487000 loss tensor(0.8344, device='cuda:0')
# episode: 488000 loss tensor(0.8254, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07269056032306916
# gzsl: unseen=0.0013 , seen=0.5354 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 489000 loss tensor(0.8299, device='cuda:0')
# episode: 490000 loss tensor(0.8209, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07332155477031801
# gzsl: unseen=0.0013 , seen=0.5354 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 491000 loss tensor(0.8203, device='cuda:0')
# episode: 492000 loss tensor(0.8259, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07370015143866734
# gzsl: unseen=0.0013 , seen=0.5347 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 493000 loss tensor(0.8121, device='cuda:0')
# episode: 494000 loss tensor(0.8026, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07370015143866734
# gzsl: unseen=0.0013 , seen=0.5347 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 495000 loss tensor(0.8137, device='cuda:0')
# episode: 496000 loss tensor(0.8077, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07382635032811712
# gzsl: unseen=0.0013 , seen=0.5347 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 497000 loss tensor(0.8345, device='cuda:0')
# episode: 498000 loss tensor(0.8319, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07407874810701666
# gzsl: unseen=0.0013 , seen=0.5354 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 499000 loss tensor(0.8331, device='cuda:0')
# episode: 500000 loss tensor(0.8320, device='cuda:0')
# Testing...
# class num: 12
# class num: 32
# class num: 32
# zsl: 0.07420494699646643
# gzsl: unseen=0.0013 , seen=0.5361 , h=0.0025
# ____________________________________________________________________________________________________
