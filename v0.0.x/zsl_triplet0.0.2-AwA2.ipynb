# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os

# %%
BATCH_SIZE = 64
EPISODE = 500000
TEST_EPISODE = 1000
LEARNING_RATE =1e-2
GPU = 0
Margin = 1

# %%
print("init dataset")
##################################参数##################################################################
dataroot = './data'
dataset = 'AwA2_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个

########################add negative pairs#######################
#x_negative = np.empty_like(x)
#x_negative_label = np.empty_like(train_label)
#print(x.shape[0])

#for i in range(x.shape[0]):
#    pick=np.random.choice(np.where(train_label[i]!=train_id)[0], replace=True)
#    x_negative[i] = x[pick]
#    x_negative_label[i] = train_label[pick]
    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
#train_negative_label = torch.from_numpy(x_negative_label).unsqueeze(1)
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
#print(all_attributes)
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net import AttributeNetwork
from my_net import TripletNetwork_cos

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(85,1024,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
triplet_network = TripletNetwork_cos(attribute_network)  #metric learning   
triplet_network.cuda(GPU)   
#attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
#优化器adam 学习率 正则1e-5

#attribute_network_scheduler = StepLR(attribute_network_optim, step_size=200000, gamma=0.5)
#学习率每200k步 乘0.5
#triplet_network_optim = torch.optim.Adam(triplet_network.parameters(), lr=LEARNING_RATE)
#
triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE, momentum=0.5)
triplet_network_scheduler = StepLR(triplet_network_optim , step_size=200000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = Variable(batch_features_ext).cuda(GPU).float()  # 32*1024

        #print(batch_features_ext)

        sample_features = attribute_network(Variable(sample_attributes).cuda(GPU).float())
        sample_features_ext = sample_features.repeat(batch_size, 1)
        #print(sample_features_ext.shape)


        relations = F.cosine_similarity(batch_features_ext, sample_features_ext).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        #print(predict_labels)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
print("training...")
last_accuracy = 0.0
for episode in range(EPISODE):
   
    triplet_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    
    batch_features_negative = np.empty_like(batch_features.numpy())
    
    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_labels.numpy()]).squeeze(1)
    
    batch_features = Variable(batch_features).cuda(GPU).float()  # 32*2048
    
    for i in range(batch_features_negative.shape[0]):
        pick=np.random.choice(np.where(batch_labels.numpy()[i]!=train_id)[0], replace=True)
        batch_features_negative[i] = x[pick]    
    
    batch_features_negative = torch.from_numpy(batch_features_negative)
    batch_features_negative = Variable(batch_features_negative).cuda(GPU).float()  # 32*2048
    
    #batch_attributes = attribute_network(Variable(batch_attributes).cuda(GPU))
    batch_attributes = Variable(batch_attributes).cuda(GPU)
    
    dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(batch_attributes, batch_features, batch_features_negative)
    
    criterion = nn.MarginRankingLoss(margin = Margin).cuda(GPU)
    
    target = torch.FloatTensor(dista.size()).fill_(-1).cuda(GPU)
    
    
    loss_triplet= criterion(dista, distb, target)
    loss_embedd = embedded_x.norm(2) + embedded_y.norm(2) + embedded_z.norm(2)
    loss = loss_triplet #+ 0.001 * loss_embedd

    # update
    triplet_network.zero_grad()
    loss.backward()
    triplet_network_optim.step()
    
    if (episode+1)%1000 == 0:
        print("episode:", episode+1, "loss", loss.data)
    if (episode+1)%2000 == 0:
        print("Testing...")
        zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(50), attributes)
        gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(50), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        print('zsl:', zsl_accuracy)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        print('_'*100)
# Out:
# training...
# episode: 1000 loss tensor(0.9889, device='cuda:0')
# episode: 2000 loss tensor(0.9837, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.0796158220649564
# gzsl: unseen=0.0119 , seen=0.0337 , h=0.0176
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(0.9919, device='cuda:0')
# episode: 4000 loss tensor(0.9966, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.11651712372046
# gzsl: unseen=0.0158 , seen=0.0638 , h=0.0253
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(0.9862, device='cuda:0')
# episode: 6000 loss tensor(1.0039, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.15556678882851005
# gzsl: unseen=0.0217 , seen=0.0950 , h=0.0354
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(0.9884, device='cuda:0')
# episode: 8000 loss tensor(0.9870, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.1918362188803235
# gzsl: unseen=0.0284 , seen=0.1318 , h=0.0468
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(1.0124, device='cuda:0')
# episode: 10000 loss tensor(0.9922, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2243144193099962
# gzsl: unseen=0.0358 , seen=0.1647 , h=0.0588
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(0.9941, device='cuda:0')
# episode: 12000 loss tensor(0.9866, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24984203209907746
# gzsl: unseen=0.0439 , seen=0.1976 , h=0.0718
# ____________________________________________________________________________________________________
# episode: 13000 loss tensor(0.9721, device='cuda:0')
# episode: 14000 loss tensor(0.9826, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2684190572475673
# gzsl: unseen=0.0495 , seen=0.2293 , h=0.0815
# ____________________________________________________________________________________________________
# episode: 15000 loss tensor(0.9813, device='cuda:0')
# episode: 16000 loss tensor(0.9993, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27991912043472766
# gzsl: unseen=0.0574 , seen=0.2581 , h=0.0939
# ____________________________________________________________________________________________________
# episode: 17000 loss tensor(0.9858, device='cuda:0')
# episode: 18000 loss tensor(0.9776, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.29053456337672184
# gzsl: unseen=0.0647 , seen=0.2792 , h=0.1051
# ____________________________________________________________________________________________________
# episode: 19000 loss tensor(0.9742, device='cuda:0')
# episode: 20000 loss tensor(1.0031, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.30026538607354986
# gzsl: unseen=0.0701 , seen=0.2963 , h=0.1134
# ____________________________________________________________________________________________________
# episode: 21000 loss tensor(0.9858, device='cuda:0')
# episode: 22000 loss tensor(0.9870, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3045621129786427
# gzsl: unseen=0.0741 , seen=0.3108 , h=0.1196
# ____________________________________________________________________________________________________
# episode: 23000 loss tensor(0.9825, device='cuda:0')
# episode: 24000 loss tensor(0.9835, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3087324655629976
# gzsl: unseen=0.0754 , seen=0.3252 , h=0.1225
# ____________________________________________________________________________________________________
# episode: 25000 loss tensor(0.9823, device='cuda:0')
# episode: 26000 loss tensor(0.9940, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31088082901554404
# gzsl: unseen=0.0773 , seen=0.3410 , h=0.1261
# ____________________________________________________________________________________________________
# episode: 27000 loss tensor(0.9869, device='cuda:0')
# episode: 28000 loss tensor(0.9926, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31719954505244535
# gzsl: unseen=0.0792 , seen=0.3536 , h=0.1295
# ____________________________________________________________________________________________________
# episode: 29000 loss tensor(0.9913, device='cuda:0')
# episode: 30000 loss tensor(0.9851, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32440288133451284
# gzsl: unseen=0.0794 , seen=0.3660 , h=0.1304
# ____________________________________________________________________________________________________
# episode: 31000 loss tensor(0.9876, device='cuda:0')
# episode: 32000 loss tensor(0.9911, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.334891949955769
# gzsl: unseen=0.0771 , seen=0.3754 , h=0.1279
# ____________________________________________________________________________________________________
# episode: 33000 loss tensor(0.9759, device='cuda:0')
# episode: 34000 loss tensor(0.9807, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.34399090104890684
# gzsl: unseen=0.0760 , seen=0.3830 , h=0.1268
# ____________________________________________________________________________________________________
# episode: 35000 loss tensor(0.9734, device='cuda:0')
# episode: 36000 loss tensor(0.9833, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3548590926323771
# gzsl: unseen=0.0735 , seen=0.3910 , h=0.1238
# ____________________________________________________________________________________________________
# episode: 37000 loss tensor(1.0069, device='cuda:0')
# episode: 38000 loss tensor(0.9848, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.36787564766839376
# gzsl: unseen=0.0710 , seen=0.3988 , h=0.1206
# ____________________________________________________________________________________________________
# episode: 39000 loss tensor(0.9689, device='cuda:0')
# episode: 40000 loss tensor(0.9909, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.37583722987488943
# gzsl: unseen=0.0696 , seen=0.4046 , h=0.1188
# ____________________________________________________________________________________________________
# episode: 41000 loss tensor(0.9904, device='cuda:0')
# episode: 42000 loss tensor(0.9815, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3859471755339315
# gzsl: unseen=0.0677 , seen=0.4090 , h=0.1162
# ____________________________________________________________________________________________________
# episode: 43000 loss tensor(0.9837, device='cuda:0')
# episode: 44000 loss tensor(0.9758, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.38898015923164414
# gzsl: unseen=0.0647 , seen=0.4089 , h=0.1117
# ____________________________________________________________________________________________________
# episode: 45000 loss tensor(0.9651, device='cuda:0')
# episode: 46000 loss tensor(0.9771, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3868317957790977
# gzsl: unseen=0.0614 , seen=0.4087 , h=0.1068
# ____________________________________________________________________________________________________
# episode: 47000 loss tensor(0.9778, device='cuda:0')
# episode: 48000 loss tensor(0.9661, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.38177682294957666
# gzsl: unseen=0.0576 , seen=0.4096 , h=0.1010
# ____________________________________________________________________________________________________
# episode: 49000 loss tensor(0.9864, device='cuda:0')
# episode: 50000 loss tensor(0.9788, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.37760647036522177
# gzsl: unseen=0.0524 , seen=0.4036 , h=0.0928
# ____________________________________________________________________________________________________
# episode: 51000 loss tensor(0.9710, device='cuda:0')
# episode: 52000 loss tensor(0.9630, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3711613800075825
# gzsl: unseen=0.0468 , seen=0.3992 , h=0.0837
# ____________________________________________________________________________________________________
# episode: 53000 loss tensor(0.9798, device='cuda:0')
# episode: 54000 loss tensor(0.9683, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.35991406546189814
# gzsl: unseen=0.0407 , seen=0.3888 , h=0.0737
# ____________________________________________________________________________________________________
# episode: 55000 loss tensor(0.9635, device='cuda:0')
# episode: 56000 loss tensor(0.9631, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3500568684443321
# gzsl: unseen=0.0354 , seen=0.3759 , h=0.0647
# ____________________________________________________________________________________________________
# episode: 57000 loss tensor(0.9665, device='cuda:0')
# episode: 58000 loss tensor(0.9532, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.339820548464552
# gzsl: unseen=0.0291 , seen=0.3633 , h=0.0538
# ____________________________________________________________________________________________________
# episode: 59000 loss tensor(0.9527, device='cuda:0')
# episode: 60000 loss tensor(0.9578, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3286996082396057
# gzsl: unseen=0.0238 , seen=0.3495 , h=0.0445
# ____________________________________________________________________________________________________
# episode: 61000 loss tensor(0.9605, device='cuda:0')
# episode: 62000 loss tensor(0.9607, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32124352331606215
# gzsl: unseen=0.0168 , seen=0.3334 , h=0.0320
# ____________________________________________________________________________________________________
# episode: 63000 loss tensor(0.9577, device='cuda:0')
# episode: 64000 loss tensor(0.9493, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3145456843169468
# gzsl: unseen=0.0116 , seen=0.3198 , h=0.0224
# ____________________________________________________________________________________________________
# episode: 65000 loss tensor(0.9844, device='cuda:0')
# episode: 66000 loss tensor(0.9497, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.30468848729938075
# gzsl: unseen=0.0080 , seen=0.3011 , h=0.0155
# ____________________________________________________________________________________________________
# episode: 67000 loss tensor(0.9370, device='cuda:0')
# episode: 68000 loss tensor(0.9555, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2986225199039555
# gzsl: unseen=0.0057 , seen=0.2839 , h=0.0112
# ____________________________________________________________________________________________________
# episode: 69000 loss tensor(0.9544, device='cuda:0')
# episode: 70000 loss tensor(0.9646, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.291166434980412
# gzsl: unseen=0.0045 , seen=0.2644 , h=0.0089
# ____________________________________________________________________________________________________
# episode: 71000 loss tensor(0.9420, device='cuda:0')
# episode: 72000 loss tensor(0.9322, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2839630986983445
# gzsl: unseen=0.0025 , seen=0.2479 , h=0.0050
# ____________________________________________________________________________________________________
# episode: 73000 loss tensor(0.9656, device='cuda:0')
# episode: 74000 loss tensor(0.9406, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27928724883103756
# gzsl: unseen=0.0023 , seen=0.2341 , h=0.0045
# ____________________________________________________________________________________________________
# episode: 75000 loss tensor(0.9123, device='cuda:0')
# episode: 76000 loss tensor(0.9354, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27536964488815874
# gzsl: unseen=0.0014 , seen=0.2171 , h=0.0028
# ____________________________________________________________________________________________________
# episode: 77000 loss tensor(0.9466, device='cuda:0')
# episode: 78000 loss tensor(0.9286, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2699355490964236
# gzsl: unseen=0.0009 , seen=0.2025 , h=0.0018
# ____________________________________________________________________________________________________
# episode: 79000 loss tensor(0.9349, device='cuda:0')
# episode: 80000 loss tensor(0.9545, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26500695058764057
# gzsl: unseen=0.0003 , seen=0.1897 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 81000 loss tensor(0.9383, device='cuda:0')
# episode: 82000 loss tensor(0.9442, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26096297232402377
# gzsl: unseen=0.0003 , seen=0.1783 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 83000 loss tensor(0.9380, device='cuda:0')
# episode: 84000 loss tensor(0.9378, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.257298117022621
# gzsl: unseen=0.0004 , seen=0.1688 , h=0.0008
# ____________________________________________________________________________________________________
# episode: 85000 loss tensor(0.9359, device='cuda:0')
# episode: 86000 loss tensor(0.9568, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2547706306078605
# gzsl: unseen=0.0005 , seen=0.1593 , h=0.0010
# ____________________________________________________________________________________________________
# episode: 87000 loss tensor(0.9400, device='cuda:0')
# episode: 88000 loss tensor(0.9358, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25262226715531405
# gzsl: unseen=0.0005 , seen=0.1532 , h=0.0010
# ____________________________________________________________________________________________________
# episode: 89000 loss tensor(0.9425, device='cuda:0')
# episode: 90000 loss tensor(0.9322, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2513585239479338
# gzsl: unseen=0.0004 , seen=0.1462 , h=0.0008
# ____________________________________________________________________________________________________
# episode: 91000 loss tensor(0.9360, device='cuda:0')
# episode: 92000 loss tensor(0.9431, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25085302666498166
# gzsl: unseen=0.0004 , seen=0.1420 , h=0.0008
# ____________________________________________________________________________________________________
# episode: 93000 loss tensor(0.9181, device='cuda:0')
# episode: 94000 loss tensor(0.9373, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2494629091368634
# gzsl: unseen=0.0003 , seen=0.1370 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 95000 loss tensor(0.9178, device='cuda:0')
# episode: 96000 loss tensor(0.9256, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2489574118539113
# gzsl: unseen=0.0004 , seen=0.1340 , h=0.0008
# ____________________________________________________________________________________________________
# episode: 97000 loss tensor(0.9508, device='cuda:0')
# episode: 98000 loss tensor(0.9392, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24870466321243523
# gzsl: unseen=0.0004 , seen=0.1311 , h=0.0008
# ____________________________________________________________________________________________________
# episode: 99000 loss tensor(0.9255, device='cuda:0')
# episode: 100000 loss tensor(0.9175, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24870466321243523
# gzsl: unseen=0.0003 , seen=0.1287 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 101000 loss tensor(0.9376, device='cuda:0')
# episode: 102000 loss tensor(0.9453, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2484519145709592
# gzsl: unseen=0.0003 , seen=0.1270 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 103000 loss tensor(0.9180, device='cuda:0')
# episode: 104000 loss tensor(0.9259, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2485782888916972
# gzsl: unseen=0.0003 , seen=0.1250 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 105000 loss tensor(0.9171, device='cuda:0')
# episode: 106000 loss tensor(0.9241, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2489574118539113
# gzsl: unseen=0.0003 , seen=0.1236 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 107000 loss tensor(0.9152, device='cuda:0')
# episode: 108000 loss tensor(0.9311, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2485782888916972
# gzsl: unseen=0.0001 , seen=0.1221 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 109000 loss tensor(0.9242, device='cuda:0')
# episode: 110000 loss tensor(0.9232, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2485782888916972
# gzsl: unseen=0.0001 , seen=0.1205 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 111000 loss tensor(0.9079, device='cuda:0')
# episode: 112000 loss tensor(0.9213, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24832554025022116
# gzsl: unseen=0.0001 , seen=0.1205 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 113000 loss tensor(0.9249, device='cuda:0')
# episode: 114000 loss tensor(0.9261, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2484519145709592
# gzsl: unseen=0.0001 , seen=0.1199 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 115000 loss tensor(0.9267, device='cuda:0')
# episode: 116000 loss tensor(0.9251, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24819916592948313
# gzsl: unseen=0.0001 , seen=0.1197 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 117000 loss tensor(0.9323, device='cuda:0')
# episode: 118000 loss tensor(0.9140, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24819916592948313
# gzsl: unseen=0.0001 , seen=0.1187 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 119000 loss tensor(0.9327, device='cuda:0')
# episode: 120000 loss tensor(0.9190, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2485782888916972
# gzsl: unseen=0.0001 , seen=0.1193 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 121000 loss tensor(0.9308, device='cuda:0')
# episode: 122000 loss tensor(0.9219, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2489574118539113
# gzsl: unseen=0.0001 , seen=0.1195 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 123000 loss tensor(0.9408, device='cuda:0')
# episode: 124000 loss tensor(0.9195, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24933653481612536
# gzsl: unseen=0.0001 , seen=0.1202 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 125000 loss tensor(0.9196, device='cuda:0')
# episode: 126000 loss tensor(0.9211, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2494629091368634
# gzsl: unseen=0.0003 , seen=0.1197 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 127000 loss tensor(0.9127, device='cuda:0')
# episode: 128000 loss tensor(0.9102, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25022115506129156
# gzsl: unseen=0.0003 , seen=0.1200 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 129000 loss tensor(0.9136, device='cuda:0')
# episode: 130000 loss tensor(0.9077, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2503475293820296
# gzsl: unseen=0.0003 , seen=0.1202 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 131000 loss tensor(0.9217, device='cuda:0')
# episode: 132000 loss tensor(0.9168, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25085302666498166
# gzsl: unseen=0.0003 , seen=0.1202 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 133000 loss tensor(0.9167, device='cuda:0')
# episode: 134000 loss tensor(0.9126, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2517376469101479
# gzsl: unseen=0.0003 , seen=0.1210 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 135000 loss tensor(0.9158, device='cuda:0')
# episode: 136000 loss tensor(0.9073, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25262226715531405
# gzsl: unseen=0.0003 , seen=0.1217 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 137000 loss tensor(0.9246, device='cuda:0')
# episode: 138000 loss tensor(0.9309, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2538860103626943
# gzsl: unseen=0.0003 , seen=0.1217 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 139000 loss tensor(0.9236, device='cuda:0')
# episode: 140000 loss tensor(0.9301, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25426513332490835
# gzsl: unseen=0.0003 , seen=0.1229 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 141000 loss tensor(0.9070, device='cuda:0')
# episode: 142000 loss tensor(0.8945, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2555288765322886
# gzsl: unseen=0.0003 , seen=0.1233 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 143000 loss tensor(0.9192, device='cuda:0')
# episode: 144000 loss tensor(0.9092, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.257298117022621
# gzsl: unseen=0.0003 , seen=0.1243 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 145000 loss tensor(0.9144, device='cuda:0')
# episode: 146000 loss tensor(0.9105, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25843548590926324
# gzsl: unseen=0.0003 , seen=0.1256 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 147000 loss tensor(0.9247, device='cuda:0')
# episode: 148000 loss tensor(0.9054, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2596992291166435
# gzsl: unseen=0.0003 , seen=0.1268 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 149000 loss tensor(0.9255, device='cuda:0')
# episode: 150000 loss tensor(0.8996, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26083659800328574
# gzsl: unseen=0.0003 , seen=0.1289 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 151000 loss tensor(0.9058, device='cuda:0')
# episode: 152000 loss tensor(0.9146, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26235308985214206
# gzsl: unseen=0.0001 , seen=0.1301 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 153000 loss tensor(0.9204, device='cuda:0')
# episode: 154000 loss tensor(0.9120, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2648805762669026
# gzsl: unseen=0.0001 , seen=0.1323 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 155000 loss tensor(0.9029, device='cuda:0')
# episode: 156000 loss tensor(0.9230, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2679135599646152
# gzsl: unseen=0.0001 , seen=0.1341 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 157000 loss tensor(0.9121, device='cuda:0')
# episode: 158000 loss tensor(0.9083, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2703146720586377
# gzsl: unseen=0.0001 , seen=0.1355 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 159000 loss tensor(0.9195, device='cuda:0')
# episode: 160000 loss tensor(0.9165, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.271831163907494
# gzsl: unseen=0.0000 , seen=0.1379 , h=0.0000
# ____________________________________________________________________________________________________
# episode: 161000 loss tensor(0.9151, device='cuda:0')
# episode: 162000 loss tensor(0.9114, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2732212814356123
# gzsl: unseen=0.0000 , seen=0.1396 , h=0.0000
# ____________________________________________________________________________________________________
# episode: 163000 loss tensor(0.9112, device='cuda:0')
# episode: 164000 loss tensor(0.9102, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27435865032225454
# gzsl: unseen=0.0000 , seen=0.1399 , h=0.0000
# ____________________________________________________________________________________________________
# episode: 165000 loss tensor(0.9049, device='cuda:0')
# episode: 166000 loss tensor(0.9119, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2761278908125869
# gzsl: unseen=0.0000 , seen=0.1409 , h=0.0000
# ____________________________________________________________________________________________________
# episode: 167000 loss tensor(0.9040, device='cuda:0')
# episode: 168000 loss tensor(0.9029, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2771388853784911
# gzsl: unseen=0.0000 , seen=0.1435 , h=0.0000
# ____________________________________________________________________________________________________
# episode: 169000 loss tensor(0.8994, device='cuda:0')
# episode: 170000 loss tensor(0.8975, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27928724883103756
# gzsl: unseen=0.0000 , seen=0.1450 , h=0.0000
# ____________________________________________________________________________________________________
# episode: 171000 loss tensor(0.9124, device='cuda:0')
# episode: 172000 loss tensor(0.9200, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.28017186907620373
# gzsl: unseen=0.0000 , seen=0.1462 , h=0.0000
# ____________________________________________________________________________________________________
# episode: 173000 loss tensor(0.9081, device='cuda:0')
# episode: 174000 loss tensor(0.9124, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2810564893213699
# gzsl: unseen=0.0000 , seen=0.1499 , h=0.0000
# ____________________________________________________________________________________________________
# episode: 175000 loss tensor(0.9212, device='cuda:0')
# episode: 176000 loss tensor(0.9137, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.28269935549096425
# gzsl: unseen=0.0001 , seen=0.1532 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 177000 loss tensor(0.9024, device='cuda:0')
# episode: 178000 loss tensor(0.9046, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2834576014153924
# gzsl: unseen=0.0001 , seen=0.1545 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 179000 loss tensor(0.9182, device='cuda:0')
# episode: 180000 loss tensor(0.9130, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2844685959812966
# gzsl: unseen=0.0001 , seen=0.1571 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 181000 loss tensor(0.9212, device='cuda:0')
# episode: 182000 loss tensor(0.9018, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.28408947301908255
# gzsl: unseen=0.0001 , seen=0.1605 , h=0.0003
# ____________________________________________________________________________________________________
# episode: 183000 loss tensor(0.9057, device='cuda:0')
# episode: 184000 loss tensor(0.8893, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2832048527739163
# gzsl: unseen=0.0003 , seen=0.1629 , h=0.0005
# ____________________________________________________________________________________________________
# episode: 185000 loss tensor(0.9352, device='cuda:0')
# episode: 186000 loss tensor(0.9117, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2834576014153924
# gzsl: unseen=0.0004 , seen=0.1670 , h=0.0008
# ____________________________________________________________________________________________________
# episode: 187000 loss tensor(0.9085, device='cuda:0')
# episode: 188000 loss tensor(0.9145, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.28130923796284596
# gzsl: unseen=0.0005 , seen=0.1695 , h=0.0010
# ____________________________________________________________________________________________________
# episode: 189000 loss tensor(0.9124, device='cuda:0')
# episode: 190000 loss tensor(0.8996, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.28080374067989383
# gzsl: unseen=0.0008 , seen=0.1722 , h=0.0015
# ____________________________________________________________________________________________________
# episode: 191000 loss tensor(0.8956, device='cuda:0')
# episode: 192000 loss tensor(0.9188, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.27979274611398963
# gzsl: unseen=0.0008 , seen=0.1726 , h=0.0015
# ____________________________________________________________________________________________________
# episode: 193000 loss tensor(0.9052, device='cuda:0')
# episode: 194000 loss tensor(0.8983, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2772652596992291
# gzsl: unseen=0.0008 , seen=0.1749 , h=0.0015
# ____________________________________________________________________________________________________
# episode: 195000 loss tensor(0.8887, device='cuda:0')
# episode: 196000 loss tensor(0.8965, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2747377732844686
# gzsl: unseen=0.0010 , seen=0.1756 , h=0.0020
# ____________________________________________________________________________________________________
# episode: 197000 loss tensor(0.9176, device='cuda:0')
# episode: 198000 loss tensor(0.9060, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2710729179830658
# gzsl: unseen=0.0013 , seen=0.1772 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 199000 loss tensor(0.9086, device='cuda:0')
# episode: 200000 loss tensor(0.9044, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2655124478705927
# gzsl: unseen=0.0013 , seen=0.1768 , h=0.0025
# ____________________________________________________________________________________________________
# episode: 201000 loss tensor(0.9008, device='cuda:0')
# episode: 202000 loss tensor(0.8989, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26298496145583217
# gzsl: unseen=0.0016 , seen=0.1768 , h=0.0033
# ____________________________________________________________________________________________________
# episode: 203000 loss tensor(0.9078, device='cuda:0')
# episode: 204000 loss tensor(0.8967, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2617212182484519
# gzsl: unseen=0.0018 , seen=0.1792 , h=0.0035
# ____________________________________________________________________________________________________
# episode: 205000 loss tensor(0.9169, device='cuda:0')
# episode: 206000 loss tensor(0.9113, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2596992291166435
# gzsl: unseen=0.0019 , seen=0.1794 , h=0.0038
# ____________________________________________________________________________________________________
# episode: 207000 loss tensor(0.9185, device='cuda:0')
# episode: 208000 loss tensor(0.9056, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2576772399848351
# gzsl: unseen=0.0025 , seen=0.1782 , h=0.0050
# ____________________________________________________________________________________________________
# episode: 209000 loss tensor(0.9068, device='cuda:0')
# episode: 210000 loss tensor(0.9052, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2555288765322886
# gzsl: unseen=0.0025 , seen=0.1783 , h=0.0050
# ____________________________________________________________________________________________________
# episode: 211000 loss tensor(0.9022, device='cuda:0')
# episode: 212000 loss tensor(0.9166, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2537596360419563
# gzsl: unseen=0.0027 , seen=0.1787 , h=0.0052
# ____________________________________________________________________________________________________
# episode: 213000 loss tensor(0.8981, device='cuda:0')
# episode: 214000 loss tensor(0.8982, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2533805130797422
# gzsl: unseen=0.0028 , seen=0.1778 , h=0.0055
# ____________________________________________________________________________________________________
# episode: 215000 loss tensor(0.9080, device='cuda:0')
# episode: 216000 loss tensor(0.8980, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25224314419309996
# gzsl: unseen=0.0028 , seen=0.1773 , h=0.0055
# ____________________________________________________________________________________________________
# episode: 217000 loss tensor(0.8964, device='cuda:0')
# episode: 218000 loss tensor(0.9095, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2494629091368634
# gzsl: unseen=0.0030 , seen=0.1758 , h=0.0060
# ____________________________________________________________________________________________________
# episode: 219000 loss tensor(0.9028, device='cuda:0')
# episode: 220000 loss tensor(0.9023, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.247567294325793
# gzsl: unseen=0.0034 , seen=0.1751 , h=0.0067
# ____________________________________________________________________________________________________
# episode: 221000 loss tensor(0.9094, device='cuda:0')
# episode: 222000 loss tensor(0.9067, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2460508024769367
# gzsl: unseen=0.0035 , seen=0.1739 , h=0.0069
# ____________________________________________________________________________________________________
# episode: 223000 loss tensor(0.8887, device='cuda:0')
# episode: 224000 loss tensor(0.9075, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24390243902439024
# gzsl: unseen=0.0035 , seen=0.1734 , h=0.0069
# ____________________________________________________________________________________________________
# episode: 225000 loss tensor(0.9056, device='cuda:0')
# episode: 226000 loss tensor(0.9070, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24314419309996207
# gzsl: unseen=0.0035 , seen=0.1726 , h=0.0069
# ____________________________________________________________________________________________________
# episode: 227000 loss tensor(0.8996, device='cuda:0')
# episode: 228000 loss tensor(0.8983, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.24162770125110578
# gzsl: unseen=0.0038 , seen=0.1717 , h=0.0074
# ____________________________________________________________________________________________________
# episode: 229000 loss tensor(0.8951, device='cuda:0')
# episode: 230000 loss tensor(0.9030, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23973208644003538
# gzsl: unseen=0.0038 , seen=0.1707 , h=0.0074
# ____________________________________________________________________________________________________
# episode: 231000 loss tensor(0.8894, device='cuda:0')
# episode: 232000 loss tensor(0.9096, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23758372298748895
# gzsl: unseen=0.0039 , seen=0.1690 , h=0.0077
# ____________________________________________________________________________________________________
# episode: 233000 loss tensor(0.9180, device='cuda:0')
# episode: 234000 loss tensor(0.8990, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23682547706306079
# gzsl: unseen=0.0039 , seen=0.1685 , h=0.0077
# ____________________________________________________________________________________________________
# episode: 235000 loss tensor(0.9012, device='cuda:0')
# episode: 236000 loss tensor(0.9054, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23657272842158472
# gzsl: unseen=0.0039 , seen=0.1673 , h=0.0077
# ____________________________________________________________________________________________________
# episode: 237000 loss tensor(0.8958, device='cuda:0')
# episode: 238000 loss tensor(0.9074, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23568810817641855
# gzsl: unseen=0.0039 , seen=0.1654 , h=0.0077
# ____________________________________________________________________________________________________
# episode: 239000 loss tensor(0.9031, device='cuda:0')
# episode: 240000 loss tensor(0.8846, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2349298622519904
# gzsl: unseen=0.0039 , seen=0.1651 , h=0.0077
# ____________________________________________________________________________________________________
# episode: 241000 loss tensor(0.8943, device='cuda:0')
# episode: 242000 loss tensor(0.9013, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23467711361051435
# gzsl: unseen=0.0039 , seen=0.1639 , h=0.0077
# ____________________________________________________________________________________________________
# episode: 243000 loss tensor(0.8912, device='cuda:0')
# episode: 244000 loss tensor(0.8971, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2349298622519904
# gzsl: unseen=0.0040 , seen=0.1627 , h=0.0079
# ____________________________________________________________________________________________________
# episode: 245000 loss tensor(0.8900, device='cuda:0')
# episode: 246000 loss tensor(0.9146, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23530898521420449
# gzsl: unseen=0.0043 , seen=0.1617 , h=0.0084
# ____________________________________________________________________________________________________
# episode: 247000 loss tensor(0.9062, device='cuda:0')
# episode: 248000 loss tensor(0.8985, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23480348793125236
# gzsl: unseen=0.0044 , seen=0.1618 , h=0.0086
# ____________________________________________________________________________________________________
# episode: 249000 loss tensor(0.9003, device='cuda:0')
# episode: 250000 loss tensor(0.8960, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23404524200682422
# gzsl: unseen=0.0047 , seen=0.1618 , h=0.0091
# ____________________________________________________________________________________________________
# episode: 251000 loss tensor(0.8853, device='cuda:0')
# episode: 252000 loss tensor(0.9054, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23177050423353973
# gzsl: unseen=0.0048 , seen=0.1612 , h=0.0093
# ____________________________________________________________________________________________________
# episode: 253000 loss tensor(0.9039, device='cuda:0')
# episode: 254000 loss tensor(0.9021, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23227600151649186
# gzsl: unseen=0.0049 , seen=0.1600 , h=0.0096
# ____________________________________________________________________________________________________
# episode: 255000 loss tensor(0.8995, device='cuda:0')
# episode: 256000 loss tensor(0.9033, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23075950966763553
# gzsl: unseen=0.0053 , seen=0.1600 , h=0.0103
# ____________________________________________________________________________________________________
# episode: 257000 loss tensor(0.9153, device='cuda:0')
# episode: 258000 loss tensor(0.9037, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2310122583091116
# gzsl: unseen=0.0056 , seen=0.1600 , h=0.0107
# ____________________________________________________________________________________________________
# episode: 259000 loss tensor(0.8994, device='cuda:0')
# episode: 260000 loss tensor(0.8971, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2306331353468975
# gzsl: unseen=0.0057 , seen=0.1605 , h=0.0110
# ____________________________________________________________________________________________________
# episode: 261000 loss tensor(0.9125, device='cuda:0')
# episode: 262000 loss tensor(0.8787, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.22886389485656514
# gzsl: unseen=0.0057 , seen=0.1600 , h=0.0110
# ____________________________________________________________________________________________________
# episode: 263000 loss tensor(0.8902, device='cuda:0')
# episode: 264000 loss tensor(0.8958, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2277265259699229
# gzsl: unseen=0.0059 , seen=0.1600 , h=0.0115
# ____________________________________________________________________________________________________
# episode: 265000 loss tensor(0.8855, device='cuda:0')
# episode: 266000 loss tensor(0.8993, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.22797927461139897
# gzsl: unseen=0.0062 , seen=0.1598 , h=0.0119
# ____________________________________________________________________________________________________
# episode: 267000 loss tensor(0.8904, device='cuda:0')
# episode: 268000 loss tensor(0.9085, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.228232023252875
# gzsl: unseen=0.0066 , seen=0.1601 , h=0.0126
# ____________________________________________________________________________________________________
# episode: 269000 loss tensor(0.8835, device='cuda:0')
# episode: 270000 loss tensor(0.9145, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.22936939213951724
# gzsl: unseen=0.0067 , seen=0.1601 , h=0.0129
# ____________________________________________________________________________________________________
# episode: 271000 loss tensor(0.9038, device='cuda:0')
# episode: 272000 loss tensor(0.9012, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.22949576646025527
# gzsl: unseen=0.0067 , seen=0.1596 , h=0.0129
# ____________________________________________________________________________________________________
# episode: 273000 loss tensor(0.8924, device='cuda:0')
# episode: 274000 loss tensor(0.8913, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2296221407809933
# gzsl: unseen=0.0073 , seen=0.1593 , h=0.0140
# ____________________________________________________________________________________________________
# episode: 275000 loss tensor(0.8725, device='cuda:0')
# episode: 276000 loss tensor(0.8862, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2296221407809933
# gzsl: unseen=0.0075 , seen=0.1588 , h=0.0142
# ____________________________________________________________________________________________________
# episode: 277000 loss tensor(0.8912, device='cuda:0')
# episode: 278000 loss tensor(0.8893, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23000126374320737
# gzsl: unseen=0.0075 , seen=0.1590 , h=0.0142
# ____________________________________________________________________________________________________
# episode: 279000 loss tensor(0.8899, device='cuda:0')
# episode: 280000 loss tensor(0.8767, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2310122583091116
# gzsl: unseen=0.0080 , seen=0.1584 , h=0.0152
# ____________________________________________________________________________________________________
# episode: 281000 loss tensor(0.8774, device='cuda:0')
# episode: 282000 loss tensor(0.8932, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23038038670542146
# gzsl: unseen=0.0081 , seen=0.1566 , h=0.0154
# ____________________________________________________________________________________________________
# episode: 283000 loss tensor(0.8776, device='cuda:0')
# episode: 284000 loss tensor(0.8789, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23075950966763553
# gzsl: unseen=0.0085 , seen=0.1557 , h=0.0161
# ____________________________________________________________________________________________________
# episode: 285000 loss tensor(0.8984, device='cuda:0')
# episode: 286000 loss tensor(0.8865, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2306331353468975
# gzsl: unseen=0.0088 , seen=0.1547 , h=0.0167
# ____________________________________________________________________________________________________
# episode: 287000 loss tensor(0.8923, device='cuda:0')
# episode: 288000 loss tensor(0.8973, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23038038670542146
# gzsl: unseen=0.0092 , seen=0.1545 , h=0.0174
# ____________________________________________________________________________________________________
# episode: 289000 loss tensor(0.8775, device='cuda:0')
# episode: 290000 loss tensor(0.8756, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.23025401238468343
# gzsl: unseen=0.0095 , seen=0.1556 , h=0.0179
# ____________________________________________________________________________________________________
# episode: 291000 loss tensor(0.8880, device='cuda:0')
# episode: 292000 loss tensor(0.8765, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2305067610261595
# gzsl: unseen=0.0099 , seen=0.1557 , h=0.0185
# ____________________________________________________________________________________________________
# ...
# zsl: 0.25957285479590547
# gzsl: unseen=0.0274 , seen=0.1654 , h=0.0470
# ____________________________________________________________________________________________________
# episode: 405000 loss tensor(0.8840, device='cuda:0')
# episode: 406000 loss tensor(0.8800, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2593201061544294
# gzsl: unseen=0.0278 , seen=0.1651 , h=0.0476
# ____________________________________________________________________________________________________
# episode: 407000 loss tensor(0.8759, device='cuda:0')
# episode: 408000 loss tensor(0.9090, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25944648047516744
# gzsl: unseen=0.0281 , seen=0.1658 , h=0.0480
# ____________________________________________________________________________________________________
# episode: 409000 loss tensor(0.8608, device='cuda:0')
# episode: 410000 loss tensor(0.8659, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25894098319221537
# gzsl: unseen=0.0286 , seen=0.1661 , h=0.0487
# ____________________________________________________________________________________________________
# episode: 411000 loss tensor(0.8710, device='cuda:0')
# episode: 412000 loss tensor(0.8934, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2591937318336914
# gzsl: unseen=0.0288 , seen=0.1666 , h=0.0491
# ____________________________________________________________________________________________________
# episode: 413000 loss tensor(0.8794, device='cuda:0')
# episode: 414000 loss tensor(0.8555, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25944648047516744
# gzsl: unseen=0.0293 , seen=0.1670 , h=0.0499
# ____________________________________________________________________________________________________
# episode: 415000 loss tensor(0.8589, device='cuda:0')
# episode: 416000 loss tensor(0.8671, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.25982560343738154
# gzsl: unseen=0.0296 , seen=0.1668 , h=0.0502
# ____________________________________________________________________________________________________
# episode: 417000 loss tensor(0.8781, device='cuda:0')
# episode: 418000 loss tensor(0.8527, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2600783520788576
# gzsl: unseen=0.0296 , seen=0.1671 , h=0.0503
# ____________________________________________________________________________________________________
# episode: 419000 loss tensor(0.8809, device='cuda:0')
# episode: 420000 loss tensor(0.8667, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2600783520788576
# gzsl: unseen=0.0301 , seen=0.1673 , h=0.0510
# ____________________________________________________________________________________________________
# episode: 421000 loss tensor(0.8755, device='cuda:0')
# episode: 422000 loss tensor(0.8971, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26045747504107164
# gzsl: unseen=0.0302 , seen=0.1676 , h=0.0512
# ____________________________________________________________________________________________________
# episode: 423000 loss tensor(0.8636, device='cuda:0')
# episode: 424000 loss tensor(0.8658, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2607102236825477
# gzsl: unseen=0.0303 , seen=0.1680 , h=0.0514
# ____________________________________________________________________________________________________
# episode: 425000 loss tensor(0.8773, device='cuda:0')
# episode: 426000 loss tensor(0.8770, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26083659800328574
# gzsl: unseen=0.0305 , seen=0.1685 , h=0.0516
# ____________________________________________________________________________________________________
# episode: 427000 loss tensor(0.8693, device='cuda:0')
# episode: 428000 loss tensor(0.8837, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2607102236825477
# gzsl: unseen=0.0307 , seen=0.1688 , h=0.0520
# ____________________________________________________________________________________________________
# episode: 429000 loss tensor(0.8800, device='cuda:0')
# episode: 430000 loss tensor(0.8575, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26058384936180967
# gzsl: unseen=0.0306 , seen=0.1688 , h=0.0518
# ____________________________________________________________________________________________________
# episode: 431000 loss tensor(0.8703, device='cuda:0')
# episode: 432000 loss tensor(0.8627, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2607102236825477
# gzsl: unseen=0.0310 , seen=0.1688 , h=0.0523
# ____________________________________________________________________________________________________
# episode: 433000 loss tensor(0.8859, device='cuda:0')
# episode: 434000 loss tensor(0.8630, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2607102236825477
# gzsl: unseen=0.0310 , seen=0.1692 , h=0.0523
# ____________________________________________________________________________________________________
# episode: 435000 loss tensor(0.8735, device='cuda:0')
# episode: 436000 loss tensor(0.8441, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26184759256918994
# gzsl: unseen=0.0312 , seen=0.1695 , h=0.0527
# ____________________________________________________________________________________________________
# episode: 437000 loss tensor(0.8629, device='cuda:0')
# episode: 438000 loss tensor(0.8831, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26184759256918994
# gzsl: unseen=0.0312 , seen=0.1695 , h=0.0527
# ____________________________________________________________________________________________________
# episode: 439000 loss tensor(0.8707, device='cuda:0')
# episode: 440000 loss tensor(0.8653, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26184759256918994
# gzsl: unseen=0.0315 , seen=0.1695 , h=0.0531
# ____________________________________________________________________________________________________
# episode: 441000 loss tensor(0.8808, device='cuda:0')
# episode: 442000 loss tensor(0.8837, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26197396688992797
# gzsl: unseen=0.0315 , seen=0.1702 , h=0.0531
# ____________________________________________________________________________________________________
# episode: 443000 loss tensor(0.8762, device='cuda:0')
# episode: 444000 loss tensor(0.8586, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26222671553140403
# gzsl: unseen=0.0315 , seen=0.1702 , h=0.0531
# ____________________________________________________________________________________________________
# episode: 445000 loss tensor(0.8561, device='cuda:0')
# episode: 446000 loss tensor(0.8658, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26222671553140403
# gzsl: unseen=0.0315 , seen=0.1709 , h=0.0531
# ____________________________________________________________________________________________________
# episode: 447000 loss tensor(0.8858, device='cuda:0')
# episode: 448000 loss tensor(0.8552, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26285858713509413
# gzsl: unseen=0.0316 , seen=0.1709 , h=0.0533
# ____________________________________________________________________________________________________
# episode: 449000 loss tensor(0.8848, device='cuda:0')
# episode: 450000 loss tensor(0.8738, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26323771009730823
# gzsl: unseen=0.0316 , seen=0.1714 , h=0.0534
# ____________________________________________________________________________________________________
# episode: 451000 loss tensor(0.8676, device='cuda:0')
# episode: 452000 loss tensor(0.8849, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26323771009730823
# gzsl: unseen=0.0318 , seen=0.1724 , h=0.0538
# ____________________________________________________________________________________________________
# episode: 453000 loss tensor(0.8817, device='cuda:0')
# episode: 454000 loss tensor(0.8749, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26386958170099833
# gzsl: unseen=0.0318 , seen=0.1721 , h=0.0537
# ____________________________________________________________________________________________________
# episode: 455000 loss tensor(0.8717, device='cuda:0')
# episode: 456000 loss tensor(0.8464, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26399595602173637
# gzsl: unseen=0.0321 , seen=0.1734 , h=0.0542
# ____________________________________________________________________________________________________
# episode: 457000 loss tensor(0.8722, device='cuda:0')
# episode: 458000 loss tensor(0.8707, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2641223303424744
# gzsl: unseen=0.0321 , seen=0.1739 , h=0.0542
# ____________________________________________________________________________________________________
# episode: 459000 loss tensor(0.8697, device='cuda:0')
# episode: 460000 loss tensor(0.8751, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26424870466321243
# gzsl: unseen=0.0321 , seen=0.1743 , h=0.0542
# ____________________________________________________________________________________________________
# episode: 461000 loss tensor(0.8732, device='cuda:0')
# episode: 462000 loss tensor(0.8872, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2646278276254265
# gzsl: unseen=0.0321 , seen=0.1748 , h=0.0542
# ____________________________________________________________________________________________________
# episode: 463000 loss tensor(0.8767, device='cuda:0')
# episode: 464000 loss tensor(0.8688, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2648805762669026
# gzsl: unseen=0.0322 , seen=0.1753 , h=0.0544
# ____________________________________________________________________________________________________
# episode: 465000 loss tensor(0.8632, device='cuda:0')
# episode: 466000 loss tensor(0.8675, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26538607354985466
# gzsl: unseen=0.0324 , seen=0.1753 , h=0.0546
# ____________________________________________________________________________________________________
# episode: 467000 loss tensor(0.8767, device='cuda:0')
# episode: 468000 loss tensor(0.8664, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26525969922911663
# gzsl: unseen=0.0326 , seen=0.1761 , h=0.0550
# ____________________________________________________________________________________________________
# episode: 469000 loss tensor(0.9029, device='cuda:0')
# episode: 470000 loss tensor(0.8665, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2656388221913307
# gzsl: unseen=0.0326 , seen=0.1765 , h=0.0550
# ____________________________________________________________________________________________________
# episode: 471000 loss tensor(0.8540, device='cuda:0')
# episode: 472000 loss tensor(0.8959, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26576519651206876
# gzsl: unseen=0.0326 , seen=0.1768 , h=0.0551
# ____________________________________________________________________________________________________
# episode: 473000 loss tensor(0.8774, device='cuda:0')
# episode: 474000 loss tensor(0.8667, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26614431947428285
# gzsl: unseen=0.0329 , seen=0.1777 , h=0.0555
# ____________________________________________________________________________________________________
# episode: 475000 loss tensor(0.8617, device='cuda:0')
# episode: 476000 loss tensor(0.8793, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26627069379502083
# gzsl: unseen=0.0329 , seen=0.1778 , h=0.0555
# ____________________________________________________________________________________________________
# episode: 477000 loss tensor(0.8716, device='cuda:0')
# episode: 478000 loss tensor(0.8614, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26639706811575886
# gzsl: unseen=0.0330 , seen=0.1785 , h=0.0557
# ____________________________________________________________________________________________________
# episode: 479000 loss tensor(0.8790, device='cuda:0')
# episode: 480000 loss tensor(0.8524, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2666498167572349
# gzsl: unseen=0.0331 , seen=0.1792 , h=0.0559
# ____________________________________________________________________________________________________
# episode: 481000 loss tensor(0.8560, device='cuda:0')
# episode: 482000 loss tensor(0.8734, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.266902565398711
# gzsl: unseen=0.0332 , seen=0.1794 , h=0.0561
# ____________________________________________________________________________________________________
# episode: 483000 loss tensor(0.8639, device='cuda:0')
# episode: 484000 loss tensor(0.8675, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26715531404018705
# gzsl: unseen=0.0334 , seen=0.1800 , h=0.0563
# ____________________________________________________________________________________________________
# episode: 485000 loss tensor(0.8679, device='cuda:0')
# episode: 486000 loss tensor(0.8718, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.267028939719449
# gzsl: unseen=0.0337 , seen=0.1802 , h=0.0568
# ____________________________________________________________________________________________________
# episode: 487000 loss tensor(0.8506, device='cuda:0')
# episode: 488000 loss tensor(0.8720, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26715531404018705
# gzsl: unseen=0.0339 , seen=0.1809 , h=0.0571
# ____________________________________________________________________________________________________
# episode: 489000 loss tensor(0.8726, device='cuda:0')
# episode: 490000 loss tensor(0.8905, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2675344370024011
# gzsl: unseen=0.0341 , seen=0.1814 , h=0.0574
# ____________________________________________________________________________________________________
# episode: 491000 loss tensor(0.8721, device='cuda:0')
# episode: 492000 loss tensor(0.8688, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26778718564387716
# gzsl: unseen=0.0341 , seen=0.1812 , h=0.0574
# ____________________________________________________________________________________________________
# episode: 493000 loss tensor(0.8685, device='cuda:0')
# episode: 494000 loss tensor(0.8789, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.26816630860609125
# gzsl: unseen=0.0350 , seen=0.1816 , h=0.0587
# ____________________________________________________________________________________________________
# episode: 495000 loss tensor(0.8734, device='cuda:0')
# episode: 496000 loss tensor(0.8728, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2682926829268293
# gzsl: unseen=0.0351 , seen=0.1821 , h=0.0589
# ____________________________________________________________________________________________________
# episode: 497000 loss tensor(0.8536, device='cuda:0')
# episode: 498000 loss tensor(0.8753, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2685454315683053
# gzsl: unseen=0.0354 , seen=0.1828 , h=0.0593
# ____________________________________________________________________________________________________
# episode: 499000 loss tensor(0.8713, device='cuda:0')
# episode: 500000 loss tensor(0.8694, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.2689245545305194
# gzsl: unseen=0.0356 , seen=0.1840 , h=0.0597
# ____________________________________________________________________________________________________
