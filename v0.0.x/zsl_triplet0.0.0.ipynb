# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os

# %%
BATCH_SIZE = 128
EPISODE = 100000
TEST_EPISODE = 1000
LEARNING_RATE =1e-2 
Weight_Decay=1e-3
GPU = 0
Margin = 0.5

# %%
print("init dataset")
##################################参数##################################################################
dataroot = '../data'
dataset = 'AwA1_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'original_att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个

########################add negative pairs#######################
#x_negative = np.empty_like(x)
#x_negative_label = np.empty_like(train_label)
#print(x.shape[0])

#for i in range(x.shape[0]):
#    pick=np.random.choice(np.where(train_label[i]!=train_id)[0], replace=True)
#    x_negative[i] = x[pick]
#    x_negative_label[i] = train_label[pick]
    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
#train_negative_label = torch.from_numpy(x_negative_label).unsqueeze(1)
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
#print(all_attributes)
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net import AttributeNetwork
from my_net import TripletNetwork

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(85,1024,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
triplet_network = TripletNetwork(attribute_network)  #metric learning   
triplet_network.cuda(GPU)   
#attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
#优化器adam 学习率 正则1e-5

#attribute_network_scheduler = StepLR(attribute_network_optim, step_size=200000, gamma=0.5)
#学习率每200k步 乘0.5
#triplet_network_optim = torch.optim.Adam(triplet_network.parameters(), lr=LEARNING_RATE)
#
triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE, 
                                        momentum=0.5, weight_decay= Weight_Decay)

triplet_network_scheduler = StepLR(triplet_network_optim , step_size=100000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = Variable(batch_features_ext).cuda(GPU).float()  # 32*1024

        #print(batch_features_ext)

        sample_features = attribute_network(Variable(sample_attributes).cuda(GPU).float())
        sample_features_ext = sample_features.repeat(batch_size, 1)
        #print(sample_features_ext.shape)


        relations = F.pairwise_distance(batch_features_ext, sample_features_ext, 2).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        #print(predict_labels)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
print("training...")
last_accuracy = 0.0
for episode in range(EPISODE):
   
    triplet_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    
    batch_features_negative = np.empty_like(batch_features.numpy())
    
    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_labels.numpy()]).squeeze(1)
    
    batch_features = Variable(batch_features).cuda(GPU).float()  # 32*2048
    
    for i in range(batch_features_negative.shape[0]):
        pick=np.random.choice(np.where(batch_labels.numpy()[i]!=train_id)[0], replace=True)
        batch_features_negative[i] = x[pick]    
    
    batch_features_negative = torch.from_numpy(batch_features_negative)
    batch_features_negative = Variable(batch_features_negative).cuda(GPU).float()  # 32*2048
    
    #batch_attributes = attribute_network(Variable(batch_attributes).cuda(GPU))
    batch_attributes = Variable(batch_attributes).cuda(GPU)
    
    dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(batch_attributes, batch_features, batch_features_negative)
    
    criterion = nn.MarginRankingLoss(margin = Margin).cuda(GPU)
    
    target = torch.FloatTensor(dista.size()).fill_(-1).cuda(GPU)
    
    
    loss_triplet= criterion(dista, distb, target)
    loss_embedd = embedded_x.norm(2) + embedded_y.norm(2) + embedded_z.norm(2)
    loss = loss_triplet #+ Nom * loss_embedd

    # update
    triplet_network.zero_grad()
    loss.backward()
    triplet_network_optim.step()
    
    if (episode+1)%1000 == 0:
        print("episode:", episode+1, "loss", loss.data)
    if (episode+1)%2000 == 0:
        print("Testing...")
        zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(50), attributes)
        gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(50), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        print('zsl:', zsl_accuracy)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        print('_'*100)
# Out:
# training...
# episode: 1000 loss tensor(1.0023, device='cuda:0')
# episode: 2000 loss tensor(1.1763, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.4872471416007036
# gzsl: unseen=0.2016 , seen=0.5894 , h=0.3004
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(1.0565, device='cuda:0')
# episode: 4000 loss tensor(0.6776, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5095866314863676
# gzsl: unseen=0.2406 , seen=0.6055 , h=0.3444
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(1.0104, device='cuda:0')
# episode: 6000 loss tensor(0.6993, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5189094107299912
# gzsl: unseen=0.2735 , seen=0.6109 , h=0.3779
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(0.6769, device='cuda:0')
# episode: 8000 loss tensor(1.0283, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5234828496042216
# gzsl: unseen=0.2515 , seen=0.6257 , h=0.3588
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(0.8697, device='cuda:0')
# episode: 10000 loss tensor(0.6618, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5234828496042216
# gzsl: unseen=0.2628 , seen=0.6184 , h=0.3688
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(0.7184, device='cuda:0')
# episode: 12000 loss tensor(0.8220, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5414248021108179
# gzsl: unseen=0.2725 , seen=0.6220 , h=0.3789
# ____________________________________________________________________________________________________
# episode: 13000 loss tensor(0.8039, device='cuda:0')
# episode: 14000 loss tensor(1.0627, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5417766051011433
# gzsl: unseen=0.2712 , seen=0.6172 , h=0.3769
# ____________________________________________________________________________________________________
# episode: 15000 loss tensor(0.7702, device='cuda:0')
# episode: 16000 loss tensor(0.7465, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.545646437994723
# gzsl: unseen=0.2783 , seen=0.6238 , h=0.3849
# ____________________________________________________________________________________________________
# episode: 17000 loss tensor(0.7751, device='cuda:0')
# episode: 18000 loss tensor(0.9680, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5572559366754617
# gzsl: unseen=0.2929 , seen=0.6186 , h=0.3975
# ____________________________________________________________________________________________________
# episode: 19000 loss tensor(0.5876, device='cuda:0')
# episode: 20000 loss tensor(0.8049, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5648197009674583
# gzsl: unseen=0.2922 , seen=0.6283 , h=0.3989
# ____________________________________________________________________________________________________
# episode: 21000 loss tensor(1.0445, device='cuda:0')
# episode: 22000 loss tensor(0.9300, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5688654353562005
# gzsl: unseen=0.2843 , seen=0.6307 , h=0.3919
# ____________________________________________________________________________________________________
# episode: 23000 loss tensor(1.0956, device='cuda:0')
# episode: 24000 loss tensor(0.7183, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5730870712401055
# gzsl: unseen=0.2857 , seen=0.6329 , h=0.3937
# ____________________________________________________________________________________________________
# episode: 25000 loss tensor(1.2172, device='cuda:0')
# episode: 26000 loss tensor(0.6228, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5639401934916447
# gzsl: unseen=0.2945 , seen=0.6269 , h=0.4007
# ____________________________________________________________________________________________________
# episode: 27000 loss tensor(0.6680, device='cuda:0')
# episode: 28000 loss tensor(0.9319, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5702726473175022
# gzsl: unseen=0.2892 , seen=0.6317 , h=0.3967
# ____________________________________________________________________________________________________
# episode: 29000 loss tensor(0.5564, device='cuda:0')
# episode: 30000 loss tensor(0.4751, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5711521547933157
# gzsl: unseen=0.2969 , seen=0.6315 , h=0.4039
# ____________________________________________________________________________________________________
# episode: 31000 loss tensor(0.7742, device='cuda:0')
# episode: 32000 loss tensor(0.6027, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5704485488126649
# gzsl: unseen=0.2953 , seen=0.6295 , h=0.4020
# ____________________________________________________________________________________________________
# episode: 33000 loss tensor(0.9421, device='cuda:0')
# episode: 34000 loss tensor(0.4724, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5649956024626209
# gzsl: unseen=0.2885 , seen=0.6299 , h=0.3957
# ____________________________________________________________________________________________________
# episode: 35000 loss tensor(0.6432, device='cuda:0')
# episode: 36000 loss tensor(0.9297, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5702726473175022
# gzsl: unseen=0.2962 , seen=0.6313 , h=0.4032
# ____________________________________________________________________________________________________
# episode: 37000 loss tensor(0.9094, device='cuda:0')
# episode: 38000 loss tensor(0.4425, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5824098504837291
# gzsl: unseen=0.3047 , seen=0.6313 , h=0.4110
# ____________________________________________________________________________________________________
# episode: 39000 loss tensor(0.8634, device='cuda:0')
# episode: 40000 loss tensor(0.6240, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5815303430079156
# gzsl: unseen=0.3011 , seen=0.6319 , h=0.4079
# ____________________________________________________________________________________________________
# episode: 41000 loss tensor(1.0870, device='cuda:0')
# episode: 42000 loss tensor(1.0094, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5850483729111697
# gzsl: unseen=0.2945 , seen=0.6335 , h=0.4020
# ____________________________________________________________________________________________________
# episode: 43000 loss tensor(0.7533, device='cuda:0')
# episode: 44000 loss tensor(0.8184, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.581882145998241
# gzsl: unseen=0.3108 , seen=0.6309 , h=0.4165
# ____________________________________________________________________________________________________
# episode: 45000 loss tensor(0.7537, device='cuda:0')
# episode: 46000 loss tensor(0.6721, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5804749340369393
# gzsl: unseen=0.3018 , seen=0.6293 , h=0.4080
# ____________________________________________________________________________________________________
# episode: 47000 loss tensor(0.9830, device='cuda:0')
# episode: 48000 loss tensor(0.8501, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5901495162708883
# gzsl: unseen=0.3196 , seen=0.6265 , h=0.4233
# ____________________________________________________________________________________________________
# episode: 49000 loss tensor(0.7151, device='cuda:0')
# episode: 50000 loss tensor(0.7467, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5852242744063324
# gzsl: unseen=0.3124 , seen=0.6305 , h=0.4178
# ____________________________________________________________________________________________________
# episode: 51000 loss tensor(0.7312, device='cuda:0')
# episode: 52000 loss tensor(0.5572, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.588566402814424
# gzsl: unseen=0.3194 , seen=0.6293 , h=0.4238
# ____________________________________________________________________________________________________
# episode: 53000 loss tensor(0.7086, device='cuda:0')
# episode: 54000 loss tensor(0.6836, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.584344766930519
# gzsl: unseen=0.3150 , seen=0.6259 , h=0.4191
# ____________________________________________________________________________________________________
# episode: 55000 loss tensor(0.4806, device='cuda:0')
# episode: 56000 loss tensor(1.0713, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5787159190853123
# gzsl: unseen=0.3048 , seen=0.6285 , h=0.4105
# ____________________________________________________________________________________________________
# episode: 57000 loss tensor(0.7117, device='cuda:0')
# episode: 58000 loss tensor(0.7341, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5815303430079156
# gzsl: unseen=0.3094 , seen=0.6299 , h=0.4150
# ____________________________________________________________________________________________________
# episode: 59000 loss tensor(0.8986, device='cuda:0')
# episode: 60000 loss tensor(0.8944, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5792436235708004
# gzsl: unseen=0.3108 , seen=0.6301 , h=0.4163
# ____________________________________________________________________________________________________
# episode: 61000 loss tensor(0.6697, device='cuda:0')
# episode: 62000 loss tensor(0.6756, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5693931398416886
# gzsl: unseen=0.3029 , seen=0.6285 , h=0.4088
# ____________________________________________________________________________________________________
# episode: 63000 loss tensor(0.6609, device='cuda:0')
# episode: 64000 loss tensor(0.5517, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5702726473175022
# gzsl: unseen=0.3131 , seen=0.6283 , h=0.4179
# ____________________________________________________________________________________________________
# episode: 65000 loss tensor(0.3495, device='cuda:0')
# episode: 66000 loss tensor(0.7408, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5736147757255937
# gzsl: unseen=0.3080 , seen=0.6295 , h=0.4136
# ____________________________________________________________________________________________________
# episode: 67000 loss tensor(0.9679, device='cuda:0')
# episode: 68000 loss tensor(0.9167, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5727352682497802
# gzsl: unseen=0.3080 , seen=0.6289 , h=0.4135
# ____________________________________________________________________________________________________
# episode: 69000 loss tensor(0.9772, device='cuda:0')
# episode: 70000 loss tensor(0.7779, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5704485488126649
# gzsl: unseen=0.3073 , seen=0.6309 , h=0.4133
# ____________________________________________________________________________________________________
# episode: 71000 loss tensor(0.7653, device='cuda:0')
# episode: 72000 loss tensor(1.0016, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5746701846965699
# gzsl: unseen=0.2997 , seen=0.6315 , h=0.4065
# ____________________________________________________________________________________________________
# episode: 73000 loss tensor(0.5332, device='cuda:0')
# episode: 74000 loss tensor(0.5481, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.569744942832014
# gzsl: unseen=0.2952 , seen=0.6317 , h=0.4023
# ____________________________________________________________________________________________________
# episode: 75000 loss tensor(0.7971, device='cuda:0')
# episode: 76000 loss tensor(0.6723, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5785400175901495
# gzsl: unseen=0.3149 , seen=0.6271 , h=0.4192
# ____________________________________________________________________________________________________
# episode: 77000 loss tensor(0.7477, device='cuda:0')
# episode: 78000 loss tensor(0.3927, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5813544415127528
# gzsl: unseen=0.3066 , seen=0.6309 , h=0.4127
# ____________________________________________________________________________________________________
# episode: 79000 loss tensor(0.9371, device='cuda:0')
# episode: 80000 loss tensor(0.7471, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.586103781882146
# gzsl: unseen=0.3089 , seen=0.6323 , h=0.4150
# ____________________________________________________________________________________________________
# episode: 81000 loss tensor(0.8464, device='cuda:0')
# episode: 82000 loss tensor(0.8592, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5737906772207564
# gzsl: unseen=0.3038 , seen=0.6315 , h=0.4102
# ____________________________________________________________________________________________________
# episode: 83000 loss tensor(0.6221, device='cuda:0')
# episode: 84000 loss tensor(0.8416, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5838170624450307
# gzsl: unseen=0.2985 , seen=0.6345 , h=0.4060
# ____________________________________________________________________________________________________
# episode: 85000 loss tensor(0.7552, device='cuda:0')
# episode: 86000 loss tensor(0.6740, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5820580474934037
# gzsl: unseen=0.3006 , seen=0.6331 , h=0.4077
# ____________________________________________________________________________________________________
# episode: 87000 loss tensor(0.7687, device='cuda:0')
# episode: 88000 loss tensor(0.8320, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.588566402814424
# gzsl: unseen=0.3027 , seen=0.6370 , h=0.4104
# ____________________________________________________________________________________________________
# episode: 89000 loss tensor(0.4757, device='cuda:0')
# episode: 90000 loss tensor(0.8163, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5808267370272647
# gzsl: unseen=0.3047 , seen=0.6341 , h=0.4116
# ____________________________________________________________________________________________________
# episode: 91000 loss tensor(0.5580, device='cuda:0')
# episode: 92000 loss tensor(0.8377, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5848724714160071
# gzsl: unseen=0.2994 , seen=0.6329 , h=0.4065
# ____________________________________________________________________________________________________
# episode: 93000 loss tensor(0.8690, device='cuda:0')
# episode: 94000 loss tensor(0.7285, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5827616534740545
# gzsl: unseen=0.3026 , seen=0.6313 , h=0.4091
# ____________________________________________________________________________________________________
# episode: 95000 loss tensor(0.6299, device='cuda:0')
# episode: 96000 loss tensor(0.5944, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5825857519788918
# gzsl: unseen=0.3071 , seen=0.6309 , h=0.4131
# ____________________________________________________________________________________________________
# episode: 97000 loss tensor(0.5474, device='cuda:0')
# episode: 98000 loss tensor(0.9273, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5832893579595426
# gzsl: unseen=0.3089 , seen=0.6353 , h=0.4157
# ____________________________________________________________________________________________________
# episode: 99000 loss tensor(0.5839, device='cuda:0')
# episode: 100000 loss tensor(0.5830, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5869832893579595
# gzsl: unseen=0.3108 , seen=0.6329 , h=0.4169
# ____________________________________________________________________________________________________
