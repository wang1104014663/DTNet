# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os

# %%
BATCH_SIZE = 64
EPISODE = 500000
TEST_EPISODE = 1000
LEARNING_RATE =1e-2
GPU = 0
Margin = 1

# %%
print("init dataset")
##################################参数##################################################################
dataroot = './data'
dataset = 'SUN_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个

########################add negative pairs#######################
#x_negative = np.empty_like(x)
#x_negative_label = np.empty_like(train_label)
#print(x.shape[0])

#for i in range(x.shape[0]):
#    pick=np.random.choice(np.where(train_label[i]!=train_id)[0], replace=True)
#    x_negative[i] = x[pick]
#    x_negative_label[i] = train_label[pick]
    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
#train_negative_label = torch.from_numpy(x_negative_label).unsqueeze(1)
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
#print(all_attributes)
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net import AttributeNetwork
from my_net import TripletNetwork_cos

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(102,1024,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
triplet_network = TripletNetwork_cos(attribute_network)  #metric learning   
triplet_network.cuda(GPU)   
#attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
#优化器adam 学习率 正则1e-5

#attribute_network_scheduler = StepLR(attribute_network_optim, step_size=200000, gamma=0.5)
#学习率每200k步 乘0.5
#triplet_network_optim = torch.optim.Adam(triplet_network.parameters(), lr=LEARNING_RATE)
#
triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE, momentum=0.5)
triplet_network_scheduler = StepLR(triplet_network_optim , step_size=200000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = Variable(batch_features_ext).cuda(GPU).float()  # 32*1024

        #print(batch_features_ext)

        sample_features = attribute_network(Variable(sample_attributes).cuda(GPU).float())
        sample_features_ext = sample_features.repeat(batch_size, 1)
        #print(sample_features_ext.shape)


        relations = F.cosine_similarity(batch_features_ext, sample_features_ext).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        #print(predict_labels)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
print("training...")
last_accuracy = 0.0
for episode in range(EPISODE):
   
    triplet_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    
    batch_features_negative = np.empty_like(batch_features.numpy())
    
    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_labels.numpy()]).squeeze(1)
    
    batch_features = Variable(batch_features).cuda(GPU).float()  # 32*2048
    
    for i in range(batch_features_negative.shape[0]):
        pick=np.random.choice(np.where(batch_labels.numpy()[i]!=train_id)[0], replace=True)
        batch_features_negative[i] = x[pick]    
    
    batch_features_negative = torch.from_numpy(batch_features_negative)
    batch_features_negative = Variable(batch_features_negative).cuda(GPU).float()  # 32*2048
    
    #batch_attributes = attribute_network(Variable(batch_attributes).cuda(GPU))
    batch_attributes = Variable(batch_attributes).cuda(GPU)
    
    dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(batch_attributes, batch_features, batch_features_negative)
    
    criterion = nn.MarginRankingLoss(margin = Margin).cuda(GPU)
    
    target = torch.FloatTensor(dista.size()).fill_(-1).cuda(GPU)
    
    
    loss_triplet= criterion(dista, distb, target)
    loss_embedd = embedded_x.norm(2) + embedded_y.norm(2) + embedded_z.norm(2)
    loss = loss_triplet #+ 0.001 * loss_embedd

    # update
    triplet_network.zero_grad()
    loss.backward()
    triplet_network_optim.step()
    
    if (episode+1)%1000 == 0:
        print("episode:", episode+1, "loss", loss.data)
    if (episode+1)%2000 == 0:
        print("Testing...")
        zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(717), attributes)
        gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(717), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        print('zsl:', zsl_accuracy)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        print('_'*100)
# Out:
# training...
# episode: 1000 loss tensor(1.0106, device='cuda:0')
# episode: 2000 loss tensor(1.0112, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.022222222222222223
# gzsl: unseen=0.0028 , seen=0.0008 , h=0.0012
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(1.0008, device='cuda:0')
# episode: 4000 loss tensor(0.9945, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.034722222222222224
# gzsl: unseen=0.0021 , seen=0.0016 , h=0.0018
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(1.0070, device='cuda:0')
# episode: 6000 loss tensor(1.0065, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.03958333333333333
# gzsl: unseen=0.0028 , seen=0.0027 , h=0.0027
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(0.9993, device='cuda:0')
# episode: 8000 loss tensor(1.0296, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.044444444444444446
# gzsl: unseen=0.0035 , seen=0.0043 , h=0.0038
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(1.0211, device='cuda:0')
# episode: 10000 loss tensor(0.9961, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.05486111111111111
# gzsl: unseen=0.0035 , seen=0.0062 , h=0.0045
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(1.0286, device='cuda:0')
# episode: 12000 loss tensor(1.0216, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.058333333333333334
# gzsl: unseen=0.0035 , seen=0.0058 , h=0.0043
# ____________________________________________________________________________________________________
# episode: 13000 loss tensor(1.0141, device='cuda:0')
# episode: 14000 loss tensor(1.0092, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06111111111111111
# gzsl: unseen=0.0035 , seen=0.0058 , h=0.0043
# ____________________________________________________________________________________________________
# episode: 15000 loss tensor(0.9828, device='cuda:0')
# episode: 16000 loss tensor(1.0125, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06388888888888888
# gzsl: unseen=0.0035 , seen=0.0066 , h=0.0045
# ____________________________________________________________________________________________________
# episode: 17000 loss tensor(1.0017, device='cuda:0')
# episode: 18000 loss tensor(1.0039, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06666666666666667
# gzsl: unseen=0.0035 , seen=0.0085 , h=0.0049
# ____________________________________________________________________________________________________
# episode: 19000 loss tensor(1.0059, device='cuda:0')
# episode: 20000 loss tensor(0.9989, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.07083333333333333
# gzsl: unseen=0.0042 , seen=0.0093 , h=0.0058
# ____________________________________________________________________________________________________
# episode: 21000 loss tensor(0.9908, device='cuda:0')
# episode: 22000 loss tensor(0.9972, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.07430555555555556
# gzsl: unseen=0.0042 , seen=0.0101 , h=0.0059
# ____________________________________________________________________________________________________
# episode: 23000 loss tensor(0.9940, device='cuda:0')
# episode: 24000 loss tensor(0.9986, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.075
# gzsl: unseen=0.0028 , seen=0.0101 , h=0.0044
# ____________________________________________________________________________________________________
# episode: 25000 loss tensor(0.9944, device='cuda:0')
# episode: 26000 loss tensor(0.9930, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.075
# gzsl: unseen=0.0014 , seen=0.0101 , h=0.0024
# ____________________________________________________________________________________________________
# episode: 27000 loss tensor(1.0059, device='cuda:0')
# episode: 28000 loss tensor(1.0107, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.07569444444444444
# gzsl: unseen=0.0021 , seen=0.0089 , h=0.0034
# ____________________________________________________________________________________________________
# episode: 29000 loss tensor(0.9948, device='cuda:0')
# episode: 30000 loss tensor(0.9989, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.07291666666666667
# gzsl: unseen=0.0021 , seen=0.0089 , h=0.0034
# ____________________________________________________________________________________________________
# episode: 31000 loss tensor(1.0061, device='cuda:0')
# episode: 32000 loss tensor(1.0059, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.075
# gzsl: unseen=0.0021 , seen=0.0112 , h=0.0035
# ____________________________________________________________________________________________________
# episode: 33000 loss tensor(1.0075, device='cuda:0')
# episode: 34000 loss tensor(0.9942, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.07083333333333333
# gzsl: unseen=0.0042 , seen=0.0116 , h=0.0061
# ____________________________________________________________________________________________________
# episode: 35000 loss tensor(0.9766, device='cuda:0')
# episode: 36000 loss tensor(1.0049, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06736111111111111
# gzsl: unseen=0.0056 , seen=0.0112 , h=0.0074
# ____________________________________________________________________________________________________
# episode: 37000 loss tensor(1.0044, device='cuda:0')
# episode: 38000 loss tensor(0.9894, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06666666666666667
# gzsl: unseen=0.0056 , seen=0.0116 , h=0.0075
# ____________________________________________________________________________________________________
# episode: 39000 loss tensor(0.9999, device='cuda:0')
# episode: 40000 loss tensor(1.0048, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06736111111111111
# gzsl: unseen=0.0056 , seen=0.0132 , h=0.0078
# ____________________________________________________________________________________________________
# episode: 41000 loss tensor(0.9947, device='cuda:0')
# episode: 42000 loss tensor(0.9653, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06944444444444445
# gzsl: unseen=0.0049 , seen=0.0120 , h=0.0069
# ____________________________________________________________________________________________________
# episode: 43000 loss tensor(1.0076, device='cuda:0')
# episode: 44000 loss tensor(0.9964, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.07013888888888889
# gzsl: unseen=0.0049 , seen=0.0116 , h=0.0069
# ____________________________________________________________________________________________________
# episode: 45000 loss tensor(1.0047, device='cuda:0')
# episode: 46000 loss tensor(0.9920, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06944444444444445
# gzsl: unseen=0.0042 , seen=0.0112 , h=0.0061
# ____________________________________________________________________________________________________
# episode: 47000 loss tensor(1.0076, device='cuda:0')
# episode: 48000 loss tensor(0.9930, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06805555555555555
# gzsl: unseen=0.0042 , seen=0.0124 , h=0.0062
# ____________________________________________________________________________________________________
# episode: 49000 loss tensor(0.9933, device='cuda:0')
# episode: 50000 loss tensor(0.9943, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.07083333333333333
# gzsl: unseen=0.0042 , seen=0.0124 , h=0.0062
# ____________________________________________________________________________________________________
# episode: 51000 loss tensor(1.0077, device='cuda:0')
# episode: 52000 loss tensor(0.9858, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06805555555555555
# gzsl: unseen=0.0042 , seen=0.0112 , h=0.0061
# ____________________________________________________________________________________________________
# episode: 53000 loss tensor(0.9909, device='cuda:0')
# episode: 54000 loss tensor(0.9913, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06875
# gzsl: unseen=0.0042 , seen=0.0116 , h=0.0061
# ____________________________________________________________________________________________________
# episode: 55000 loss tensor(1.0017, device='cuda:0')
# episode: 56000 loss tensor(0.9728, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06666666666666667
# gzsl: unseen=0.0056 , seen=0.0112 , h=0.0074
# ____________________________________________________________________________________________________
# episode: 57000 loss tensor(0.9732, device='cuda:0')
# episode: 58000 loss tensor(0.9927, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.06527777777777778
# gzsl: unseen=0.0042 , seen=0.0109 , h=0.0060
# ____________________________________________________________________________________________________
# episode: 59000 loss tensor(1.0041, device='cuda:0')
# episode: 60000 loss tensor(0.9948, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.059722222222222225
# gzsl: unseen=0.0042 , seen=0.0105 , h=0.0060
# ____________________________________________________________________________________________________
# episode: 61000 loss tensor(1.0052, device='cuda:0')
# episode: 62000 loss tensor(0.9886, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.059027777777777776
# gzsl: unseen=0.0042 , seen=0.0105 , h=0.0060
# ____________________________________________________________________________________________________
# episode: 63000 loss tensor(0.9650, device='cuda:0')
# episode: 64000 loss tensor(0.9891, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.059722222222222225
# gzsl: unseen=0.0042 , seen=0.0105 , h=0.0060
# ____________________________________________________________________________________________________
# episode: 65000 loss tensor(0.9818, device='cuda:0')
# episode: 66000 loss tensor(0.9800, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.058333333333333334
# gzsl: unseen=0.0049 , seen=0.0101 , h=0.0066
# ____________________________________________________________________________________________________
# episode: 67000 loss tensor(0.9757, device='cuda:0')
# episode: 68000 loss tensor(0.9780, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.05555555555555555
# gzsl: unseen=0.0063 , seen=0.0089 , h=0.0073
# ____________________________________________________________________________________________________
# episode: 69000 loss tensor(0.9654, device='cuda:0')
# episode: 70000 loss tensor(0.9790, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.05277777777777778
# gzsl: unseen=0.0076 , seen=0.0074 , h=0.0075
# ____________________________________________________________________________________________________
# episode: 71000 loss tensor(0.9802, device='cuda:0')
# episode: 72000 loss tensor(0.9765, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.05347222222222222
# gzsl: unseen=0.0063 , seen=0.0066 , h=0.0064
# ____________________________________________________________________________________________________
# episode: 73000 loss tensor(0.9531, device='cuda:0')
# episode: 74000 loss tensor(0.9660, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.05138888888888889
# gzsl: unseen=0.0063 , seen=0.0062 , h=0.0062
# ____________________________________________________________________________________________________
# episode: 75000 loss tensor(0.9892, device='cuda:0')
# episode: 76000 loss tensor(0.9713, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.05347222222222222
# gzsl: unseen=0.0063 , seen=0.0054 , h=0.0058
# ____________________________________________________________________________________________________
# episode: 77000 loss tensor(0.9956, device='cuda:0')
# episode: 78000 loss tensor(0.9805, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.052083333333333336
# gzsl: unseen=0.0063 , seen=0.0054 , h=0.0058
# ____________________________________________________________________________________________________
# episode: 79000 loss tensor(0.9831, device='cuda:0')
# episode: 80000 loss tensor(0.9762, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.05416666666666667
# gzsl: unseen=0.0063 , seen=0.0050 , h=0.0056
# ____________________________________________________________________________________________________
# episode: 81000 loss tensor(0.9755, device='cuda:0')
# episode: 82000 loss tensor(0.9715, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.052083333333333336
# gzsl: unseen=0.0056 , seen=0.0050 , h=0.0053
# ____________________________________________________________________________________________________
# episode: 83000 loss tensor(0.9714, device='cuda:0')
# episode: 84000 loss tensor(0.9714, device='cuda:0')
# Testing...
# class num: 72
# class num: 717
# class num: 717
# zsl: 0.052083333333333336
# gzsl: unseen=0.0056 , seen=0.0050 , h=0.0053
# ____________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2743263528cb> in <module>()
#      33
#      34     loss_triplet= criterion(dista, distb, target)
# ---> 35     loss_embedd = embedded_x.norm(2) + embedded_y.norm(2) + embedded_z.norm(2)
#      36     loss = loss_triplet #+ 0.001 * loss_embedd
#      37
#
# KeyboardInterrupt:
