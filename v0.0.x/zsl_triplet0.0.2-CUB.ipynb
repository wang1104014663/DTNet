# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os

# %%
BATCH_SIZE = 64
EPISODE = 500000
TEST_EPISODE = 1000
LEARNING_RATE =1e-2
GPU = 0
Margin = 1

# %%
print("init dataset")
##################################参数##################################################################
dataroot = './data'
dataset = 'CUB1_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'original_att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个

########################add negative pairs#######################
#x_negative = np.empty_like(x)
#x_negative_label = np.empty_like(train_label)
#print(x.shape[0])

#for i in range(x.shape[0]):
#    pick=np.random.choice(np.where(train_label[i]!=train_id)[0], replace=True)
#    x_negative[i] = x[pick]
#    x_negative_label[i] = train_label[pick]
    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
#train_negative_label = torch.from_numpy(x_negative_label).unsqueeze(1)
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
#print(all_attributes)
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net import AttributeNetwork
from my_net import TripletNetwork_cos

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(312,1200,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
triplet_network = TripletNetwork_cos(attribute_network)  #metric learning   
triplet_network.cuda(GPU)   
#attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
#优化器adam 学习率 正则1e-5

#attribute_network_scheduler = StepLR(attribute_network_optim, step_size=200000, gamma=0.5)
#学习率每200k步 乘0.5
#triplet_network_optim = torch.optim.Adam(triplet_network.parameters(), lr=LEARNING_RATE)
#
triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE, momentum=0.5)
triplet_network_scheduler = StepLR(triplet_network_optim , step_size=200000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = Variable(batch_features_ext).cuda(GPU).float()  # 32*1024

        #print(batch_features_ext)

        sample_features = attribute_network(Variable(sample_attributes).cuda(GPU).float())
        sample_features_ext = sample_features.repeat(batch_size, 1)
        #print(sample_features_ext.shape)


        relations = F.cosine_similarity(batch_features_ext, sample_features_ext).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        #print(predict_labels)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
print("training...")
last_accuracy = 0.0
for episode in range(EPISODE):
   
    triplet_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    
    batch_features_negative = np.empty_like(batch_features.numpy())
    
    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_labels.numpy()]).squeeze(1)
    
    batch_features = Variable(batch_features).cuda(GPU).float()  # 32*2048
    
    for i in range(batch_features_negative.shape[0]):
        pick=np.random.choice(np.where(batch_labels.numpy()[i]!=train_id)[0], replace=True)
        batch_features_negative[i] = x[pick]    
    
    batch_features_negative = torch.from_numpy(batch_features_negative)
    batch_features_negative = Variable(batch_features_negative).cuda(GPU).float()  # 32*2048
    
    #batch_attributes = attribute_network(Variable(batch_attributes).cuda(GPU))
    batch_attributes = Variable(batch_attributes).cuda(GPU)
    
    dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(batch_attributes, batch_features, batch_features_negative)
    
    criterion = nn.MarginRankingLoss(margin = Margin).cuda(GPU)
    
    target = torch.FloatTensor(dista.size()).fill_(-1).cuda(GPU)
    
    
    loss_triplet= criterion(dista, distb, target)
    loss_embedd = embedded_x.norm(2) + embedded_y.norm(2) + embedded_z.norm(2)
    loss = loss_triplet #+ 0.001 * loss_embedd

    # update
    triplet_network.zero_grad()
    loss.backward()
    triplet_network_optim.step()
    
    if (episode+1)%1000 == 0:
        print("episode:", episode+1, "loss", loss.data)
    if (episode+1)%2000 == 0:
        print("Testing...")
        zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(200), attributes)
        gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(200), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        print('zsl:', zsl_accuracy)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        print('_'*100)
# Out:
# training...
# episode: 1000 loss tensor(0.9417, device='cuda:0')
# episode: 2000 loss tensor(0.8979, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.25884732052578363
# gzsl: unseen=0.0516 , seen=0.2098 , h=0.0828
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(0.8762, device='cuda:0')
# episode: 4000 loss tensor(0.8776, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.3232221098752949
# gzsl: unseen=0.0775 , seen=0.2749 , h=0.1209
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(0.8456, device='cuda:0')
# episode: 6000 loss tensor(0.8650, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.3343444556791372
# gzsl: unseen=0.0954 , seen=0.3078 , h=0.1456
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(0.8544, device='cuda:0')
# episode: 8000 loss tensor(0.8447, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.3613077182339063
# gzsl: unseen=0.1021 , seen=0.3328 , h=0.1563
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(0.8701, device='cuda:0')
# episode: 10000 loss tensor(0.8199, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.3751263902932255
# gzsl: unseen=0.1025 , seen=0.3532 , h=0.1588
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(0.8616, device='cuda:0')
# episode: 12000 loss tensor(0.8242, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.38422649140546006
# gzsl: unseen=0.1132 , seen=0.3651 , h=0.1729
# ____________________________________________________________________________________________________
# episode: 13000 loss tensor(0.8493, device='cuda:0')
# episode: 14000 loss tensor(0.8444, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.38658577687900236
# gzsl: unseen=0.1220 , seen=0.3827 , h=0.1850
# ____________________________________________________________________________________________________
# episode: 15000 loss tensor(0.8326, device='cuda:0')
# episode: 16000 loss tensor(0.8345, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.39096730704415233
# gzsl: unseen=0.1163 , seen=0.3781 , h=0.1779
# ____________________________________________________________________________________________________
# episode: 17000 loss tensor(0.8460, device='cuda:0')
# episode: 18000 loss tensor(0.8230, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.38928210313447925
# gzsl: unseen=0.1301 , seen=0.3730 , h=0.1929
# ____________________________________________________________________________________________________
# episode: 19000 loss tensor(0.8271, device='cuda:0')
# episode: 20000 loss tensor(0.8021, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.39568587799123695
# gzsl: unseen=0.1385 , seen=0.3855 , h=0.2038
# ____________________________________________________________________________________________________
# episode: 21000 loss tensor(0.8215, device='cuda:0')
# episode: 22000 loss tensor(0.8503, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.3953488372093023
# gzsl: unseen=0.1564 , seen=0.3804 , h=0.2216
# ____________________________________________________________________________________________________
# episode: 23000 loss tensor(0.8342, device='cuda:0')
# episode: 24000 loss tensor(0.8086, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.39298955173576
# gzsl: unseen=0.1547 , seen=0.3827 , h=0.2203
# ____________________________________________________________________________________________________
# episode: 25000 loss tensor(0.8049, device='cuda:0')
# episode: 26000 loss tensor(0.8275, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.3977081226828446
# gzsl: unseen=0.1591 , seen=0.3906 , h=0.2261
# ____________________________________________________________________________________________________
# episode: 27000 loss tensor(0.8170, device='cuda:0')
# episode: 28000 loss tensor(0.7916, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.40310077519379844
# gzsl: unseen=0.1672 , seen=0.3883 , h=0.2337
# ____________________________________________________________________________________________________
# episode: 29000 loss tensor(0.7995, device='cuda:0')
# episode: 30000 loss tensor(0.8492, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.40310077519379844
# gzsl: unseen=0.1729 , seen=0.3968 , h=0.2409
# ____________________________________________________________________________________________________
# episode: 31000 loss tensor(0.8277, device='cuda:0')
# episode: 32000 loss tensor(0.8126, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41051567239635994
# gzsl: unseen=0.1783 , seen=0.3985 , h=0.2464
# ____________________________________________________________________________________________________
# episode: 33000 loss tensor(0.7999, device='cuda:0')
# episode: 34000 loss tensor(0.7902, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4162453656892484
# gzsl: unseen=0.1958 , seen=0.3923 , h=0.2612
# ____________________________________________________________________________________________________
# episode: 35000 loss tensor(0.8197, device='cuda:0')
# episode: 36000 loss tensor(0.8065, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41287495786990225
# gzsl: unseen=0.2005 , seen=0.3872 , h=0.2642
# ____________________________________________________________________________________________________
# episode: 37000 loss tensor(0.8121, device='cuda:0')
# episode: 38000 loss tensor(0.7759, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41456016177957533
# gzsl: unseen=0.2140 , seen=0.3815 , h=0.2742
# ____________________________________________________________________________________________________
# episode: 39000 loss tensor(0.7945, device='cuda:0')
# episode: 40000 loss tensor(0.8044, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4239973036737445
# gzsl: unseen=0.2349 , seen=0.3934 , h=0.2942
# ____________________________________________________________________________________________________
# episode: 41000 loss tensor(0.8037, device='cuda:0')
# episode: 42000 loss tensor(0.8000, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41927873272665994
# gzsl: unseen=0.2390 , seen=0.3917 , h=0.2968
# ____________________________________________________________________________________________________
# episode: 43000 loss tensor(0.8067, device='cuda:0')
# episode: 44000 loss tensor(0.8061, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4142231209976407
# gzsl: unseen=0.2518 , seen=0.3707 , h=0.2999
# ____________________________________________________________________________________________________
# episode: 45000 loss tensor(0.8198, device='cuda:0')
# episode: 46000 loss tensor(0.7959, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.42433434445567914
# gzsl: unseen=0.2595 , seen=0.3793 , h=0.3082
# ____________________________________________________________________________________________________
# episode: 47000 loss tensor(0.7885, device='cuda:0')
# episode: 48000 loss tensor(0.7875, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.425345466801483
# gzsl: unseen=0.2814 , seen=0.3690 , h=0.3193
# ____________________________________________________________________________________________________
# episode: 49000 loss tensor(0.8026, device='cuda:0')
# episode: 50000 loss tensor(0.8113, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4236602628918099
# gzsl: unseen=0.2747 , seen=0.3707 , h=0.3156
# ____________________________________________________________________________________________________
# episode: 51000 loss tensor(0.7838, device='cuda:0')
# episode: 52000 loss tensor(0.8048, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4320862824401753
# gzsl: unseen=0.2855 , seen=0.3662 , h=0.3208
# ____________________________________________________________________________________________________
# episode: 53000 loss tensor(0.8030, device='cuda:0')
# episode: 54000 loss tensor(0.7752, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4280417930569599
# gzsl: unseen=0.2969 , seen=0.3515 , h=0.3219
# ____________________________________________________________________________________________________
# episode: 55000 loss tensor(0.7945, device='cuda:0')
# episode: 56000 loss tensor(0.8085, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4354566902595214
# gzsl: unseen=0.3077 , seen=0.3481 , h=0.3267
# ____________________________________________________________________________________________________
# episode: 57000 loss tensor(0.7591, device='cuda:0')
# episode: 58000 loss tensor(0.7734, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4334344455679137
# gzsl: unseen=0.3094 , seen=0.3515 , h=0.3291
# ____________________________________________________________________________________________________
# episode: 59000 loss tensor(0.7822, device='cuda:0')
# episode: 60000 loss tensor(0.8154, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43916413886080213
# gzsl: unseen=0.3222 , seen=0.3458 , h=0.3336
# ____________________________________________________________________________________________________
# episode: 61000 loss tensor(0.7679, device='cuda:0')
# episode: 62000 loss tensor(0.7656, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43242332322210986
# gzsl: unseen=0.3222 , seen=0.3396 , h=0.3307
# ____________________________________________________________________________________________________
# episode: 63000 loss tensor(0.7780, device='cuda:0')
# episode: 64000 loss tensor(0.7874, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4395011796427368
# gzsl: unseen=0.3320 , seen=0.3441 , h=0.3379
# ____________________________________________________________________________________________________
# episode: 65000 loss tensor(0.7870, device='cuda:0')
# episode: 66000 loss tensor(0.7663, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43478260869565216
# gzsl: unseen=0.3303 , seen=0.3328 , h=0.3315
# ____________________________________________________________________________________________________
# episode: 67000 loss tensor(0.8067, device='cuda:0')
# episode: 68000 loss tensor(0.7874, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43377148634984836
# gzsl: unseen=0.3320 , seen=0.3401 , h=0.3360
# ____________________________________________________________________________________________________
# episode: 69000 loss tensor(0.7946, device='cuda:0')
# episode: 70000 loss tensor(0.7766, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43410852713178294
# gzsl: unseen=0.3374 , seen=0.3311 , h=0.3342
# ____________________________________________________________________________________________________
# episode: 71000 loss tensor(0.7911, device='cuda:0')
# episode: 72000 loss tensor(0.8105, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4330974047859791
# gzsl: unseen=0.3448 , seen=0.3390 , h=0.3419
# ____________________________________________________________________________________________________
# episode: 73000 loss tensor(0.7895, device='cuda:0')
# episode: 74000 loss tensor(0.7651, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4304010785305022
# gzsl: unseen=0.3431 , seen=0.3288 , h=0.3358
# ____________________________________________________________________________________________________
# episode: 75000 loss tensor(0.8211, device='cuda:0')
# episode: 76000 loss tensor(0.7997, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4344455679137176
# gzsl: unseen=0.3438 , seen=0.3339 , h=0.3388
# ____________________________________________________________________________________________________
# episode: 77000 loss tensor(0.7836, device='cuda:0')
# episode: 78000 loss tensor(0.7821, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4260195483653522
# gzsl: unseen=0.3401 , seen=0.3271 , h=0.3335
# ____________________________________________________________________________________________________
# episode: 79000 loss tensor(0.7843, device='cuda:0')
# episode: 80000 loss tensor(0.8140, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43478260869565216
# gzsl: unseen=0.3492 , seen=0.3288 , h=0.3387
# ____________________________________________________________________________________________________
# episode: 81000 loss tensor(0.8073, device='cuda:0')
# episode: 82000 loss tensor(0.7633, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4351196494775868
# gzsl: unseen=0.3529 , seen=0.3265 , h=0.3392
# ____________________________________________________________________________________________________
# episode: 83000 loss tensor(0.7539, device='cuda:0')
# episode: 84000 loss tensor(0.7779, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.42938995618469833
# gzsl: unseen=0.3502 , seen=0.3203 , h=0.3346
# ____________________________________________________________________________________________________
# episode: 85000 loss tensor(0.7562, device='cuda:0')
# episode: 86000 loss tensor(0.7684, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.427030670711156
# gzsl: unseen=0.3485 , seen=0.3180 , h=0.3326
# ____________________________________________________________________________________________________
# episode: 87000 loss tensor(0.7731, device='cuda:0')
# episode: 88000 loss tensor(0.7902, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4398382204246714
# gzsl: unseen=0.3637 , seen=0.3129 , h=0.3364
# ____________________________________________________________________________________________________
# episode: 89000 loss tensor(0.7905, device='cuda:0')
# episode: 90000 loss tensor(0.7876, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43242332322210986
# gzsl: unseen=0.3569 , seen=0.3180 , h=0.3364
# ____________________________________________________________________________________________________
# episode: 91000 loss tensor(0.7381, device='cuda:0')
# episode: 92000 loss tensor(0.7864, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.42972699696663297
# gzsl: unseen=0.3586 , seen=0.3141 , h=0.3349
# ____________________________________________________________________________________________________
# episode: 93000 loss tensor(0.7742, device='cuda:0')
# episode: 94000 loss tensor(0.7873, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4320862824401753
# gzsl: unseen=0.3654 , seen=0.3056 , h=0.3328
# ____________________________________________________________________________________________________
# episode: 95000 loss tensor(0.7607, device='cuda:0')
# episode: 96000 loss tensor(0.7731, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.42197505898213683
# gzsl: unseen=0.3532 , seen=0.3067 , h=0.3283
# ____________________________________________________________________________________________________
# episode: 97000 loss tensor(0.7769, device='cuda:0')
# episode: 98000 loss tensor(0.7678, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4330974047859791
# gzsl: unseen=0.3643 , seen=0.3022 , h=0.3303
# ____________________________________________________________________________________________________
# episode: 99000 loss tensor(0.7570, device='cuda:0')
# episode: 100000 loss tensor(0.7881, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43242332322210986
# gzsl: unseen=0.3650 , seen=0.3016 , h=0.3303
# ____________________________________________________________________________________________________
# episode: 101000 loss tensor(0.7664, device='cuda:0')
# episode: 102000 loss tensor(0.7902, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4368048533872599
# gzsl: unseen=0.3697 , seen=0.3005 , h=0.3315
# ____________________________________________________________________________________________________
# episode: 103000 loss tensor(0.7788, device='cuda:0')
# episode: 104000 loss tensor(0.7846, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4395011796427368
# gzsl: unseen=0.3758 , seen=0.2868 , h=0.3254
# ____________________________________________________________________________________________________
# episode: 105000 loss tensor(0.7768, device='cuda:0')
# episode: 106000 loss tensor(0.7980, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43646781260532524
# gzsl: unseen=0.3704 , seen=0.3027 , h=0.3332
# ____________________________________________________________________________________________________
# episode: 107000 loss tensor(0.7977, device='cuda:0')
# episode: 108000 loss tensor(0.7826, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43377148634984836
# gzsl: unseen=0.3680 , seen=0.2954 , h=0.3277
# ____________________________________________________________________________________________________
# episode: 109000 loss tensor(0.7615, device='cuda:0')
# episode: 110000 loss tensor(0.7628, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4334344455679137
# gzsl: unseen=0.3694 , seen=0.2931 , h=0.3268
# ____________________________________________________________________________________________________
# episode: 111000 loss tensor(0.7774, device='cuda:0')
# episode: 112000 loss tensor(0.7770, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.440175261206606
# gzsl: unseen=0.3765 , seen=0.3005 , h=0.3342
# ____________________________________________________________________________________________________
# episode: 113000 loss tensor(0.7537, device='cuda:0')
# episode: 114000 loss tensor(0.7806, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44152342433434444
# gzsl: unseen=0.3809 , seen=0.2920 , h=0.3305
# ____________________________________________________________________________________________________
# episode: 115000 loss tensor(0.7830, device='cuda:0')
# episode: 116000 loss tensor(0.7899, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4408493427704752
# gzsl: unseen=0.3876 , seen=0.2897 , h=0.3316
# ____________________________________________________________________________________________________
# episode: 117000 loss tensor(0.8143, device='cuda:0')
# episode: 118000 loss tensor(0.7772, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43882709807886755
# gzsl: unseen=0.3886 , seen=0.2874 , h=0.3304
# ____________________________________________________________________________________________________
# episode: 119000 loss tensor(0.7648, device='cuda:0')
# episode: 120000 loss tensor(0.7908, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44118638355240986
# gzsl: unseen=0.3886 , seen=0.2868 , h=0.3301
# ____________________________________________________________________________________________________
# episode: 121000 loss tensor(0.7713, device='cuda:0')
# episode: 122000 loss tensor(0.7794, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43916413886080213
# gzsl: unseen=0.3883 , seen=0.2891 , h=0.3314
# ____________________________________________________________________________________________________
# episode: 123000 loss tensor(0.7782, device='cuda:0')
# episode: 124000 loss tensor(0.7548, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4344455679137176
# gzsl: unseen=0.3839 , seen=0.2732 , h=0.3193
# ____________________________________________________________________________________________________
# episode: 125000 loss tensor(0.7822, device='cuda:0')
# episode: 126000 loss tensor(0.7752, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44118638355240986
# gzsl: unseen=0.3900 , seen=0.2806 , h=0.3264
# ____________________________________________________________________________________________________
# episode: 127000 loss tensor(0.7978, device='cuda:0')
# episode: 128000 loss tensor(0.7675, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4432086282440175
# gzsl: unseen=0.3906 , seen=0.2840 , h=0.3289
# ____________________________________________________________________________________________________
# episode: 129000 loss tensor(0.7937, device='cuda:0')
# episode: 130000 loss tensor(0.7927, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4418604651162791
# gzsl: unseen=0.3913 , seen=0.2851 , h=0.3299
# ____________________________________________________________________________________________________
# episode: 131000 loss tensor(0.7839, device='cuda:0')
# episode: 132000 loss tensor(0.7696, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4418604651162791
# gzsl: unseen=0.3987 , seen=0.2676 , h=0.3202
# ____________________________________________________________________________________________________
# episode: 133000 loss tensor(0.7759, device='cuda:0')
# episode: 134000 loss tensor(0.7934, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4384900572969329
# gzsl: unseen=0.3916 , seen=0.2783 , h=0.3254
# ____________________________________________________________________________________________________
# episode: 135000 loss tensor(0.7768, device='cuda:0')
# episode: 136000 loss tensor(0.7662, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43916413886080213
# gzsl: unseen=0.3920 , seen=0.2749 , h=0.3232
# ____________________________________________________________________________________________________
# episode: 137000 loss tensor(0.7811, device='cuda:0')
# episode: 138000 loss tensor(0.7605, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4374789349511291
# gzsl: unseen=0.3906 , seen=0.2727 , h=0.3212
# ____________________________________________________________________________________________________
# episode: 139000 loss tensor(0.8133, device='cuda:0')
# episode: 140000 loss tensor(0.7639, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43916413886080213
# gzsl: unseen=0.3957 , seen=0.2761 , h=0.3252
# ____________________________________________________________________________________________________
# episode: 141000 loss tensor(0.7992, device='cuda:0')
# episode: 142000 loss tensor(0.7783, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43646781260532524
# gzsl: unseen=0.3913 , seen=0.2681 , h=0.3182
# ____________________________________________________________________________________________________
# episode: 143000 loss tensor(0.7694, device='cuda:0')
# episode: 144000 loss tensor(0.7712, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44118638355240986
# gzsl: unseen=0.3953 , seen=0.2670 , h=0.3187
# ____________________________________________________________________________________________________
# episode: 145000 loss tensor(0.7564, device='cuda:0')
# episode: 146000 loss tensor(0.7692, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44455679137175597
# gzsl: unseen=0.3994 , seen=0.2795 , h=0.3288
# ____________________________________________________________________________________________________
# episode: 147000 loss tensor(0.8093, device='cuda:0')
# episode: 148000 loss tensor(0.7555, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44287158746208294
# gzsl: unseen=0.4004 , seen=0.2698 , h=0.3224
# ____________________________________________________________________________________________________
# episode: 149000 loss tensor(0.7540, device='cuda:0')
# episode: 150000 loss tensor(0.7912, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4418604651162791
# gzsl: unseen=0.3994 , seen=0.2664 , h=0.3196
# ____________________________________________________________________________________________________
# episode: 151000 loss tensor(0.7528, device='cuda:0')
# episode: 152000 loss tensor(0.7419, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4395011796427368
# gzsl: unseen=0.3994 , seen=0.2687 , h=0.3213
# ____________________________________________________________________________________________________
# episode: 153000 loss tensor(0.7823, device='cuda:0')
# episode: 154000 loss tensor(0.8050, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4408493427704752
# gzsl: unseen=0.4014 , seen=0.2625 , h=0.3174
# ____________________________________________________________________________________________________
# episode: 155000 loss tensor(0.7876, device='cuda:0')
# episode: 156000 loss tensor(0.7724, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4398382204246714
# gzsl: unseen=0.4055 , seen=0.2625 , h=0.3187
# ____________________________________________________________________________________________________
# episode: 157000 loss tensor(0.7610, device='cuda:0')
# episode: 158000 loss tensor(0.7617, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43882709807886755
# gzsl: unseen=0.4028 , seen=0.2647 , h=0.3195
# ____________________________________________________________________________________________________
# episode: 159000 loss tensor(0.7629, device='cuda:0')
# episode: 160000 loss tensor(0.7806, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4398382204246714
# gzsl: unseen=0.3994 , seen=0.2608 , h=0.3155
# ____________________________________________________________________________________________________
# episode: 161000 loss tensor(0.7971, device='cuda:0')
# episode: 162000 loss tensor(0.7767, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4455679137175598
# gzsl: unseen=0.4098 , seen=0.2670 , h=0.3234
# ____________________________________________________________________________________________________
# episode: 163000 loss tensor(0.7705, device='cuda:0')
# episode: 164000 loss tensor(0.7839, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44287158746208294
# gzsl: unseen=0.4078 , seen=0.2664 , h=0.3223
# ____________________________________________________________________________________________________
# episode: 165000 loss tensor(0.7731, device='cuda:0')
# episode: 166000 loss tensor(0.7509, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4418604651162791
# gzsl: unseen=0.4071 , seen=0.2568 , h=0.3150
# ____________________________________________________________________________________________________
# episode: 167000 loss tensor(0.7775, device='cuda:0')
# episode: 168000 loss tensor(0.7903, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4442197505898214
# gzsl: unseen=0.4135 , seen=0.2591 , h=0.3186
# ____________________________________________________________________________________________________
# episode: 169000 loss tensor(0.7823, device='cuda:0')
# episode: 170000 loss tensor(0.7792, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44287158746208294
# gzsl: unseen=0.4068 , seen=0.2568 , h=0.3149
# ____________________________________________________________________________________________________
# episode: 171000 loss tensor(0.7993, device='cuda:0')
# episode: 172000 loss tensor(0.7585, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4472531176272329
# gzsl: unseen=0.4125 , seen=0.2579 , h=0.3174
# ____________________________________________________________________________________________________
# episode: 173000 loss tensor(0.7456, device='cuda:0')
# episode: 174000 loss tensor(0.7803, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44455679137175597
# gzsl: unseen=0.4082 , seen=0.2551 , h=0.3140
# ____________________________________________________________________________________________________
# episode: 175000 loss tensor(0.7968, device='cuda:0')
# episode: 176000 loss tensor(0.7638, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44860128075497135
# gzsl: unseen=0.4119 , seen=0.2574 , h=0.3168
# ____________________________________________________________________________________________________
# episode: 177000 loss tensor(0.7886, device='cuda:0')
# episode: 178000 loss tensor(0.7624, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43646781260532524
# gzsl: unseen=0.4001 , seen=0.2545 , h=0.3111
# ____________________________________________________________________________________________________
# episode: 179000 loss tensor(0.7889, device='cuda:0')
# episode: 180000 loss tensor(0.7698, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4398382204246714
# gzsl: unseen=0.4068 , seen=0.2557 , h=0.3140
# ____________________________________________________________________________________________________
# episode: 181000 loss tensor(0.7640, device='cuda:0')
# episode: 182000 loss tensor(0.7572, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4384900572969329
# gzsl: unseen=0.4075 , seen=0.2489 , h=0.3090
# ____________________________________________________________________________________________________
# episode: 183000 loss tensor(0.7586, device='cuda:0')
# episode: 184000 loss tensor(0.7702, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4442197505898214
# gzsl: unseen=0.4159 , seen=0.2494 , h=0.3118
# ____________________________________________________________________________________________________
# episode: 185000 loss tensor(0.8127, device='cuda:0')
# episode: 186000 loss tensor(0.7786, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43815301651499833
# gzsl: unseen=0.4071 , seen=0.2517 , h=0.3111
# ____________________________________________________________________________________________________
# episode: 187000 loss tensor(0.7911, device='cuda:0')
# episode: 188000 loss tensor(0.7639, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44590495449949447
# gzsl: unseen=0.4152 , seen=0.2517 , h=0.3134
# ____________________________________________________________________________________________________
# episode: 189000 loss tensor(0.7829, device='cuda:0')
# episode: 190000 loss tensor(0.7710, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4408493427704752
# gzsl: unseen=0.4119 , seen=0.2438 , h=0.3063
# ____________________________________________________________________________________________________
# episode: 191000 loss tensor(0.7773, device='cuda:0')
# episode: 192000 loss tensor(0.8009, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44388270980788674
# gzsl: unseen=0.4129 , seen=0.2523 , h=0.3132
# ____________________________________________________________________________________________________
# episode: 193000 loss tensor(0.7968, device='cuda:0')
# episode: 194000 loss tensor(0.7920, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44354566902595216
# gzsl: unseen=0.4112 , seen=0.2370 , h=0.3007
# ____________________________________________________________________________________________________
# episode: 195000 loss tensor(0.7717, device='cuda:0')
# episode: 196000 loss tensor(0.7386, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44051230198854063
# gzsl: unseen=0.4125 , seen=0.2438 , h=0.3065
# ____________________________________________________________________________________________________
# episode: 197000 loss tensor(0.7939, device='cuda:0')
# episode: 198000 loss tensor(0.7740, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43815301651499833
# gzsl: unseen=0.4112 , seen=0.2409 , h=0.3038
# ____________________________________________________________________________________________________
# episode: 199000 loss tensor(0.7888, device='cuda:0')
# episode: 200000 loss tensor(0.7809, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4452308729356252
# gzsl: unseen=0.4173 , seen=0.2489 , h=0.3118
# ____________________________________________________________________________________________________
# episode: 201000 loss tensor(0.7966, device='cuda:0')
# episode: 202000 loss tensor(0.7868, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44287158746208294
# gzsl: unseen=0.4173 , seen=0.2347 , h=0.3004
# ____________________________________________________________________________________________________
# episode: 203000 loss tensor(0.7777, device='cuda:0')
# episode: 204000 loss tensor(0.7713, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4418604651162791
# gzsl: unseen=0.4189 , seen=0.2330 , h=0.2994
# ____________________________________________________________________________________________________
# episode: 205000 loss tensor(0.7929, device='cuda:0')
# episode: 206000 loss tensor(0.7886, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4361307718233906
# gzsl: unseen=0.4132 , seen=0.2330 , h=0.2980
# ____________________________________________________________________________________________________
# episode: 207000 loss tensor(0.7803, device='cuda:0')
# episode: 208000 loss tensor(0.7445, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4395011796427368
# gzsl: unseen=0.4149 , seen=0.2353 , h=0.3003
# ____________________________________________________________________________________________________
# episode: 209000 loss tensor(0.7741, device='cuda:0')
# episode: 210000 loss tensor(0.7747, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4368048533872599
# gzsl: unseen=0.4115 , seen=0.2273 , h=0.2929
# ____________________________________________________________________________________________________
# episode: 211000 loss tensor(0.7693, device='cuda:0')
# episode: 212000 loss tensor(0.7970, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4395011796427368
# gzsl: unseen=0.4162 , seen=0.2194 , h=0.2873
# ____________________________________________________________________________________________________
# episode: 213000 loss tensor(0.7628, device='cuda:0')
# episode: 214000 loss tensor(0.7779, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.440175261206606
# gzsl: unseen=0.4173 , seen=0.2296 , h=0.2962
# ____________________________________________________________________________________________________
# episode: 215000 loss tensor(0.8021, device='cuda:0')
# episode: 216000 loss tensor(0.7651, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4374789349511291
# gzsl: unseen=0.4149 , seen=0.2262 , h=0.2928
# ____________________________________________________________________________________________________
# episode: 217000 loss tensor(0.7618, device='cuda:0')
# episode: 218000 loss tensor(0.7623, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44118638355240986
# gzsl: unseen=0.4169 , seen=0.2251 , h=0.2923
# ____________________________________________________________________________________________________
# episode: 219000 loss tensor(0.7617, device='cuda:0')
# episode: 220000 loss tensor(0.7650, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4374789349511291
# gzsl: unseen=0.4156 , seen=0.2228 , h=0.2901
# ____________________________________________________________________________________________________
# episode: 221000 loss tensor(0.7832, device='cuda:0')
# episode: 222000 loss tensor(0.7607, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4354566902595214
# gzsl: unseen=0.4146 , seen=0.2211 , h=0.2884
# ____________________________________________________________________________________________________
# episode: 223000 loss tensor(0.7822, device='cuda:0')
# episode: 224000 loss tensor(0.7740, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44051230198854063
# gzsl: unseen=0.4186 , seen=0.2211 , h=0.2894
# ____________________________________________________________________________________________________
# episode: 225000 loss tensor(0.7694, device='cuda:0')
# episode: 226000 loss tensor(0.7763, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43646781260532524
# gzsl: unseen=0.4139 , seen=0.2166 , h=0.2843
# ____________________________________________________________________________________________________
# episode: 227000 loss tensor(0.7921, device='cuda:0')
# episode: 228000 loss tensor(0.7583, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43646781260532524
# gzsl: unseen=0.4146 , seen=0.2239 , h=0.2908
# ____________________________________________________________________________________________________
# episode: 229000 loss tensor(0.7671, device='cuda:0')
# episode: 230000 loss tensor(0.7809, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43882709807886755
# gzsl: unseen=0.4162 , seen=0.2205 , h=0.2883
# ____________________________________________________________________________________________________
# episode: 231000 loss tensor(0.7598, device='cuda:0')
# episode: 232000 loss tensor(0.7663, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43916413886080213
# gzsl: unseen=0.4176 , seen=0.2222 , h=0.2901
# ____________________________________________________________________________________________________
# episode: 233000 loss tensor(0.7606, device='cuda:0')
# episode: 234000 loss tensor(0.7650, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.435793731041456
# gzsl: unseen=0.4132 , seen=0.2160 , h=0.2837
# ____________________________________________________________________________________________________
# episode: 235000 loss tensor(0.7786, device='cuda:0')
# episode: 236000 loss tensor(0.7889, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4361307718233906
# gzsl: unseen=0.4162 , seen=0.2171 , h=0.2854
# ____________________________________________________________________________________________________
# episode: 237000 loss tensor(0.7798, device='cuda:0')
# episode: 238000 loss tensor(0.7738, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4395011796427368
# gzsl: unseen=0.4196 , seen=0.2183 , h=0.2872
# ____________________________________________________________________________________________________
# episode: 239000 loss tensor(0.7505, device='cuda:0')
# episode: 240000 loss tensor(0.7563, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44118638355240986
# gzsl: unseen=0.4223 , seen=0.2200 , h=0.2893
# ____________________________________________________________________________________________________
# episode: 241000 loss tensor(0.7842, device='cuda:0')
# episode: 242000 loss tensor(0.7712, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4361307718233906
# gzsl: unseen=0.4156 , seen=0.2194 , h=0.2872
# ____________________________________________________________________________________________________
# episode: 243000 loss tensor(0.7823, device='cuda:0')
# episode: 244000 loss tensor(0.7742, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43377148634984836
# gzsl: unseen=0.4119 , seen=0.2126 , h=0.2804
# ____________________________________________________________________________________________________
# episode: 245000 loss tensor(0.7718, device='cuda:0')
# episode: 246000 loss tensor(0.7735, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44051230198854063
# gzsl: unseen=0.4189 , seen=0.2166 , h=0.2855
# ____________________________________________________________________________________________________
# episode: 247000 loss tensor(0.7688, device='cuda:0')
# episode: 248000 loss tensor(0.7796, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4425345466801483
# gzsl: unseen=0.4220 , seen=0.2126 , h=0.2827
# ____________________________________________________________________________________________________
# episode: 249000 loss tensor(0.7803, device='cuda:0')
# episode: 250000 loss tensor(0.7665, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43646781260532524
# gzsl: unseen=0.4166 , seen=0.2098 , h=0.2790
# ____________________________________________________________________________________________________
# episode: 251000 loss tensor(0.7908, device='cuda:0')
# episode: 252000 loss tensor(0.8097, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4334344455679137
# gzsl: unseen=0.4139 , seen=0.2080 , h=0.2769
# ____________________________________________________________________________________________________
# episode: 253000 loss tensor(0.7783, device='cuda:0')
# episode: 254000 loss tensor(0.7795, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43714189416919447
# gzsl: unseen=0.4179 , seen=0.2075 , h=0.2773
# ____________________________________________________________________________________________________
# episode: 255000 loss tensor(0.8048, device='cuda:0')
# episode: 256000 loss tensor(0.7551, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4408493427704752
# gzsl: unseen=0.4223 , seen=0.2075 , h=0.2783
# ____________________________________________________________________________________________________
# episode: 257000 loss tensor(0.7809, device='cuda:0')
# episode: 258000 loss tensor(0.7626, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43646781260532524
# gzsl: unseen=0.4179 , seen=0.2018 , h=0.2722
# ____________________________________________________________________________________________________
# episode: 259000 loss tensor(0.7763, device='cuda:0')
# episode: 260000 loss tensor(0.7646, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43242332322210986
# gzsl: unseen=0.4112 , seen=0.2069 , h=0.2753
# ____________________________________________________________________________________________________
# episode: 261000 loss tensor(0.7705, device='cuda:0')
# episode: 262000 loss tensor(0.7901, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43714189416919447
# gzsl: unseen=0.4179 , seen=0.2069 , h=0.2768
# ____________________________________________________________________________________________________
# episode: 263000 loss tensor(0.7415, device='cuda:0')
# episode: 264000 loss tensor(0.7643, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43478260869565216
# gzsl: unseen=0.4169 , seen=0.2058 , h=0.2756
# ____________________________________________________________________________________________________
# episode: 265000 loss tensor(0.7902, device='cuda:0')
# episode: 266000 loss tensor(0.7924, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43714189416919447
# gzsl: unseen=0.4179 , seen=0.2029 , h=0.2732
# ____________________________________________________________________________________________________
# episode: 267000 loss tensor(0.7546, device='cuda:0')
# episode: 268000 loss tensor(0.7871, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.435793731041456
# gzsl: unseen=0.4162 , seen=0.2012 , h=0.2713
# ____________________________________________________________________________________________________
# episode: 269000 loss tensor(0.7694, device='cuda:0')
# episode: 270000 loss tensor(0.8090, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4395011796427368
# gzsl: unseen=0.4196 , seen=0.2041 , h=0.2746
# ____________________________________________________________________________________________________
# episode: 271000 loss tensor(0.7841, device='cuda:0')
# episode: 272000 loss tensor(0.8089, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43916413886080213
# gzsl: unseen=0.4200 , seen=0.2063 , h=0.2767
# ____________________________________________________________________________________________________
# episode: 273000 loss tensor(0.7601, device='cuda:0')
# episode: 274000 loss tensor(0.7697, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43646781260532524
# gzsl: unseen=0.4189 , seen=0.2007 , h=0.2714
# ____________________________________________________________________________________________________
# episode: 275000 loss tensor(0.7706, device='cuda:0')
# episode: 276000 loss tensor(0.7834, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4448938321536906
# gzsl: unseen=0.4260 , seen=0.2075 , h=0.2791
# ____________________________________________________________________________________________________
# episode: 277000 loss tensor(0.7983, device='cuda:0')
# episode: 278000 loss tensor(0.7471, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4334344455679137
# gzsl: unseen=0.4146 , seen=0.1933 , h=0.2637
# ____________________________________________________________________________________________________
# episode: 279000 loss tensor(0.7567, device='cuda:0')
# episode: 280000 loss tensor(0.7711, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43646781260532524
# gzsl: unseen=0.4183 , seen=0.2035 , h=0.2738
# ____________________________________________________________________________________________________
# episode: 281000 loss tensor(0.7775, device='cuda:0')
# episode: 282000 loss tensor(0.7652, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4398382204246714
# gzsl: unseen=0.4216 , seen=0.1967 , h=0.2683
# ____________________________________________________________________________________________________
# episode: 283000 loss tensor(0.7618, device='cuda:0')
# episode: 284000 loss tensor(0.8044, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.435793731041456
# gzsl: unseen=0.4166 , seen=0.1990 , h=0.2693
# ____________________________________________________________________________________________________
# episode: 285000 loss tensor(0.7654, device='cuda:0')
# episode: 286000 loss tensor(0.7675, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.43882709807886755
# gzsl: unseen=0.4206 , seen=0.1961 , h=0.2675
# ____________________________________________________________________________________________________
# episode: 287000 loss tensor(0.7623, device='cuda:0')
# episode: 288000 loss tensor(0.7579, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4374789349511291
# gzsl: unseen=0.4210 , seen=0.2029 , h=0.2739
# ____________________________________________________________________________________________________
# episode: 289000 loss tensor(0.7723, device='cuda:0')
# episode: 290000 loss tensor(0.7737, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.44287158746208294
# gzsl: unseen=0.4267 , seen=0.2024 , h=0.2745
# ____________________________________________________________________________________________________
# ...
# episode: 405000 loss tensor(0.7555, device='cuda:0')
# episode: 406000 loss tensor(0.7608, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4172564880350522
# gzsl: unseen=0.4044 , seen=0.1718 , h=0.2411
# ____________________________________________________________________________________________________
# episode: 407000 loss tensor(0.7755, device='cuda:0')
# episode: 408000 loss tensor(0.8030, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41523424334344455
# gzsl: unseen=0.4028 , seen=0.1718 , h=0.2408
# ____________________________________________________________________________________________________
# episode: 409000 loss tensor(0.7610, device='cuda:0')
# episode: 410000 loss tensor(0.7720, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4186046511627907
# gzsl: unseen=0.4075 , seen=0.1678 , h=0.2377
# ____________________________________________________________________________________________________
# episode: 411000 loss tensor(0.7729, device='cuda:0')
# episode: 412000 loss tensor(0.7721, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4182676103808561
# gzsl: unseen=0.4085 , seen=0.1678 , h=0.2379
# ____________________________________________________________________________________________________
# episode: 413000 loss tensor(0.7664, device='cuda:0')
# episode: 414000 loss tensor(0.7623, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41354903943377147
# gzsl: unseen=0.4028 , seen=0.1678 , h=0.2369
# ____________________________________________________________________________________________________
# episode: 415000 loss tensor(0.7880, device='cuda:0')
# episode: 416000 loss tensor(0.7568, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4186046511627907
# gzsl: unseen=0.4082 , seen=0.1695 , h=0.2395
# ____________________________________________________________________________________________________
# episode: 417000 loss tensor(0.7541, device='cuda:0')
# episode: 418000 loss tensor(0.7653, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4186046511627907
# gzsl: unseen=0.4075 , seen=0.1695 , h=0.2394
# ____________________________________________________________________________________________________
# episode: 419000 loss tensor(0.7987, device='cuda:0')
# episode: 420000 loss tensor(0.7645, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41456016177957533
# gzsl: unseen=0.4024 , seen=0.1706 , h=0.2397
# ____________________________________________________________________________________________________
# episode: 421000 loss tensor(0.7646, device='cuda:0')
# episode: 422000 loss tensor(0.7892, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41927873272665994
# gzsl: unseen=0.4071 , seen=0.1729 , h=0.2427
# ____________________________________________________________________________________________________
# episode: 423000 loss tensor(0.7853, device='cuda:0')
# episode: 424000 loss tensor(0.7714, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4159083249073138
# gzsl: unseen=0.4044 , seen=0.1650 , h=0.2343
# ____________________________________________________________________________________________________
# episode: 425000 loss tensor(0.7720, device='cuda:0')
# episode: 426000 loss tensor(0.7879, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4172564880350522
# gzsl: unseen=0.4055 , seen=0.1695 , h=0.2391
# ____________________________________________________________________________________________________
# episode: 427000 loss tensor(0.7300, device='cuda:0')
# episode: 428000 loss tensor(0.7652, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4186046511627907
# gzsl: unseen=0.4068 , seen=0.1712 , h=0.2410
# ____________________________________________________________________________________________________
# episode: 429000 loss tensor(0.7822, device='cuda:0')
# episode: 430000 loss tensor(0.7841, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4162453656892484
# gzsl: unseen=0.4051 , seen=0.1650 , h=0.2345
# ____________________________________________________________________________________________________
# episode: 431000 loss tensor(0.7433, device='cuda:0')
# episode: 432000 loss tensor(0.7535, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41927873272665994
# gzsl: unseen=0.4092 , seen=0.1695 , h=0.2397
# ____________________________________________________________________________________________________
# episode: 433000 loss tensor(0.7782, device='cuda:0')
# episode: 434000 loss tensor(0.7715, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41186383552409844
# gzsl: unseen=0.4018 , seen=0.1684 , h=0.2373
# ____________________________________________________________________________________________________
# episode: 435000 loss tensor(0.7746, device='cuda:0')
# episode: 436000 loss tensor(0.7729, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4186046511627907
# gzsl: unseen=0.4082 , seen=0.1689 , h=0.2390
# ____________________________________________________________________________________________________
# episode: 437000 loss tensor(0.7760, device='cuda:0')
# episode: 438000 loss tensor(0.7997, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.416582406471183
# gzsl: unseen=0.4051 , seen=0.1672 , h=0.2367
# ____________________________________________________________________________________________________
# episode: 439000 loss tensor(0.7634, device='cuda:0')
# episode: 440000 loss tensor(0.7901, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4196157735085945
# gzsl: unseen=0.4082 , seen=0.1723 , h=0.2423
# ____________________________________________________________________________________________________
# episode: 441000 loss tensor(0.7696, device='cuda:0')
# episode: 442000 loss tensor(0.7775, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4159083249073138
# gzsl: unseen=0.4051 , seen=0.1684 , h=0.2379
# ____________________________________________________________________________________________________
# episode: 443000 loss tensor(0.7908, device='cuda:0')
# episode: 444000 loss tensor(0.7767, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4213009774182676
# gzsl: unseen=0.4112 , seen=0.1672 , h=0.2378
# ____________________________________________________________________________________________________
# episode: 445000 loss tensor(0.7825, device='cuda:0')
# episode: 446000 loss tensor(0.7550, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41691944725311764
# gzsl: unseen=0.4061 , seen=0.1672 , h=0.2369
# ____________________________________________________________________________________________________
# episode: 447000 loss tensor(0.7836, device='cuda:0')
# episode: 448000 loss tensor(0.7774, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41253791708796766
# gzsl: unseen=0.4028 , seen=0.1655 , h=0.2346
# ____________________________________________________________________________________________________
# episode: 449000 loss tensor(0.7951, device='cuda:0')
# episode: 450000 loss tensor(0.7812, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4142231209976407
# gzsl: unseen=0.4041 , seen=0.1667 , h=0.2360
# ____________________________________________________________________________________________________
# episode: 451000 loss tensor(0.7965, device='cuda:0')
# episode: 452000 loss tensor(0.7681, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4186046511627907
# gzsl: unseen=0.4095 , seen=0.1655 , h=0.2358
# ____________________________________________________________________________________________________
# episode: 453000 loss tensor(0.7842, device='cuda:0')
# episode: 454000 loss tensor(0.7879, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41759352881698686
# gzsl: unseen=0.4082 , seen=0.1650 , h=0.2350
# ____________________________________________________________________________________________________
# episode: 455000 loss tensor(0.7512, device='cuda:0')
# episode: 456000 loss tensor(0.7845, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4155712841253792
# gzsl: unseen=0.4061 , seen=0.1638 , h=0.2335
# ____________________________________________________________________________________________________
# episode: 457000 loss tensor(0.7820, device='cuda:0')
# episode: 458000 loss tensor(0.7671, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41287495786990225
# gzsl: unseen=0.4021 , seen=0.1610 , h=0.2299
# ____________________________________________________________________________________________________
# episode: 459000 loss tensor(0.8084, device='cuda:0')
# episode: 460000 loss tensor(0.7466, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4186046511627907
# gzsl: unseen=0.4075 , seen=0.1644 , h=0.2343
# ____________________________________________________________________________________________________
# episode: 461000 loss tensor(0.7843, device='cuda:0')
# episode: 462000 loss tensor(0.7839, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41354903943377147
# gzsl: unseen=0.4034 , seen=0.1587 , h=0.2278
# ____________________________________________________________________________________________________
# episode: 463000 loss tensor(0.7899, device='cuda:0')
# episode: 464000 loss tensor(0.7766, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41489720256150997
# gzsl: unseen=0.4051 , seen=0.1667 , h=0.2362
# ____________________________________________________________________________________________________
# episode: 465000 loss tensor(0.7595, device='cuda:0')
# episode: 466000 loss tensor(0.7902, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41759352881698686
# gzsl: unseen=0.4075 , seen=0.1633 , h=0.2331
# ____________________________________________________________________________________________________
# episode: 467000 loss tensor(0.7791, device='cuda:0')
# episode: 468000 loss tensor(0.7212, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4142231209976407
# gzsl: unseen=0.4048 , seen=0.1638 , h=0.2333
# ____________________________________________________________________________________________________
# episode: 469000 loss tensor(0.7797, device='cuda:0')
# episode: 470000 loss tensor(0.7737, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41118975396022917
# gzsl: unseen=0.4018 , seen=0.1599 , h=0.2287
# ____________________________________________________________________________________________________
# episode: 471000 loss tensor(0.7634, device='cuda:0')
# episode: 472000 loss tensor(0.7719, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.412200876306033
# gzsl: unseen=0.4024 , seen=0.1582 , h=0.2271
# ____________________________________________________________________________________________________
# episode: 473000 loss tensor(0.8180, device='cuda:0')
# episode: 474000 loss tensor(0.7994, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4132119986518369
# gzsl: unseen=0.4041 , seen=0.1587 , h=0.2279
# ____________________________________________________________________________________________________
# episode: 475000 loss tensor(0.7787, device='cuda:0')
# episode: 476000 loss tensor(0.7592, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4098415908324907
# gzsl: unseen=0.3997 , seen=0.1627 , h=0.2313
# ____________________________________________________________________________________________________
# episode: 477000 loss tensor(0.7636, device='cuda:0')
# episode: 478000 loss tensor(0.7674, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4186046511627907
# gzsl: unseen=0.4088 , seen=0.1593 , h=0.2293
# ____________________________________________________________________________________________________
# episode: 479000 loss tensor(0.7592, device='cuda:0')
# episode: 480000 loss tensor(0.7693, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41287495786990225
# gzsl: unseen=0.4038 , seen=0.1610 , h=0.2302
# ____________________________________________________________________________________________________
# episode: 481000 loss tensor(0.7475, device='cuda:0')
# episode: 482000 loss tensor(0.7702, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.412200876306033
# gzsl: unseen=0.4031 , seen=0.1576 , h=0.2266
# ____________________________________________________________________________________________________
# episode: 483000 loss tensor(0.7659, device='cuda:0')
# episode: 484000 loss tensor(0.7649, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41354903943377147
# gzsl: unseen=0.4024 , seen=0.1599 , h=0.2288
# ____________________________________________________________________________________________________
# episode: 485000 loss tensor(0.7500, device='cuda:0')
# episode: 486000 loss tensor(0.7843, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4115267947421638
# gzsl: unseen=0.4018 , seen=0.1604 , h=0.2293
# ____________________________________________________________________________________________________
# episode: 487000 loss tensor(0.7701, device='cuda:0')
# episode: 488000 loss tensor(0.7672, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41691944725311764
# gzsl: unseen=0.4071 , seen=0.1633 , h=0.2331
# ____________________________________________________________________________________________________
# episode: 489000 loss tensor(0.7643, device='cuda:0')
# episode: 490000 loss tensor(0.7611, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4159083249073138
# gzsl: unseen=0.4075 , seen=0.1593 , h=0.2291
# ____________________________________________________________________________________________________
# episode: 491000 loss tensor(0.7838, device='cuda:0')
# episode: 492000 loss tensor(0.7634, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41354903943377147
# gzsl: unseen=0.4034 , seen=0.1616 , h=0.2307
# ____________________________________________________________________________________________________
# episode: 493000 loss tensor(0.7888, device='cuda:0')
# episode: 494000 loss tensor(0.7522, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4088304684866869
# gzsl: unseen=0.4004 , seen=0.1570 , h=0.2256
# ____________________________________________________________________________________________________
# episode: 495000 loss tensor(0.7802, device='cuda:0')
# episode: 496000 loss tensor(0.7789, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.41691944725311764
# gzsl: unseen=0.4085 , seen=0.1576 , h=0.2274
# ____________________________________________________________________________________________________
# episode: 497000 loss tensor(0.7526, device='cuda:0')
# episode: 498000 loss tensor(0.7783, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.4182676103808561
# gzsl: unseen=0.4082 , seen=0.1667 , h=0.2367
# ____________________________________________________________________________________________________
# episode: 499000 loss tensor(0.7710, device='cuda:0')
# episode: 500000 loss tensor(0.7721, device='cuda:0')
# Testing...
# class num: 50
# class num: 200
# class num: 200
# zsl: 0.412200876306033
# gzsl: unseen=0.4028 , seen=0.1582 , h=0.2271
# ____________________________________________________________________________________________________
