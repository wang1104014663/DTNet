# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os

# %%
BATCH_SIZE = 64
EPISODE = 200000
TEST_EPISODE = 1000
LEARNING_RATE =1e-3
Nom = 0
Weight_Deacy = 0
GPU = 0
Margin = 1

# %%
print("init dataset")
##################################参数##################################################################
dataroot = '../data'
dataset = 'AwA1_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'original_att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个

########################add negative pairs#######################
#x_negative = np.empty_like(x)
#x_negative_label = np.empty_like(train_label)
#print(x.shape[0])

#for i in range(x.shape[0]):
#    pick=np.random.choice(np.where(train_label[i]!=train_id)[0], replace=True)
#    x_negative[i] = x[pick]
#    x_negative_label[i] = train_label[pick]
    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
#train_negative_label = torch.from_numpy(x_negative_label).unsqueeze(1)
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
#print(all_attributes)
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net_3 import AttributeNetwork
from my_net_3 import TripletNetwork
from my_net_3 import MetricNetwork

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(85,1024,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
metric_network = MetricNetwork(2048,1024,2048)
triplet_network = TripletNetwork(attribute_network, metric_network)  #metric learning   
triplet_network.cuda(GPU)   
#attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
#优化器adam 学习率 正则1e-5

#attribute_network_scheduler = StepLR(attribute_network_optim, step_size=200000, gamma=0.5)
#学习率每200k步 乘0.5
#triplet_network_optim = torch.optim.Adam(triplet_network.parameters(), lr=LEARNING_RATE)
#
triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE,momentum=0.9 , 
                                         weight_decay=Weight_Deacy)
triplet_network_scheduler = StepLR(triplet_network_optim , step_size=100000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = metric_network(Variable(batch_features_ext).cuda(GPU).float())  # 32*1024

        #print(batch_features_ext)

        sample_features = metric_network(attribute_network(Variable(sample_attributes).cuda(GPU).float()))
        sample_features_ext = sample_features.repeat(batch_size, 1)
        #print(sample_features_ext.shape)


        relations = F.pairwise_distance(batch_features_ext, sample_features_ext, 2).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        #print(predict_labels)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
print(triplet_network)
# Out:
# TripletNetwork(
#   (embeddingnet_att): AttributeNetwork(
#     (fc1): Linear(in_features=85, out_features=1024, bias=True)
#     (fc2): Linear(in_features=1024, out_features=2048, bias=True)
#   )
#   (embeddingnet): MetricNetwork(
#     (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#     (fc2): Linear(in_features=1024, out_features=2048, bias=True)
#   )
# )

# %%
print("training...")
last_accuracy = 0.0
for episode in range(EPISODE):
    #attribute_network.train()
    triplet_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    
    batch_features_negative = np.empty_like(batch_features.numpy())
    
    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_labels.numpy()]).squeeze(1)
    
    batch_features = Variable(batch_features).cuda(GPU).float()  # 32*2048
    
    for i in range(batch_features_negative.shape[0]):
        pick=np.random.choice(np.where(batch_labels.numpy()[i]!=train_id)[0], replace=True)
        batch_features_negative[i] = x[pick]    
    
    batch_features_negative = torch.from_numpy(batch_features_negative)
    batch_features_negative = Variable(batch_features_negative).cuda(GPU).float()  # 32*2048
    
    #batch_attributes = attribute_network(Variable(batch_attributes).cuda(GPU))
    batch_attributes = Variable(batch_attributes).cuda(GPU)
    
    dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(batch_attributes, batch_features, batch_features_negative)
    
    criterion = nn.MarginRankingLoss(margin = Margin).cuda(GPU)
    
    target = torch.FloatTensor(dista.size()).fill_(-1).cuda(GPU)
    
    
    loss_triplet= criterion(dista, distb, target)
    loss_embedd = embedded_x.norm(2) + embedded_y.norm(2) + embedded_z.norm(2)
    loss = loss_triplet + Nom * loss_embedd

    # update
    triplet_network.zero_grad()
    loss.backward()
    triplet_network_optim.step()
    
    if (episode+1)%1000 == 0:
        print("episode:", episode+1, "loss", loss.data)
    if (episode+1)%1000 == 0:
        print("Testing...")
        #attribute_network.eval()
        zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(50), attributes)
        gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(50), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        print('zsl:', zsl_accuracy)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        print('_'*100)
# Out:
# training...
# episode: 1000 loss tensor(0.1128, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.37150395778364115
# gzsl: unseen=0.0770 , seen=0.3348 , h=0.1253
# ____________________________________________________________________________________________________
# episode: 2000 loss tensor(1.00000e-02 *
#        1.8228, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3354441512752858
# gzsl: unseen=0.0521 , seen=0.3749 , h=0.0914
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(1.00000e-02 *
#        4.9499, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.33315743183817065
# gzsl: unseen=0.0556 , seen=0.4191 , h=0.0982
# ____________________________________________________________________________________________________
# episode: 4000 loss tensor(1.00000e-03 *
#        4.7522, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32612137203166225
# gzsl: unseen=0.0533 , seen=0.4072 , h=0.0943
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32313104661389624
# gzsl: unseen=0.0489 , seen=0.4141 , h=0.0875
# ____________________________________________________________________________________________________
# episode: 6000 loss tensor(1.00000e-03 *
#        5.7260, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3247141600703606
# gzsl: unseen=0.0533 , seen=0.4347 , h=0.0950
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(1.00000e-03 *
#        3.1013, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3264731750219877
# gzsl: unseen=0.0512 , seen=0.4314 , h=0.0915
# ____________________________________________________________________________________________________
# episode: 8000 loss tensor(1.00000e-03 *
#        4.8366, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3238346525945471
# gzsl: unseen=0.0529 , seen=0.4316 , h=0.0943
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(1.00000e-03 *
#        5.0517, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32999120492524187
# gzsl: unseen=0.0529 , seen=0.4228 , h=0.0941
# ____________________________________________________________________________________________________
# episode: 10000 loss tensor(1.00000e-04 *
#        9.3346, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3248900615655233
# gzsl: unseen=0.0547 , seen=0.4274 , h=0.0970
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(1.00000e-03 *
#        6.0231, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3238346525945471
# gzsl: unseen=0.0549 , seen=0.4429 , h=0.0977
# ____________________________________________________________________________________________________
# episode: 12000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32788038698328936
# gzsl: unseen=0.0549 , seen=0.4326 , h=0.0974
# ____________________________________________________________________________________________________
# episode: 13000 loss tensor(1.00000e-03 *
#        2.1500, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32788038698328936
# gzsl: unseen=0.0542 , seen=0.4433 , h=0.0966
# ____________________________________________________________________________________________________
# episode: 14000 loss tensor(1.00000e-03 *
#        1.3163, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32999120492524187
# gzsl: unseen=0.0542 , seen=0.4340 , h=0.0963
# ____________________________________________________________________________________________________
# episode: 15000 loss tensor(1.00000e-03 *
#        3.8807, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3268249780123131
# gzsl: unseen=0.0559 , seen=0.4353 , h=0.0991
# ____________________________________________________________________________________________________
# episode: 16000 loss tensor(1.00000e-03 *
#        2.7647, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3259454705364996
# gzsl: unseen=0.0584 , seen=0.4391 , h=0.1031
# ____________________________________________________________________________________________________
# episode: 17000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3229551451187335
# gzsl: unseen=0.0561 , seen=0.4373 , h=0.0995
# ____________________________________________________________________________________________________
# episode: 18000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3245382585751979
# gzsl: unseen=0.0559 , seen=0.4284 , h=0.0990
# ____________________________________________________________________________________________________
# episode: 19000 loss tensor(1.00000e-02 *
#        1.4913, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3308707124010554
# gzsl: unseen=0.0559 , seen=0.4391 , h=0.0992
# ____________________________________________________________________________________________________
# episode: 20000 loss tensor(1.00000e-03 *
#        1.5988, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3106420404573439
# gzsl: unseen=0.0561 , seen=0.4244 , h=0.0991
# ____________________________________________________________________________________________________
# episode: 21000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3148636763412489
# gzsl: unseen=0.0572 , seen=0.4419 , h=0.1012
# ____________________________________________________________________________________________________
# episode: 22000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31204925241864556
# gzsl: unseen=0.0582 , seen=0.4425 , h=0.1029
# ____________________________________________________________________________________________________
# episode: 23000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3143359718557608
# gzsl: unseen=0.0595 , seen=0.4395 , h=0.1047
# ____________________________________________________________________________________________________
# episode: 24000 loss tensor(1.00000e-04 *
#        6.0140, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.30817941952506595
# gzsl: unseen=0.0593 , seen=0.4336 , h=0.1043
# ____________________________________________________________________________________________________
# episode: 25000 loss tensor(1.00000e-03 *
#        4.6118, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3122251539138083
# gzsl: unseen=0.0575 , seen=0.4320 , h=0.1015
# ____________________________________________________________________________________________________
# episode: 26000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3266490765171504
# gzsl: unseen=0.0570 , seen=0.4306 , h=0.1007
# ____________________________________________________________________________________________________
# episode: 27000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3222515391380827
# gzsl: unseen=0.0607 , seen=0.4449 , h=0.1068
# ____________________________________________________________________________________________________
# episode: 28000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3287598944591029
# gzsl: unseen=0.0561 , seen=0.4405 , h=0.0995
# ____________________________________________________________________________________________________
# episode: 29000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32348284960422163
# gzsl: unseen=0.0577 , seen=0.4342 , h=0.1019
# ____________________________________________________________________________________________________
# episode: 30000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3217238346525945
# gzsl: unseen=0.0579 , seen=0.4423 , h=0.1024
# ____________________________________________________________________________________________________
# episode: 31000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3201407211961302
# gzsl: unseen=0.0596 , seen=0.4389 , h=0.1050
# ____________________________________________________________________________________________________
# episode: 32000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3275285839929639
# gzsl: unseen=0.0614 , seen=0.4488 , h=0.1080
# ____________________________________________________________________________________________________
# episode: 33000 loss tensor(1.00000e-02 *
#        1.3554, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3247141600703606
# gzsl: unseen=0.0612 , seen=0.4514 , h=0.1078
# ____________________________________________________________________________________________________
# episode: 34000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3222515391380827
# gzsl: unseen=0.0598 , seen=0.4484 , h=0.1055
# ____________________________________________________________________________________________________
# episode: 35000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31627088830255057
# gzsl: unseen=0.0628 , seen=0.4542 , h=0.1103
# ____________________________________________________________________________________________________
# episode: 36000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31187335092348284
# gzsl: unseen=0.0603 , seen=0.4373 , h=0.1060
# ____________________________________________________________________________________________________
# episode: 37000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3222515391380827
# gzsl: unseen=0.0600 , seen=0.4342 , h=0.1054
# ____________________________________________________________________________________________________
# episode: 38000 loss tensor(1.00000e-04 *
#        1.7644, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32735268249780125
# gzsl: unseen=0.0619 , seen=0.4449 , h=0.1087
# ____________________________________________________________________________________________________
# episode: 39000 loss tensor(1.00000e-03 *
#        3.9004, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32981530343007914
# gzsl: unseen=0.0612 , seen=0.4385 , h=0.1074
# ____________________________________________________________________________________________________
# episode: 40000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.334740545294635
# gzsl: unseen=0.0607 , seen=0.4459 , h=0.1068
# ____________________________________________________________________________________________________
# episode: 41000 loss tensor(1.00000e-03 *
#        5.4672, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3275285839929639
# gzsl: unseen=0.0644 , seen=0.4514 , h=0.1127
# ____________________________________________________________________________________________________
# episode: 42000 loss tensor(1.00000e-03 *
#        2.8975, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3159190853122252
# gzsl: unseen=0.0635 , seen=0.4367 , h=0.1109
# ____________________________________________________________________________________________________
# episode: 43000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3210202286719437
# gzsl: unseen=0.0663 , seen=0.4401 , h=0.1153
# ____________________________________________________________________________________________________
# episode: 44000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32576956904133686
# gzsl: unseen=0.0639 , seen=0.4425 , h=0.1116
# ____________________________________________________________________________________________________
# episode: 45000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32999120492524187
# gzsl: unseen=0.0665 , seen=0.4653 , h=0.1164
# ____________________________________________________________________________________________________
# episode: 46000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3308707124010554
# gzsl: unseen=0.0688 , seen=0.4641 , h=0.1198
# ____________________________________________________________________________________________________
# episode: 47000 loss tensor(1.00000e-03 *
#        1.1380, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.331750219876869
# gzsl: unseen=0.0633 , seen=0.4538 , h=0.1111
# ____________________________________________________________________________________________________
# episode: 48000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31996481970096746
# gzsl: unseen=0.0626 , seen=0.4431 , h=0.1097
# ____________________________________________________________________________________________________
# episode: 49000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31521547933157434
# gzsl: unseen=0.0626 , seen=0.4419 , h=0.1097
# ____________________________________________________________________________________________________
# episode: 50000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31926121372031663
# gzsl: unseen=0.0668 , seen=0.4405 , h=0.1161
# ____________________________________________________________________________________________________
# episode: 51000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3222515391380827
# gzsl: unseen=0.0686 , seen=0.4441 , h=0.1188
# ____________________________________________________________________________________________________
# episode: 52000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3206684256816183
# gzsl: unseen=0.0697 , seen=0.4470 , h=0.1205
# ____________________________________________________________________________________________________
# episode: 53000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3229551451187335
# gzsl: unseen=0.0675 , seen=0.4459 , h=0.1173
# ____________________________________________________________________________________________________
# episode: 54000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3224274406332454
# gzsl: unseen=0.0688 , seen=0.4421 , h=0.1190
# ____________________________________________________________________________________________________
# episode: 55000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.325065963060686
# gzsl: unseen=0.0697 , seen=0.4524 , h=0.1207
# ____________________________________________________________________________________________________
# episode: 56000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32207563764291997
# gzsl: unseen=0.0725 , seen=0.4558 , h=0.1251
# ____________________________________________________________________________________________________
# episode: 57000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32717678100263853
# gzsl: unseen=0.0718 , seen=0.4496 , h=0.1238
# ____________________________________________________________________________________________________
# episode: 58000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31996481970096746
# gzsl: unseen=0.0711 , seen=0.4441 , h=0.1225
# ____________________________________________________________________________________________________
# episode: 59000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31978891820580474
# gzsl: unseen=0.0691 , seen=0.4425 , h=0.1196
# ____________________________________________________________________________________________________
# episode: 60000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3217238346525945
# gzsl: unseen=0.0679 , seen=0.4417 , h=0.1177
# ____________________________________________________________________________________________________
# episode: 61000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31820580474934035
# gzsl: unseen=0.0688 , seen=0.4431 , h=0.1191
# ____________________________________________________________________________________________________
# episode: 62000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32313104661389624
# gzsl: unseen=0.0690 , seen=0.4407 , h=0.1192
# ____________________________________________________________________________________________________
# episode: 63000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3204925241864556
# gzsl: unseen=0.0686 , seen=0.4490 , h=0.1190
# ____________________________________________________________________________________________________
# episode: 64000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32401055408970975
# gzsl: unseen=0.0698 , seen=0.4512 , h=0.1209
# ____________________________________________________________________________________________________
# episode: 65000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3254177660510114
# gzsl: unseen=0.0730 , seen=0.4556 , h=0.1258
# ____________________________________________________________________________________________________
# episode: 66000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3259454705364996
# gzsl: unseen=0.0704 , seen=0.4530 , h=0.1218
# ____________________________________________________________________________________________________
# episode: 67000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3167985927880387
# gzsl: unseen=0.0693 , seen=0.4544 , h=0.1203
# ____________________________________________________________________________________________________
# episode: 68000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3175021987686895
# gzsl: unseen=0.0688 , seen=0.4403 , h=0.1190
# ____________________________________________________________________________________________________
# episode: 69000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32207563764291997
# gzsl: unseen=0.0718 , seen=0.4524 , h=0.1239
# ____________________________________________________________________________________________________
# episode: 70000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3226033421284081
# gzsl: unseen=0.0728 , seen=0.4455 , h=0.1252
# ____________________________________________________________________________________________________
# episode: 71000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3159190853122252
# gzsl: unseen=0.0739 , seen=0.4500 , h=0.1269
# ____________________________________________________________________________________________________
# episode: 72000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31943711521547935
# gzsl: unseen=0.0737 , seen=0.4508 , h=0.1267
# ____________________________________________________________________________________________________
# episode: 73000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31732629727352685
# gzsl: unseen=0.0705 , seen=0.4413 , h=0.1216
# ____________________________________________________________________________________________________
# episode: 74000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3164467897977133
# gzsl: unseen=0.0695 , seen=0.4421 , h=0.1201
# ____________________________________________________________________________________________________
# episode: 75000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31398416886543534
# gzsl: unseen=0.0697 , seen=0.4381 , h=0.1202
# ____________________________________________________________________________________________________
# episode: 76000 loss tensor(1.00000e-03 *
#        5.6321, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32207563764291997
# gzsl: unseen=0.0756 , seen=0.4534 , h=0.1296
# ____________________________________________________________________________________________________
# episode: 77000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3187335092348285
# gzsl: unseen=0.0732 , seen=0.4482 , h=0.1258
# ____________________________________________________________________________________________________
# episode: 78000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.316622691292876
# gzsl: unseen=0.0726 , seen=0.4457 , h=0.1249
# ____________________________________________________________________________________________________
# episode: 79000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32031662269129285
# gzsl: unseen=0.0695 , seen=0.4314 , h=0.1197
# ____________________________________________________________________________________________________
# episode: 80000 loss tensor(1.00000e-03 *
#        5.2077, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32189973614775724
# gzsl: unseen=0.0765 , seen=0.4459 , h=0.1306
# ____________________________________________________________________________________________________
# episode: 81000 loss tensor(1.00000e-03 *
#        1.6822, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31627088830255057
# gzsl: unseen=0.0779 , seen=0.4433 , h=0.1326
# ____________________________________________________________________________________________________
# episode: 82000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3229551451187335
# gzsl: unseen=0.0788 , seen=0.4457 , h=0.1339
# ____________________________________________________________________________________________________
# episode: 83000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32401055408970975
# gzsl: unseen=0.0799 , seen=0.4552 , h=0.1359
# ____________________________________________________________________________________________________
# episode: 84000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3224274406332454
# gzsl: unseen=0.0793 , seen=0.4550 , h=0.1351
# ____________________________________________________________________________________________________
# episode: 85000 loss tensor(1.00000e-03 *
#        1.9684, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3204925241864556
# gzsl: unseen=0.0785 , seen=0.4548 , h=0.1338
# ____________________________________________________________________________________________________
# episode: 86000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3171503957783641
# gzsl: unseen=0.0788 , seen=0.4558 , h=0.1344
# ____________________________________________________________________________________________________
# episode: 87000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3138082673702726
# gzsl: unseen=0.0797 , seen=0.4574 , h=0.1357
# ____________________________________________________________________________________________________
# episode: 88000 loss tensor(1.00000e-04 *
#        9.9001, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3132805628847845
# gzsl: unseen=0.0772 , seen=0.4544 , h=0.1320
# ____________________________________________________________________________________________________
# episode: 89000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3090589270008795
# gzsl: unseen=0.0744 , seen=0.4482 , h=0.1276
# ____________________________________________________________________________________________________
# episode: 90000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3095866314863676
# gzsl: unseen=0.0763 , seen=0.4506 , h=0.1306
# ____________________________________________________________________________________________________
# episode: 91000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3106420404573439
# gzsl: unseen=0.0788 , seen=0.4488 , h=0.1341
# ____________________________________________________________________________________________________
# episode: 92000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31398416886543534
# gzsl: unseen=0.0793 , seen=0.4510 , h=0.1349
# ____________________________________________________________________________________________________
# episode: 93000 loss tensor(1.00000e-03 *
#        1.3884, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.315391380826737
# gzsl: unseen=0.0763 , seen=0.4508 , h=0.1306
# ____________________________________________________________________________________________________
# episode: 94000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3190853122251539
# gzsl: unseen=0.0774 , seen=0.4560 , h=0.1323
# ____________________________________________________________________________________________________
# episode: 95000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.31820580474934035
# gzsl: unseen=0.0772 , seen=0.4568 , h=0.1321
# ____________________________________________________________________________________________________
# episode: 96000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3189094107299912
# gzsl: unseen=0.0795 , seen=0.4516 , h=0.1352
# ____________________________________________________________________________________________________
# episode: 97000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3217238346525945
# gzsl: unseen=0.0811 , seen=0.4554 , h=0.1377
# ____________________________________________________________________________________________________
# episode: 98000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3204925241864556
# gzsl: unseen=0.0827 , seen=0.4570 , h=0.1400
# ____________________________________________________________________________________________________
# episode: 99000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3169744942832014
# gzsl: unseen=0.0799 , seen=0.4518 , h=0.1357
# ____________________________________________________________________________________________________
# episode: 100000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.33157431838170626
# gzsl: unseen=0.0813 , seen=0.4576 , h=0.1380
# ____________________________________________________________________________________________________
# episode: 101000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32717678100263853
# gzsl: unseen=0.0788 , seen=0.4433 , h=0.1338
# ____________________________________________________________________________________________________
# episode: 102000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32629727352682497
# gzsl: unseen=0.0793 , seen=0.4429 , h=0.1346
# ____________________________________________________________________________________________________
# episode: 103000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32137203166226913
# gzsl: unseen=0.0797 , seen=0.4425 , h=0.1350
# ____________________________________________________________________________________________________
# episode: 104000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32207563764291997
# gzsl: unseen=0.0777 , seen=0.4387 , h=0.1321
# ____________________________________________________________________________________________________
# episode: 105000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3217238346525945
# gzsl: unseen=0.0774 , seen=0.4445 , h=0.1318
# ____________________________________________________________________________________________________
# episode: 106000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3222515391380827
# gzsl: unseen=0.0788 , seen=0.4468 , h=0.1340
# ____________________________________________________________________________________________________
# episode: 107000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3280562884784521
# gzsl: unseen=0.0827 , seen=0.4502 , h=0.1397
# ____________________________________________________________________________________________________
# episode: 108000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32788038698328936
# gzsl: unseen=0.0825 , seen=0.4512 , h=0.1395
# ____________________________________________________________________________________________________
# episode: 109000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3270008795074758
# gzsl: unseen=0.0802 , seen=0.4564 , h=0.1364
# ____________________________________________________________________________________________________
# episode: 110000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32717678100263853
# gzsl: unseen=0.0816 , seen=0.4530 , h=0.1383
# ____________________________________________________________________________________________________
# episode: 111000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3247141600703606
# gzsl: unseen=0.0786 , seen=0.4488 , h=0.1338
# ____________________________________________________________________________________________________
# episode: 112000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3245382585751979
# gzsl: unseen=0.0777 , seen=0.4451 , h=0.1324
# ____________________________________________________________________________________________________
# episode: 113000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32401055408970975
# gzsl: unseen=0.0779 , seen=0.4447 , h=0.1326
# ____________________________________________________________________________________________________
# episode: 114000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3289357959542656
# gzsl: unseen=0.0828 , seen=0.4502 , h=0.1399
# ____________________________________________________________________________________________________
# episode: 115000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32823218997361475
# gzsl: unseen=0.0800 , seen=0.4453 , h=0.1357
# ____________________________________________________________________________________________________
# episode: 116000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3312225153913808
# gzsl: unseen=0.0788 , seen=0.4449 , h=0.1339
# ____________________________________________________________________________________________________
# episode: 117000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32788038698328936
# gzsl: unseen=0.0785 , seen=0.4445 , h=0.1334
# ____________________________________________________________________________________________________
# episode: 118000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32823218997361475
# gzsl: unseen=0.0806 , seen=0.4435 , h=0.1364
# ____________________________________________________________________________________________________
# episode: 119000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32770448548812664
# gzsl: unseen=0.0802 , seen=0.4445 , h=0.1359
# ____________________________________________________________________________________________________
# episode: 120000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32612137203166225
# gzsl: unseen=0.0800 , seen=0.4459 , h=0.1357
# ____________________________________________________________________________________________________
# episode: 121000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3289357959542656
# gzsl: unseen=0.0786 , seen=0.4453 , h=0.1337
# ____________________________________________________________________________________________________
# episode: 122000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32981530343007914
# gzsl: unseen=0.0807 , seen=0.4544 , h=0.1371
# ____________________________________________________________________________________________________
# episode: 123000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.33509234828496043
# gzsl: unseen=0.0816 , seen=0.4566 , h=0.1385
# ____________________________________________________________________________________________________
# episode: 124000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3308707124010554
# gzsl: unseen=0.0802 , seen=0.4453 , h=0.1359
# ____________________________________________________________________________________________________
# episode: 125000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3329815303430079
# gzsl: unseen=0.0814 , seen=0.4488 , h=0.1379
# ____________________________________________________________________________________________________
# episode: 126000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3312225153913808
# gzsl: unseen=0.0804 , seen=0.4578 , h=0.1368
# ____________________________________________________________________________________________________
# episode: 127000 loss tensor(1.00000e-03 *
#        9.0748, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3296394019349164
# gzsl: unseen=0.0793 , seen=0.4532 , h=0.1350
# ____________________________________________________________________________________________________
# episode: 128000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3308707124010554
# gzsl: unseen=0.0799 , seen=0.4528 , h=0.1358
# ____________________________________________________________________________________________________
# episode: 129000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3326297273526825
# gzsl: unseen=0.0813 , seen=0.4562 , h=0.1380
# ____________________________________________________________________________________________________
# episode: 130000 loss tensor(1.00000e-03 *
#        4.1226, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3266490765171504
# gzsl: unseen=0.0786 , seen=0.4572 , h=0.1342
# ____________________________________________________________________________________________________
# episode: 131000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3259454705364996
# gzsl: unseen=0.0799 , seen=0.4508 , h=0.1357
# ____________________________________________________________________________________________________
# episode: 132000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3266490765171504
# gzsl: unseen=0.0790 , seen=0.4443 , h=0.1341
# ____________________________________________________________________________________________________
# episode: 133000 loss tensor(1.00000e-03 *
#        2.1541, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32401055408970975
# gzsl: unseen=0.0807 , seen=0.4516 , h=0.1370
# ____________________________________________________________________________________________________
# episode: 134000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3206684256816183
# gzsl: unseen=0.0807 , seen=0.4455 , h=0.1367
# ____________________________________________________________________________________________________
# episode: 135000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3224274406332454
# gzsl: unseen=0.0809 , seen=0.4447 , h=0.1369
# ____________________________________________________________________________________________________
# episode: 136000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3266490765171504
# gzsl: unseen=0.0804 , seen=0.4482 , h=0.1363
# ____________________________________________________________________________________________________
# episode: 137000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32524186455584875
# gzsl: unseen=0.0806 , seen=0.4443 , h=0.1364
# ____________________________________________________________________________________________________
# episode: 138000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32717678100263853
# gzsl: unseen=0.0806 , seen=0.4463 , h=0.1365
# ____________________________________________________________________________________________________
# episode: 139000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3322779243623571
# gzsl: unseen=0.0809 , seen=0.4516 , h=0.1372
# ____________________________________________________________________________________________________
# episode: 140000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32981530343007914
# gzsl: unseen=0.0820 , seen=0.4566 , h=0.1390
# ____________________________________________________________________________________________________
# episode: 141000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3324538258575198
# gzsl: unseen=0.0827 , seen=0.4536 , h=0.1399
# ____________________________________________________________________________________________________
# episode: 142000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32788038698328936
# gzsl: unseen=0.0830 , seen=0.4552 , h=0.1404
# ____________________________________________________________________________________________________
# episode: 143000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32735268249780125
# gzsl: unseen=0.0823 , seen=0.4506 , h=0.1392
# ____________________________________________________________________________________________________
# episode: 144000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32788038698328936
# gzsl: unseen=0.0820 , seen=0.4496 , h=0.1387
# ____________________________________________________________________________________________________
# episode: 145000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3264731750219877
# gzsl: unseen=0.0828 , seen=0.4484 , h=0.1399
# ____________________________________________________________________________________________________
# episode: 146000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3259454705364996
# gzsl: unseen=0.0818 , seen=0.4498 , h=0.1384
# ____________________________________________________________________________________________________
# episode: 147000 loss tensor(1.00000e-03 *
#        1.0732, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3287598944591029
# gzsl: unseen=0.0825 , seen=0.4522 , h=0.1395
# ____________________________________________________________________________________________________
# episode: 148000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32981530343007914
# gzsl: unseen=0.0816 , seen=0.4522 , h=0.1383
# ____________________________________________________________________________________________________
# episode: 149000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32981530343007914
# gzsl: unseen=0.0795 , seen=0.4453 , h=0.1349
# ____________________________________________________________________________________________________
# episode: 150000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.33403693931398415
# gzsl: unseen=0.0816 , seen=0.4496 , h=0.1382
# ____________________________________________________________________________________________________
# episode: 151000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3333333333333333
# gzsl: unseen=0.0832 , seen=0.4516 , h=0.1405
# ____________________________________________________________________________________________________
# episode: 152000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.33403693931398415
# gzsl: unseen=0.0816 , seen=0.4510 , h=0.1382
# ____________________________________________________________________________________________________
# episode: 153000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3326297273526825
# gzsl: unseen=0.0839 , seen=0.4510 , h=0.1415
# ____________________________________________________________________________________________________
# episode: 154000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3296394019349164
# gzsl: unseen=0.0806 , seen=0.4461 , h=0.1365
# ____________________________________________________________________________________________________
# episode: 155000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32999120492524187
# gzsl: unseen=0.0816 , seen=0.4459 , h=0.1380
# ____________________________________________________________________________________________________
# episode: 156000 loss tensor(1.00000e-03 *
#        1.6587, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3296394019349164
# gzsl: unseen=0.0811 , seen=0.4443 , h=0.1372
# ____________________________________________________________________________________________________
# episode: 157000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3287598944591029
# gzsl: unseen=0.0807 , seen=0.4453 , h=0.1367
# ____________________________________________________________________________________________________
# episode: 158000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.3259454705364996
# gzsl: unseen=0.0811 , seen=0.4472 , h=0.1373
# ____________________________________________________________________________________________________
# episode: 159000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.32770448548812664
# gzsl: unseen=0.0841 , seen=0.4502 , h=0.1417
# ____________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f9c4e182b69c> in <module>()
#      25     batch_attributes = Variable(batch_attributes).cuda(GPU)
#      26
# ---> 27     dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(batch_attributes, batch_features, batch_features_negative)
#      28
#      29     criterion = nn.MarginRankingLoss(margin = Margin).cuda(GPU)
#
# /workspace/wanghai/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /workspace/wanghai/My_ZSL/v0.2.x/my_net_3.py in forward(self, x, y, z)
#      55     def forward(self, x, y, z):
#      56         embedded_x = self.embeddingnet(self.embeddingnet_att(x))
# ---> 57         embedded_y = self.embeddingnet(y)
#      58         embedded_z = self.embeddingnet(z)
#      59         dist_a = F.pairwise_distance(embedded_x, embedded_y, 2)
#
# /workspace/wanghai/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /workspace/wanghai/My_ZSL/v0.2.x/my_net_3.py in forward(self, x)
#      41         x = F.sigmoid(self.fc1(x))      #activate
#      42        # x = F.dropout(x)
# ---> 43         x = F.sigmoid(self.fc2(x))   #sigmoid tanh
#      44
#      45         #x = F.sigmoid(self.fc3(x))
#
# /workspace/wanghai/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /workspace/wanghai/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def extra_repr(self):
#
# /workspace/wanghai/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     990     if input.dim() == 2 and bias is not None:
#     991         # fused op is marginally faster
# --> 992         return torch.addmm(bias, input, weight.t())
#     993
#     994     output = input.matmul(weight.t())
#
# KeyboardInterrupt:
