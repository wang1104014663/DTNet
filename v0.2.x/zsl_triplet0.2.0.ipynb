# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os
from tensorboardX import SummaryWriter

# %%
BATCH_SIZE = 128
EPISODE = 500000
TEST_EPISODE = 1000
LEARNING_RATE =1e-5
Nom = 1e-5
Weight_Deacy = 1e-5
GPU = 0
Margin = 1

# %%
print("init dataset")
##################################参数##################################################################
dataroot = '../data'
dataset = 'AwA1_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'original_att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个

########################add negative pairs#######################
#x_negative = np.empty_like(x)
#x_negative_label = np.empty_like(train_label)
#print(x.shape[0])

#for i in range(x.shape[0]):
#    pick=np.random.choice(np.where(train_label[i]!=train_id)[0], replace=True)
#    x_negative[i] = x[pick]
#    x_negative_label[i] = train_label[pick]
    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
#train_negative_label = torch.from_numpy(x_negative_label).unsqueeze(1)
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
#print(all_attributes)
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net_3 import AttributeNetwork
from my_net_3 import TripletNetwork
from my_net_3 import MetricNetwork

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(85,1024,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
metric_network = MetricNetwork(2048,1024,2048)
triplet_network = TripletNetwork(attribute_network, metric_network)  #metric learning   
triplet_network.cuda(GPU)   
#attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
#优化器adam 学习率 正则1e-5

#attribute_network_scheduler = StepLR(attribute_network_optim, step_size=200000, gamma=0.5)
#学习率每200k步 乘0.5
triplet_network_optim = torch.optim.Adam(triplet_network.parameters(), lr=LEARNING_RATE,weight_decay=Weight_Deacy)
#
#triplet_network_optim = torch.optim.SGD(triplet_network.parameters(), lr=LEARNING_RATE,momentum=0.9 , 
#                                         weight_decay=Weight_Deacy)
triplet_network_scheduler = StepLR(triplet_network_optim , step_size=200000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = metric_network(Variable(batch_features_ext).cuda(GPU).float())  # 32*1024

        #print(batch_features_ext)

        sample_features = metric_network(attribute_network(Variable(sample_attributes).cuda(GPU).float()))
        sample_features_ext = sample_features.repeat(batch_size, 1)
        #print(sample_features_ext.shape)


        relations = F.pairwise_distance(batch_features_ext, sample_features_ext, 2).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        #print(predict_labels)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

# %%
print(triplet_network)
# Out:
# TripletNetwork(
#   (embeddingnet_att): AttributeNetwork(
#     (fc1): Linear(in_features=85, out_features=1024, bias=True)
#     (fc2): Linear(in_features=1024, out_features=2048, bias=True)
#   )
#   (embeddingnet): MetricNetwork(
#     (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#     (fc2): Linear(in_features=1024, out_features=2048, bias=True)
#   )
# )

# %%
print("training...")
last_accuracy = 0.0
writer = SummaryWriter()
for episode in range(EPISODE):
    #attribute_network.train()
    triplet_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features = train_loader.__iter__().next()
    
    batch_features_negative = np.empty_like(batch_features.numpy())
    
    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_labels.numpy()]).squeeze(1)
    
    batch_features = Variable(batch_features).cuda(GPU).float()  # 32*2048
    
    for i in range(batch_features_negative.shape[0]):
        pick=np.random.choice(np.where(batch_labels.numpy()!=batch_labels.numpy()[i])[0], replace=True)
        batch_features_negative[i] = batch_features[pick]    

    batch_features_negative = torch.from_numpy(batch_features_negative)
    batch_features_negative = Variable(batch_features_negative).cuda(GPU).float()  # 32*2048
    
    #batch_attributes = attribute_network(Variable(batch_attributes).cuda(GPU))
    batch_attributes = Variable(batch_attributes).cuda(GPU)
    
    dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(batch_attributes, batch_features, batch_features_negative)
    
    criterion = nn.MarginRankingLoss(margin = Margin).cuda(GPU)
    
    target = torch.FloatTensor(dista.size()).fill_(-1).cuda(GPU)
    
    
    loss_triplet= criterion(dista, distb, target)
    loss_embedd = embedded_x.norm(2) + embedded_y.norm(2) + embedded_z.norm(2)
    loss = loss_triplet + Nom * loss_embedd

    # update
    triplet_network.zero_grad()
    loss.backward()
    triplet_network_optim.step()
    
    if (episode+1)%1000 == 0:
        print("episode:", episode+1, "loss", loss)
        writer.add_scalar('data/loss', loss, episode)
    if (episode+1)%1000 == 0:
        print("Testing...")
        #attribute_network.eval()
        zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(50), attributes)
        gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(50), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        print('zsl:', zsl_accuracy)
        print('gzsl: unseen=%.4f , seen=%.4f , h=%.4f' % (gzsl_unseen_accuracy , gzsl_seen_accuracy, H))
        print('_'*100)
        writer.add_scalar('data/zsl_accuracy', zsl_accuracy, episode)
        writer.add_scalar('data/gzsl_unseen_accuracy', gzsl_unseen_accuracy, episode)
        writer.add_scalar('data/gzsl_seen_accuracy', gzsl_seen_accuracy, episode)
        writer.add_scalar('data/H', H, episode)
writer.export_scalars_to_json("./test.json")
writer.close()
# Out:
# training...
# episode: 1000 loss tensor(1.00000e-02 *
#        5.7284, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.423570800351803
# gzsl: unseen=0.2310 , seen=0.5948 , h=0.3327
# ____________________________________________________________________________________________________
# episode: 2000 loss tensor(1.00000e-02 *
#        4.4071, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.44450307827616536
# gzsl: unseen=0.2262 , seen=0.6509 , h=0.3357
# ____________________________________________________________________________________________________
# episode: 3000 loss tensor(1.00000e-02 *
#        5.2074, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.4914687774846086
# gzsl: unseen=0.2433 , seen=0.6843 , h=0.3589
# ____________________________________________________________________________________________________
# episode: 4000 loss tensor(1.00000e-02 *
#        5.5884, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.46824978012313107
# gzsl: unseen=0.2413 , seen=0.7162 , h=0.3610
# ____________________________________________________________________________________________________
# episode: 5000 loss tensor(1.00000e-02 *
#        1.4664, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5203166226912929
# gzsl: unseen=0.2507 , seen=0.7227 , h=0.3722
# ____________________________________________________________________________________________________
# episode: 6000 loss tensor(1.00000e-02 *
#        1.6067, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5182058047493404
# gzsl: unseen=0.2570 , seen=0.7322 , h=0.3804
# ____________________________________________________________________________________________________
# episode: 7000 loss tensor(1.00000e-02 *
#        3.4132, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5366754617414248
# gzsl: unseen=0.2524 , seen=0.7451 , h=0.3771
# ____________________________________________________________________________________________________
# episode: 8000 loss tensor(1.00000e-02 *
#        2.8456, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5454705364995602
# gzsl: unseen=0.2679 , seen=0.7453 , h=0.3941
# ____________________________________________________________________________________________________
# episode: 9000 loss tensor(1.00000e-02 *
#        2.1134, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5574318381706245
# gzsl: unseen=0.2793 , seen=0.7473 , h=0.4067
# ____________________________________________________________________________________________________
# episode: 10000 loss tensor(1.00000e-02 *
#        3.2072, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5277044854881267
# gzsl: unseen=0.2698 , seen=0.7557 , h=0.3977
# ____________________________________________________________________________________________________
# episode: 11000 loss tensor(1.00000e-03 *
#        9.0416, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.533509234828496
# gzsl: unseen=0.2726 , seen=0.7701 , h=0.4027
# ____________________________________________________________________________________________________
# episode: 12000 loss tensor(1.00000e-03 *
#        4.8982, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5472295514511873
# gzsl: unseen=0.2748 , seen=0.7624 , h=0.4039
# ____________________________________________________________________________________________________
# episode: 13000 loss tensor(1.00000e-02 *
#        1.4312, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5503957783641161
# gzsl: unseen=0.2646 , seen=0.7693 , h=0.3937
# ____________________________________________________________________________________________________
# episode: 14000 loss tensor(1.00000e-02 *
#        3.4670, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5586631486367634
# gzsl: unseen=0.2872 , seen=0.7711 , h=0.4186
# ____________________________________________________________________________________________________
# episode: 15000 loss tensor(1.00000e-03 *
#        7.1831, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.561301671064204
# gzsl: unseen=0.2816 , seen=0.7695 , h=0.4123
# ____________________________________________________________________________________________________
# episode: 16000 loss tensor(1.00000e-03 *
#        5.0991, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5604221635883905
# gzsl: unseen=0.2997 , seen=0.7775 , h=0.4327
# ____________________________________________________________________________________________________
# episode: 17000 loss tensor(1.00000e-02 *
#        1.2818, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5440633245382586
# gzsl: unseen=0.2777 , seen=0.7818 , h=0.4099
# ____________________________________________________________________________________________________
# episode: 18000 loss tensor(1.00000e-02 *
#        4.3725, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5590149516270888
# gzsl: unseen=0.2686 , seen=0.7872 , h=0.4005
# ____________________________________________________________________________________________________
# episode: 19000 loss tensor(1.00000e-02 *
#        1.0851, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5766051011433597
# gzsl: unseen=0.2828 , seen=0.7866 , h=0.4161
# ____________________________________________________________________________________________________
# episode: 20000 loss tensor(1.00000e-02 *
#        5.5462, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5727352682497802
# gzsl: unseen=0.3031 , seen=0.7852 , h=0.4373
# ____________________________________________________________________________________________________
# episode: 21000 loss tensor(1.00000e-03 *
#        8.5257, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5704485488126649
# gzsl: unseen=0.2931 , seen=0.7751 , h=0.4253
# ____________________________________________________________________________________________________
# episode: 22000 loss tensor(1.00000e-03 *
#        4.2180, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5806508355321021
# gzsl: unseen=0.3168 , seen=0.7856 , h=0.4515
# ____________________________________________________________________________________________________
# episode: 23000 loss tensor(1.00000e-02 *
#        1.0610, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5723834652594547
# gzsl: unseen=0.3017 , seen=0.7842 , h=0.4357
# ____________________________________________________________________________________________________
# episode: 24000 loss tensor(1.00000e-03 *
#        4.0612, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5542656112576957
# gzsl: unseen=0.2976 , seen=0.7884 , h=0.4321
# ____________________________________________________________________________________________________
# episode: 25000 loss tensor(1.00000e-02 *
#        1.0954, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5815303430079156
# gzsl: unseen=0.2865 , seen=0.7874 , h=0.4202
# ____________________________________________________________________________________________________
# episode: 26000 loss tensor(1.00000e-02 *
#        1.1213, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5609498680738786
# gzsl: unseen=0.2974 , seen=0.7870 , h=0.4317
# ____________________________________________________________________________________________________
# episode: 27000 loss tensor(1.00000e-03 *
#        9.3498, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5744942832014072
# gzsl: unseen=0.3103 , seen=0.7862 , h=0.4450
# ____________________________________________________________________________________________________
# episode: 28000 loss tensor(1.00000e-03 *
#        3.9274, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5586631486367634
# gzsl: unseen=0.2952 , seen=0.7892 , h=0.4296
# ____________________________________________________________________________________________________
# episode: 29000 loss tensor(1.00000e-03 *
#        7.3409, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5572559366754617
# gzsl: unseen=0.2716 , seen=0.7900 , h=0.4042
# ____________________________________________________________________________________________________
# episode: 30000 loss tensor(1.00000e-03 *
#        7.0689, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5525065963060686
# gzsl: unseen=0.2744 , seen=0.8019 , h=0.4089
# ____________________________________________________________________________________________________
# episode: 31000 loss tensor(1.00000e-02 *
#        1.6800, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5621811785400176
# gzsl: unseen=0.2872 , seen=0.7884 , h=0.4211
# ____________________________________________________________________________________________________
# episode: 32000 loss tensor(1.00000e-02 *
#        1.2488, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.584344766930519
# gzsl: unseen=0.2939 , seen=0.7912 , h=0.4286
# ____________________________________________________________________________________________________
# episode: 33000 loss tensor(1.00000e-03 *
#        6.0161, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5815303430079156
# gzsl: unseen=0.3226 , seen=0.7886 , h=0.4579
# ____________________________________________________________________________________________________
# episode: 34000 loss tensor(1.00000e-03 *
#        5.2660, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5634124890061566
# gzsl: unseen=0.3059 , seen=0.7848 , h=0.4402
# ____________________________________________________________________________________________________
# episode: 35000 loss tensor(1.00000e-02 *
#        2.2615, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5848724714160071
# gzsl: unseen=0.2811 , seen=0.7981 , h=0.4158
# ____________________________________________________________________________________________________
# episode: 36000 loss tensor(1.00000e-02 *
#        1.0761, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5630606860158311
# gzsl: unseen=0.2985 , seen=0.7927 , h=0.4337
# ____________________________________________________________________________________________________
# episode: 37000 loss tensor(1.00000e-02 *
#        2.9805, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.580123131046614
# gzsl: unseen=0.2923 , seen=0.7977 , h=0.4279
# ____________________________________________________________________________________________________
# episode: 38000 loss tensor(1.00000e-02 *
#        2.8305, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5639401934916447
# gzsl: unseen=0.2880 , seen=0.8009 , h=0.4236
# ____________________________________________________________________________________________________
# episode: 39000 loss tensor(1.00000e-03 *
#        3.7267, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5674582233948988
# gzsl: unseen=0.3006 , seen=0.8023 , h=0.4374
# ____________________________________________________________________________________________________
# episode: 40000 loss tensor(1.00000e-02 *
#        1.5873, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5855760773966578
# gzsl: unseen=0.2983 , seen=0.7967 , h=0.4341
# ____________________________________________________________________________________________________
# episode: 41000 loss tensor(1.00000e-03 *
#        3.5486, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5692172383465259
# gzsl: unseen=0.3015 , seen=0.7919 , h=0.4367
# ____________________________________________________________________________________________________
# episode: 42000 loss tensor(1.00000e-03 *
#        3.4915, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5665787159190853
# gzsl: unseen=0.3054 , seen=0.8021 , h=0.4423
# ____________________________________________________________________________________________________
# episode: 43000 loss tensor(1.00000e-03 *
#        8.8793, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5748460861917326
# gzsl: unseen=0.3339 , seen=0.7921 , h=0.4697
# ____________________________________________________________________________________________________
# episode: 44000 loss tensor(1.00000e-02 *
#        1.0255, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.586103781882146
# gzsl: unseen=0.3180 , seen=0.7916 , h=0.4538
# ____________________________________________________________________________________________________
# episode: 45000 loss tensor(1.00000e-03 *
#        3.5219, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.575197889182058
# gzsl: unseen=0.3263 , seen=0.8001 , h=0.4636
# ____________________________________________________________________________________________________
# episode: 46000 loss tensor(1.00000e-02 *
#        1.9208, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5919085312225154
# gzsl: unseen=0.3191 , seen=0.7989 , h=0.4560
# ____________________________________________________________________________________________________
# episode: 47000 loss tensor(1.00000e-03 *
#        3.5933, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.575197889182058
# gzsl: unseen=0.3281 , seen=0.8092 , h=0.4668
# ____________________________________________________________________________________________________
# episode: 48000 loss tensor(1.00000e-03 *
#        6.8538, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5780123131046614
# gzsl: unseen=0.3231 , seen=0.8054 , h=0.4612
# ____________________________________________________________________________________________________
# episode: 49000 loss tensor(1.00000e-03 *
#        3.5072, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5929639401934916
# gzsl: unseen=0.3409 , seen=0.8003 , h=0.4781
# ____________________________________________________________________________________________________
# episode: 50000 loss tensor(1.00000e-03 *
#        3.4247, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6029903254177661
# gzsl: unseen=0.3325 , seen=0.8122 , h=0.4718
# ____________________________________________________________________________________________________
# episode: 51000 loss tensor(1.00000e-03 *
#        6.0459, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5998240985048373
# gzsl: unseen=0.3407 , seen=0.8082 , h=0.4794
# ____________________________________________________________________________________________________
# episode: 52000 loss tensor(1.00000e-03 *
#        3.5708, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5989445910290238
# gzsl: unseen=0.3245 , seen=0.8084 , h=0.4631
# ____________________________________________________________________________________________________
# episode: 53000 loss tensor(1.00000e-02 *
#        1.7829, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5875109938434476
# gzsl: unseen=0.3379 , seen=0.8007 , h=0.4753
# ____________________________________________________________________________________________________
# episode: 54000 loss tensor(1.00000e-02 *
#        1.6214, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5938434476693052
# gzsl: unseen=0.3318 , seen=0.8108 , h=0.4708
# ____________________________________________________________________________________________________
# episode: 55000 loss tensor(1.00000e-02 *
#        1.3077, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5934916446789797
# gzsl: unseen=0.3369 , seen=0.8098 , h=0.4758
# ____________________________________________________________________________________________________
# episode: 56000 loss tensor(1.00000e-03 *
#        4.7615, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5919085312225154
# gzsl: unseen=0.3548 , seen=0.8044 , h=0.4924
# ____________________________________________________________________________________________________
# episode: 57000 loss tensor(1.00000e-03 *
#        3.2664, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5838170624450307
# gzsl: unseen=0.3219 , seen=0.8088 , h=0.4605
# ____________________________________________________________________________________________________
# episode: 58000 loss tensor(1.00000e-03 *
#        6.0496, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5815303430079156
# gzsl: unseen=0.3420 , seen=0.8038 , h=0.4798
# ____________________________________________________________________________________________________
# episode: 59000 loss tensor(1.00000e-03 *
#        3.3158, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5792436235708004
# gzsl: unseen=0.3363 , seen=0.8078 , h=0.4749
# ____________________________________________________________________________________________________
# episode: 60000 loss tensor(1.00000e-03 *
#        9.3097, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5887423043095866
# gzsl: unseen=0.3523 , seen=0.8076 , h=0.4906
# ____________________________________________________________________________________________________
# episode: 61000 loss tensor(1.00000e-02 *
#        1.9761, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5824098504837291
# gzsl: unseen=0.3520 , seen=0.8060 , h=0.4900
# ____________________________________________________________________________________________________
# episode: 62000 loss tensor(1.00000e-03 *
#        3.2044, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5931398416886543
# gzsl: unseen=0.3543 , seen=0.8104 , h=0.4930
# ____________________________________________________________________________________________________
# episode: 63000 loss tensor(1.00000e-03 *
#        3.2142, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6112576956904133
# gzsl: unseen=0.3414 , seen=0.8187 , h=0.4819
# ____________________________________________________________________________________________________
# episode: 64000 loss tensor(1.00000e-03 *
#        6.0487, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6216358839050132
# gzsl: unseen=0.3560 , seen=0.8142 , h=0.4954
# ____________________________________________________________________________________________________
# episode: 65000 loss tensor(1.00000e-03 *
#        5.9122, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6102022867194371
# gzsl: unseen=0.3734 , seen=0.8072 , h=0.5106
# ____________________________________________________________________________________________________
# episode: 66000 loss tensor(1.00000e-02 *
#        2.5678, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5864555848724714
# gzsl: unseen=0.3196 , seen=0.7983 , h=0.4565
# ____________________________________________________________________________________________________
# episode: 67000 loss tensor(1.00000e-03 *
#        3.1754, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6045734388742304
# gzsl: unseen=0.3536 , seen=0.7975 , h=0.4899
# ____________________________________________________________________________________________________
# episode: 68000 loss tensor(1.00000e-03 *
#        9.3765, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5744942832014072
# gzsl: unseen=0.3117 , seen=0.8122 , h=0.4505
# ____________________________________________________________________________________________________
# episode: 69000 loss tensor(1.00000e-03 *
#        3.1685, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.565523306948109
# gzsl: unseen=0.3208 , seen=0.8108 , h=0.4598
# ____________________________________________________________________________________________________
# episode: 70000 loss tensor(1.00000e-03 *
#        6.9912, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5987686895338611
# gzsl: unseen=0.3523 , seen=0.8118 , h=0.4914
# ____________________________________________________________________________________________________
# episode: 71000 loss tensor(1.00000e-03 *
#        9.5950, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6028144239226033
# gzsl: unseen=0.3696 , seen=0.8033 , h=0.5062
# ____________________________________________________________________________________________________
# episode: 72000 loss tensor(1.00000e-03 *
#        5.3302, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6189973614775726
# gzsl: unseen=0.3467 , seen=0.8136 , h=0.4862
# ____________________________________________________________________________________________________
# episode: 73000 loss tensor(1.00000e-03 *
#        7.9276, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6014072119613016
# gzsl: unseen=0.3515 , seen=0.8140 , h=0.4909
# ____________________________________________________________________________________________________
# episode: 74000 loss tensor(1.00000e-02 *
#        1.0122, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6019349164467898
# gzsl: unseen=0.3525 , seen=0.8106 , h=0.4913
# ____________________________________________________________________________________________________
# episode: 75000 loss tensor(1.00000e-03 *
#        6.0308, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.597009674582234
# gzsl: unseen=0.3609 , seen=0.8054 , h=0.4985
# ____________________________________________________________________________________________________
# episode: 76000 loss tensor(1.00000e-03 *
#        3.0792, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.615127528583993
# gzsl: unseen=0.3247 , seen=0.8197 , h=0.4652
# ____________________________________________________________________________________________________
# episode: 77000 loss tensor(1.00000e-03 *
#        5.9168, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5991204925241864
# gzsl: unseen=0.3530 , seen=0.8044 , h=0.4907
# ____________________________________________________________________________________________________
# episode: 78000 loss tensor(1.00000e-03 *
#        5.2015, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5994722955145119
# gzsl: unseen=0.3602 , seen=0.8076 , h=0.4982
# ____________________________________________________________________________________________________
# episode: 79000 loss tensor(1.00000e-03 *
#        3.2837, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6288478452066842
# gzsl: unseen=0.3564 , seen=0.8161 , h=0.4961
# ____________________________________________________________________________________________________
# episode: 80000 loss tensor(1.00000e-02 *
#        1.2308, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6276165347405452
# gzsl: unseen=0.3613 , seen=0.8106 , h=0.4998
# ____________________________________________________________________________________________________
# episode: 81000 loss tensor(1.00000e-03 *
#        3.0088, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6302550571679859
# gzsl: unseen=0.3870 , seen=0.8124 , h=0.5242
# ____________________________________________________________________________________________________
# episode: 82000 loss tensor(1.00000e-03 *
#        2.9229, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6072119613016711
# gzsl: unseen=0.3210 , seen=0.8074 , h=0.4594
# ____________________________________________________________________________________________________
# episode: 83000 loss tensor(1.00000e-03 *
#        3.0425, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5804749340369393
# gzsl: unseen=0.3159 , seen=0.8102 , h=0.4546
# ____________________________________________________________________________________________________
# episode: 84000 loss tensor(1.00000e-03 *
#        5.8582, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6008795074758135
# gzsl: unseen=0.3456 , seen=0.8136 , h=0.4852
# ____________________________________________________________________________________________________
# episode: 85000 loss tensor(1.00000e-03 *
#        2.8790, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6228671943711521
# gzsl: unseen=0.3770 , seen=0.8136 , h=0.5152
# ____________________________________________________________________________________________________
# episode: 86000 loss tensor(1.00000e-03 *
#        4.3587, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6165347405452947
# gzsl: unseen=0.3339 , seen=0.8187 , h=0.4743
# ____________________________________________________________________________________________________
# episode: 87000 loss tensor(1.00000e-03 *
#        6.5777, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6302550571679859
# gzsl: unseen=0.3717 , seen=0.8157 , h=0.5107
# ____________________________________________________________________________________________________
# episode: 88000 loss tensor(1.00000e-03 *
#        2.8294, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6089709762532981
# gzsl: unseen=0.3414 , seen=0.8124 , h=0.4808
# ____________________________________________________________________________________________________
# episode: 89000 loss tensor(1.00000e-03 *
#        2.9059, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6221635883905013
# gzsl: unseen=0.3683 , seen=0.8142 , h=0.5072
# ____________________________________________________________________________________________________
# episode: 90000 loss tensor(1.00000e-03 *
#        2.8200, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6189973614775726
# gzsl: unseen=0.3558 , seen=0.8102 , h=0.4945
# ____________________________________________________________________________________________________
# episode: 91000 loss tensor(1.00000e-03 *
#        2.8349, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6295514511873351
# gzsl: unseen=0.3659 , seen=0.8177 , h=0.5055
# ____________________________________________________________________________________________________
# episode: 92000 loss tensor(1.00000e-03 *
#        2.8025, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6335971855760774
# gzsl: unseen=0.4019 , seen=0.8102 , h=0.5373
# ____________________________________________________________________________________________________
# episode: 93000 loss tensor(1.00000e-03 *
#        2.7404, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6249780123131047
# gzsl: unseen=0.3842 , seen=0.8136 , h=0.5219
# ____________________________________________________________________________________________________
# episode: 94000 loss tensor(1.00000e-03 *
#        3.7920, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6230430958663149
# gzsl: unseen=0.3942 , seen=0.8098 , h=0.5303
# ____________________________________________________________________________________________________
# episode: 95000 loss tensor(1.00000e-02 *
#        1.3462, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6300791556728232
# gzsl: unseen=0.3527 , seen=0.8136 , h=0.4921
# ____________________________________________________________________________________________________
# episode: 96000 loss tensor(1.00000e-03 *
#        5.1956, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6121372031662269
# gzsl: unseen=0.3763 , seen=0.8185 , h=0.5155
# ____________________________________________________________________________________________________
# episode: 97000 loss tensor(1.00000e-03 *
#        2.8055, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6283201407211961
# gzsl: unseen=0.3854 , seen=0.8173 , h=0.5238
# ____________________________________________________________________________________________________
# episode: 98000 loss tensor(1.00000e-03 *
#        2.8304, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6068601583113457
# gzsl: unseen=0.3815 , seen=0.8116 , h=0.5191
# ____________________________________________________________________________________________________
# episode: 99000 loss tensor(1.00000e-02 *
#        1.1203, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6038698328935796
# gzsl: unseen=0.3581 , seen=0.8183 , h=0.4982
# ____________________________________________________________________________________________________
# episode: 100000 loss tensor(1.00000e-03 *
#        2.7788, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6365875109938435
# gzsl: unseen=0.3951 , seen=0.8191 , h=0.5330
# ____________________________________________________________________________________________________
# episode: 101000 loss tensor(1.00000e-03 *
#        3.3549, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6225153913808268
# gzsl: unseen=0.3274 , seen=0.8150 , h=0.4671
# ____________________________________________________________________________________________________
# episode: 102000 loss tensor(1.00000e-03 *
#        5.4257, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6024626209322779
# gzsl: unseen=0.3602 , seen=0.8159 , h=0.4998
# ____________________________________________________________________________________________________
# episode: 103000 loss tensor(1.00000e-02 *
#        1.3248, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5929639401934916
# gzsl: unseen=0.3379 , seen=0.8157 , h=0.4779
# ____________________________________________________________________________________________________
# episode: 104000 loss tensor(1.00000e-03 *
#        7.2888, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6184696569920844
# gzsl: unseen=0.3917 , seen=0.8175 , h=0.5297
# ____________________________________________________________________________________________________
# episode: 105000 loss tensor(1.00000e-03 *
#        2.7605, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6102022867194371
# gzsl: unseen=0.3891 , seen=0.8237 , h=0.5285
# ____________________________________________________________________________________________________
# episode: 106000 loss tensor(1.00000e-03 *
#        2.6936, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6188214599824099
# gzsl: unseen=0.3835 , seen=0.8128 , h=0.5211
# ____________________________________________________________________________________________________
# episode: 107000 loss tensor(1.00000e-03 *
#        6.8150, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6073878627968338
# gzsl: unseen=0.3815 , seen=0.8199 , h=0.5207
# ____________________________________________________________________________________________________
# episode: 108000 loss tensor(1.00000e-03 *
#        2.6562, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.604221635883905
# gzsl: unseen=0.3638 , seen=0.8199 , h=0.5039
# ____________________________________________________________________________________________________
# episode: 109000 loss tensor(1.00000e-03 *
#        2.6774, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6297273526824978
# gzsl: unseen=0.4151 , seen=0.8144 , h=0.5499
# ____________________________________________________________________________________________________
# episode: 110000 loss tensor(1.00000e-03 *
#        3.7543, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6230430958663149
# gzsl: unseen=0.3778 , seen=0.8187 , h=0.5170
# ____________________________________________________________________________________________________
# episode: 111000 loss tensor(1.00000e-03 *
#        5.7411, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6351802990325418
# gzsl: unseen=0.3712 , seen=0.8292 , h=0.5128
# ____________________________________________________________________________________________________
# episode: 112000 loss tensor(1.00000e-03 *
#        3.7555, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6200527704485488
# gzsl: unseen=0.3722 , seen=0.8187 , h=0.5118
# ____________________________________________________________________________________________________
# episode: 113000 loss tensor(1.00000e-03 *
#        2.9901, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5956024626209323
# gzsl: unseen=0.3655 , seen=0.8060 , h=0.5029
# ____________________________________________________________________________________________________
# episode: 114000 loss tensor(1.00000e-03 *
#        2.7359, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6117854001759016
# gzsl: unseen=0.3706 , seen=0.8144 , h=0.5094
# ____________________________________________________________________________________________________
# episode: 115000 loss tensor(1.00000e-03 *
#        2.6197, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6323658751099385
# gzsl: unseen=0.3727 , seen=0.8233 , h=0.5132
# ____________________________________________________________________________________________________
# episode: 116000 loss tensor(1.00000e-03 *
#        2.6168, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.606684256816183
# gzsl: unseen=0.3532 , seen=0.8048 , h=0.4909
# ____________________________________________________________________________________________________
# episode: 117000 loss tensor(1.00000e-03 *
#        3.4874, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6001759014951628
# gzsl: unseen=0.3402 , seen=0.8205 , h=0.4810
# ____________________________________________________________________________________________________
# episode: 118000 loss tensor(1.00000e-03 *
#        4.0702, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6262093227792436
# gzsl: unseen=0.3822 , seen=0.8150 , h=0.5204
# ____________________________________________________________________________________________________
# episode: 119000 loss tensor(1.00000e-02 *
#        1.0322, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5706244503078276
# gzsl: unseen=0.3321 , seen=0.8223 , h=0.4731
# ____________________________________________________________________________________________________
# episode: 120000 loss tensor(1.00000e-03 *
#        2.5841, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6228671943711521
# gzsl: unseen=0.3824 , seen=0.8161 , h=0.5208
# ____________________________________________________________________________________________________
# episode: 121000 loss tensor(1.00000e-03 *
#        2.5334, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6117854001759016
# gzsl: unseen=0.3347 , seen=0.8201 , h=0.4754
# ____________________________________________________________________________________________________
# episode: 122000 loss tensor(1.00000e-03 *
#        2.5069, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6033421284080914
# gzsl: unseen=0.3337 , seen=0.8185 , h=0.4741
# ____________________________________________________________________________________________________
# episode: 123000 loss tensor(1.00000e-03 *
#        3.2675, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6035180299032542
# gzsl: unseen=0.3636 , seen=0.8138 , h=0.5026
# ____________________________________________________________________________________________________
# episode: 124000 loss tensor(1.00000e-03 *
#        2.4655, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6102022867194371
# gzsl: unseen=0.3798 , seen=0.8152 , h=0.5182
# ____________________________________________________________________________________________________
# episode: 125000 loss tensor(1.00000e-03 *
#        2.5034, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6149516270888302
# gzsl: unseen=0.3842 , seen=0.8118 , h=0.5215
# ____________________________________________________________________________________________________
# episode: 126000 loss tensor(1.00000e-03 *
#        2.4879, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6311345646437995
# gzsl: unseen=0.3653 , seen=0.8231 , h=0.5061
# ____________________________________________________________________________________________________
# episode: 127000 loss tensor(1.00000e-03 *
#        2.4978, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6348284960422164
# gzsl: unseen=0.4030 , seen=0.8169 , h=0.5397
# ____________________________________________________________________________________________________
# episode: 128000 loss tensor(1.00000e-03 *
#        2.4628, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6242744063324538
# gzsl: unseen=0.3483 , seen=0.8209 , h=0.4891
# ____________________________________________________________________________________________________
# episode: 129000 loss tensor(1.00000e-03 *
#        2.5142, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6093227792436235
# gzsl: unseen=0.3569 , seen=0.8211 , h=0.4975
# ____________________________________________________________________________________________________
# episode: 130000 loss tensor(1.00000e-03 *
#        2.4807, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6094986807387863
# gzsl: unseen=0.3740 , seen=0.8219 , h=0.5140
# ____________________________________________________________________________________________________
# episode: 131000 loss tensor(1.00000e-03 *
#        3.9176, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6212840809146878
# gzsl: unseen=0.3676 , seen=0.8132 , h=0.5064
# ____________________________________________________________________________________________________
# episode: 132000 loss tensor(1.00000e-03 *
#        2.4445, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6313104661389621
# gzsl: unseen=0.3836 , seen=0.8189 , h=0.5225
# ____________________________________________________________________________________________________
# episode: 133000 loss tensor(1.00000e-03 *
#        2.4905, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.61688654353562
# gzsl: unseen=0.3479 , seen=0.8171 , h=0.4880
# ____________________________________________________________________________________________________
# episode: 134000 loss tensor(1.00000e-03 *
#        2.4543, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6059806508355321
# gzsl: unseen=0.3597 , seen=0.8130 , h=0.4988
# ____________________________________________________________________________________________________
# episode: 135000 loss tensor(1.00000e-03 *
#        5.6087, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6094986807387863
# gzsl: unseen=0.3661 , seen=0.8221 , h=0.5066
# ____________________________________________________________________________________________________
# episode: 136000 loss tensor(1.00000e-03 *
#        2.4335, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5759014951627088
# gzsl: unseen=0.3105 , seen=0.8197 , h=0.4504
# ____________________________________________________________________________________________________
# episode: 137000 loss tensor(1.00000e-03 *
#        2.4272, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.566754617414248
# gzsl: unseen=0.2999 , seen=0.8189 , h=0.4390
# ____________________________________________________________________________________________________
# episode: 138000 loss tensor(1.00000e-03 *
#        4.1180, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5922603342128409
# gzsl: unseen=0.3537 , seen=0.8146 , h=0.4933
# ____________________________________________________________________________________________________
# episode: 139000 loss tensor(1.00000e-03 *
#        2.4123, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5926121372031662
# gzsl: unseen=0.3337 , seen=0.8171 , h=0.4739
# ____________________________________________________________________________________________________
# episode: 140000 loss tensor(1.00000e-03 *
#        6.4670, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5841688654353562
# gzsl: unseen=0.3142 , seen=0.8247 , h=0.4550
# ____________________________________________________________________________________________________
# episode: 141000 loss tensor(1.00000e-03 *
#        2.3828, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5919085312225154
# gzsl: unseen=0.3539 , seen=0.8175 , h=0.4940
# ____________________________________________________________________________________________________
# episode: 142000 loss tensor(1.00000e-03 *
#        2.4013, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5947229551451187
# gzsl: unseen=0.3490 , seen=0.8239 , h=0.4903
# ____________________________________________________________________________________________________
# episode: 143000 loss tensor(1.00000e-03 *
#        4.7278, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.588566402814424
# gzsl: unseen=0.3617 , seen=0.8257 , h=0.5030
# ____________________________________________________________________________________________________
# episode: 144000 loss tensor(1.00000e-03 *
#        7.9805, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6279683377308707
# gzsl: unseen=0.3615 , seen=0.8209 , h=0.5019
# ____________________________________________________________________________________________________
# episode: 145000 loss tensor(1.00000e-03 *
#        5.5110, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5978891820580475
# gzsl: unseen=0.3546 , seen=0.8241 , h=0.4959
# ____________________________________________________________________________________________________
# episode: 146000 loss tensor(1.00000e-03 *
#        7.8064, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.605452946350044
# gzsl: unseen=0.3784 , seen=0.8175 , h=0.5173
# ____________________________________________________________________________________________________
# episode: 147000 loss tensor(1.00000e-03 *
#        2.3868, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6188214599824099
# gzsl: unseen=0.3441 , seen=0.8195 , h=0.4846
# ____________________________________________________________________________________________________
# episode: 148000 loss tensor(1.00000e-03 *
#        3.1130, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6
# gzsl: unseen=0.3488 , seen=0.8245 , h=0.4902
# ____________________________________________________________________________________________________
# episode: 149000 loss tensor(1.00000e-03 *
#        2.9072, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6244503078276166
# gzsl: unseen=0.3763 , seen=0.8223 , h=0.5163
# ____________________________________________________________________________________________________
# episode: 150000 loss tensor(1.00000e-03 *
#        6.0662, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6068601583113457
# gzsl: unseen=0.3604 , seen=0.8237 , h=0.5014
# ____________________________________________________________________________________________________
# episode: 151000 loss tensor(1.00000e-03 *
#        5.5493, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6186455584872471
# gzsl: unseen=0.3516 , seen=0.8257 , h=0.4932
# ____________________________________________________________________________________________________
# episode: 152000 loss tensor(1.00000e-03 *
#        2.3267, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.61688654353562
# gzsl: unseen=0.3713 , seen=0.8241 , h=0.5120
# ____________________________________________________________________________________________________
# episode: 153000 loss tensor(1.00000e-03 *
#        2.3319, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6089709762532981
# gzsl: unseen=0.3799 , seen=0.8114 , h=0.5176
# ____________________________________________________________________________________________________
# episode: 154000 loss tensor(1.00000e-03 *
#        7.6821, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6263852242744063
# gzsl: unseen=0.4018 , seen=0.8193 , h=0.5391
# ____________________________________________________________________________________________________
# episode: 155000 loss tensor(1.00000e-03 *
#        7.1901, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6158311345646438
# gzsl: unseen=0.3926 , seen=0.8167 , h=0.5303
# ____________________________________________________________________________________________________
# episode: 156000 loss tensor(1.00000e-03 *
#        2.7954, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6182937554969217
# gzsl: unseen=0.3757 , seen=0.8263 , h=0.5166
# ____________________________________________________________________________________________________
# episode: 157000 loss tensor(1.00000e-03 *
#        2.2895, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6051011433597185
# gzsl: unseen=0.3502 , seen=0.8324 , h=0.4930
# ____________________________________________________________________________________________________
# episode: 158000 loss tensor(1.00000e-03 *
#        4.8249, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6158311345646438
# gzsl: unseen=0.3822 , seen=0.8231 , h=0.5220
# ____________________________________________________________________________________________________
# episode: 159000 loss tensor(1.00000e-03 *
#        2.2583, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6123131046613897
# gzsl: unseen=0.3713 , seen=0.8257 , h=0.5123
# ____________________________________________________________________________________________________
# episode: 160000 loss tensor(1.00000e-03 *
#        2.2385, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5889182058047493
# gzsl: unseen=0.3541 , seen=0.8171 , h=0.4941
# ____________________________________________________________________________________________________
# episode: 161000 loss tensor(1.00000e-03 *
#        2.2908, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5829375549692173
# gzsl: unseen=0.3407 , seen=0.8183 , h=0.4811
# ____________________________________________________________________________________________________
# episode: 162000 loss tensor(1.00000e-03 *
#        3.8831, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.5880386983289358
# gzsl: unseen=0.3673 , seen=0.8255 , h=0.5084
# ____________________________________________________________________________________________________
# ...
#        2.1116, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6237467018469657
# gzsl: unseen=0.4201 , seen=0.8386 , h=0.5597
# ____________________________________________________________________________________________________
# episode: 448000 loss tensor(1.00000e-03 *
#        6.4112, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6219876868953386
# gzsl: unseen=0.4157 , seen=0.8409 , h=0.5563
# ____________________________________________________________________________________________________
# episode: 449000 loss tensor(1.00000e-03 *
#        4.4183, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6237467018469657
# gzsl: unseen=0.4245 , seen=0.8384 , h=0.5636
# ____________________________________________________________________________________________________
# episode: 450000 loss tensor(1.00000e-03 *
#        1.7745, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6198768689533861
# gzsl: unseen=0.4106 , seen=0.8399 , h=0.5515
# ____________________________________________________________________________________________________
# episode: 451000 loss tensor(1.00000e-03 *
#        1.7591, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6263852242744063
# gzsl: unseen=0.4269 , seen=0.8374 , h=0.5655
# ____________________________________________________________________________________________________
# episode: 452000 loss tensor(1.00000e-03 *
#        2.3394, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6186455584872471
# gzsl: unseen=0.4179 , seen=0.8384 , h=0.5578
# ____________________________________________________________________________________________________
# episode: 453000 loss tensor(1.00000e-03 *
#        2.3373, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6189973614775726
# gzsl: unseen=0.4190 , seen=0.8392 , h=0.5589
# ____________________________________________________________________________________________________
# episode: 454000 loss tensor(1.00000e-03 *
#        1.7619, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6242744063324538
# gzsl: unseen=0.4211 , seen=0.8360 , h=0.5601
# ____________________________________________________________________________________________________
# episode: 455000 loss tensor(1.00000e-03 *
#        1.7645, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6230430958663149
# gzsl: unseen=0.4130 , seen=0.8370 , h=0.5531
# ____________________________________________________________________________________________________
# episode: 456000 loss tensor(1.00000e-03 *
#        2.9402, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6179419525065963
# gzsl: unseen=0.4141 , seen=0.8380 , h=0.5543
# ____________________________________________________________________________________________________
# episode: 457000 loss tensor(1.00000e-03 *
#        1.7321, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6137203166226913
# gzsl: unseen=0.4058 , seen=0.8366 , h=0.5465
# ____________________________________________________________________________________________________
# episode: 458000 loss tensor(1.00000e-03 *
#        2.4423, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6140721196130167
# gzsl: unseen=0.3949 , seen=0.8376 , h=0.5367
# ____________________________________________________________________________________________________
# episode: 459000 loss tensor(1.00000e-03 *
#        2.5846, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6133685136323659
# gzsl: unseen=0.3988 , seen=0.8395 , h=0.5407
# ____________________________________________________________________________________________________
# episode: 460000 loss tensor(1.00000e-03 *
#        1.7295, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6248021108179419
# gzsl: unseen=0.4181 , seen=0.8425 , h=0.5589
# ____________________________________________________________________________________________________
# episode: 461000 loss tensor(1.00000e-03 *
#        8.3842, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6205804749340369
# gzsl: unseen=0.4146 , seen=0.8382 , h=0.5548
# ____________________________________________________________________________________________________
# episode: 462000 loss tensor(1.00000e-03 *
#        1.7479, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.619349164467898
# gzsl: unseen=0.4118 , seen=0.8336 , h=0.5513
# ____________________________________________________________________________________________________
# episode: 463000 loss tensor(1.00000e-03 *
#        1.7375, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6165347405452947
# gzsl: unseen=0.4033 , seen=0.8338 , h=0.5437
# ____________________________________________________________________________________________________
# episode: 464000 loss tensor(1.00000e-03 *
#        1.7392, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6244503078276166
# gzsl: unseen=0.4158 , seen=0.8395 , h=0.5562
# ____________________________________________________________________________________________________
# episode: 465000 loss tensor(1.00000e-03 *
#        1.7442, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6189973614775726
# gzsl: unseen=0.4014 , seen=0.8370 , h=0.5426
# ____________________________________________________________________________________________________
# episode: 466000 loss tensor(1.00000e-03 *
#        1.7436, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6260334212840809
# gzsl: unseen=0.4035 , seen=0.8386 , h=0.5449
# ____________________________________________________________________________________________________
# episode: 467000 loss tensor(1.00000e-03 *
#        2.4577, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6219876868953386
# gzsl: unseen=0.3991 , seen=0.8419 , h=0.5415
# ____________________________________________________________________________________________________
# episode: 468000 loss tensor(1.00000e-03 *
#        2.0117, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.627792436235708
# gzsl: unseen=0.4021 , seen=0.8378 , h=0.5434
# ____________________________________________________________________________________________________
# episode: 469000 loss tensor(1.00000e-03 *
#        2.4531, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6262093227792436
# gzsl: unseen=0.3954 , seen=0.8415 , h=0.5380
# ____________________________________________________________________________________________________
# episode: 470000 loss tensor(1.00000e-03 *
#        1.6984, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6124890061565523
# gzsl: unseen=0.3900 , seen=0.8386 , h=0.5324
# ____________________________________________________________________________________________________
# episode: 471000 loss tensor(1.00000e-03 *
#        2.6296, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6045734388742304
# gzsl: unseen=0.3810 , seen=0.8397 , h=0.5242
# ____________________________________________________________________________________________________
# episode: 472000 loss tensor(1.00000e-03 *
#        1.7622, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6144239226033421
# gzsl: unseen=0.3845 , seen=0.8419 , h=0.5279
# ____________________________________________________________________________________________________
# episode: 473000 loss tensor(1.00000e-03 *
#        1.7218, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6160070360598066
# gzsl: unseen=0.4132 , seen=0.8390 , h=0.5537
# ____________________________________________________________________________________________________
# episode: 474000 loss tensor(1.00000e-03 *
#        1.7607, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6130167106420404
# gzsl: unseen=0.4118 , seen=0.8376 , h=0.5521
# ____________________________________________________________________________________________________
# episode: 475000 loss tensor(1.00000e-03 *
#        1.7368, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6131926121372032
# gzsl: unseen=0.3982 , seen=0.8342 , h=0.5391
# ____________________________________________________________________________________________________
# episode: 476000 loss tensor(1.00000e-03 *
#        2.3183, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6191732629727352
# gzsl: unseen=0.4128 , seen=0.8364 , h=0.5528
# ____________________________________________________________________________________________________
# episode: 477000 loss tensor(1.00000e-03 *
#        5.0970, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.61688654353562
# gzsl: unseen=0.4091 , seen=0.8334 , h=0.5488
# ____________________________________________________________________________________________________
# episode: 478000 loss tensor(1.00000e-03 *
#        2.5210, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6010554089709762
# gzsl: unseen=0.3843 , seen=0.8334 , h=0.5261
# ____________________________________________________________________________________________________
# episode: 479000 loss tensor(1.00000e-03 *
#        9.8326, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6094986807387863
# gzsl: unseen=0.3989 , seen=0.8380 , h=0.5406
# ____________________________________________________________________________________________________
# episode: 480000 loss tensor(1.00000e-03 *
#        1.7100, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6070360598065083
# gzsl: unseen=0.3835 , seen=0.8358 , h=0.5257
# ____________________________________________________________________________________________________
# episode: 481000 loss tensor(1.00000e-03 *
#        1.7598, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6121372031662269
# gzsl: unseen=0.3995 , seen=0.8336 , h=0.5401
# ____________________________________________________________________________________________________
# episode: 482000 loss tensor(1.00000e-03 *
#        1.7171, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6161829375549692
# gzsl: unseen=0.4033 , seen=0.8384 , h=0.5447
# ____________________________________________________________________________________________________
# episode: 483000 loss tensor(1.00000e-03 *
#        1.7340, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6001759014951628
# gzsl: unseen=0.3655 , seen=0.8417 , h=0.5097
# ____________________________________________________________________________________________________
# episode: 484000 loss tensor(1.00000e-03 *
#        6.6220, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6211081794195251
# gzsl: unseen=0.4128 , seen=0.8437 , h=0.5544
# ____________________________________________________________________________________________________
# episode: 485000 loss tensor(1.00000e-03 *
#        1.7044, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.61688654353562
# gzsl: unseen=0.3919 , seen=0.8409 , h=0.5346
# ____________________________________________________________________________________________________
# episode: 486000 loss tensor(1.00000e-03 *
#        1.7183, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6184696569920844
# gzsl: unseen=0.4062 , seen=0.8409 , h=0.5477
# ____________________________________________________________________________________________________
# episode: 487000 loss tensor(1.00000e-03 *
#        4.4270, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.613896218117854
# gzsl: unseen=0.3879 , seen=0.8507 , h=0.5328
# ____________________________________________________________________________________________________
# episode: 488000 loss tensor(1.00000e-03 *
#        1.7366, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6182937554969217
# gzsl: unseen=0.4004 , seen=0.8417 , h=0.5426
# ____________________________________________________________________________________________________
# episode: 489000 loss tensor(1.00000e-03 *
#        1.6963, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6114335971855761
# gzsl: unseen=0.3991 , seen=0.8374 , h=0.5406
# ____________________________________________________________________________________________________
# episode: 490000 loss tensor(1.00000e-03 *
#        2.3845, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6188214599824099
# gzsl: unseen=0.4072 , seen=0.8401 , h=0.5485
# ____________________________________________________________________________________________________
# episode: 491000 loss tensor(1.00000e-03 *
#        1.7357, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6228671943711521
# gzsl: unseen=0.4199 , seen=0.8471 , h=0.5615
# ____________________________________________________________________________________________________
# episode: 492000 loss tensor(1.00000e-03 *
#        1.7583, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6334212840809147
# gzsl: unseen=0.4183 , seen=0.8467 , h=0.5600
# ____________________________________________________________________________________________________
# episode: 493000 loss tensor(1.00000e-03 *
#        1.7513, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6270888302550571
# gzsl: unseen=0.4227 , seen=0.8479 , h=0.5642
# ____________________________________________________________________________________________________
# episode: 494000 loss tensor(1.00000e-03 *
#        2.7579, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6295514511873351
# gzsl: unseen=0.4252 , seen=0.8451 , h=0.5657
# ____________________________________________________________________________________________________
# episode: 495000 loss tensor(1.00000e-03 *
#        7.1752, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6255057167985928
# gzsl: unseen=0.4222 , seen=0.8445 , h=0.5629
# ____________________________________________________________________________________________________
# episode: 496000 loss tensor(1.00000e-03 *
#        1.7476, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6228671943711521
# gzsl: unseen=0.4074 , seen=0.8392 , h=0.5485
# ____________________________________________________________________________________________________
# episode: 497000 loss tensor(1.00000e-03 *
#        1.7179, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6149516270888302
# gzsl: unseen=0.4125 , seen=0.8403 , h=0.5533
# ____________________________________________________________________________________________________
# episode: 498000 loss tensor(1.00000e-03 *
#        5.0894, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6149516270888302
# gzsl: unseen=0.3914 , seen=0.8417 , h=0.5343
# ____________________________________________________________________________________________________
# episode: 499000 loss tensor(1.00000e-03 *
#        1.7189, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6144239226033421
# gzsl: unseen=0.3993 , seen=0.8399 , h=0.5413
# ____________________________________________________________________________________________________
# episode: 500000 loss tensor(1.00000e-03 *
#        1.7092, device='cuda:0')
# Testing...
# class num: 10
# class num: 50
# class num: 50
# zsl: 0.6172383465259454
# gzsl: unseen=0.3898 , seen=0.8421 , h=0.5329
# ____________________________________________________________________________________________________
