# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader,TensorDataset
import torch.utils.data as data
import numpy as np
import scipy.io as sio
import math
import argparse
import random
import os

# %%
BATCH_SIZE = 32
#EPISODE = 500000
EPISODE = 200000
TEST_EPISODE = 1000
LEARNING_RATE =1e-5
GPU = 0
Margin = 0.5

# %%
print("init dataset")
##################################参数##################################################################
dataroot = './data'
dataset = 'AwA1_data'
image_embedding = 'res101'               #ResNet101层
class_embedding = 'original_att'         #属性表达 85-d
#######################################读取视觉特征###################################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")  #scipy loadmat
 
feature = matcontent['features'].T         #转置 30478x2048 每一行是一个完整的样本

label = matcontent['labels'].astype(int).squeeze() - 1   #matlab begin 1 ,numpy begin 0
########################################读取属性特征###########################################################

matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + class_embedding + "_splits.mat")

    
# numpy array index starts from 0, matlab starts from 1
trainval_loc = matcontent['trainval_loc'].squeeze() - 1    #squeeze()去掉维度中的1 AxBx1 --->AxB

test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1

attribute = matcontent['att'].T    #转置 50x85 每行是整个属性向量

x = feature[trainval_loc]                      # train_features trainval里面是图片的编号 begin with 0 ，19832个
train_label = label[trainval_loc].astype(int)  # train_label  int类型没变 每个图片的lable 19832个
train_id = np.unique(train_label)

att = attribute[train_label]                   # train attributes 每个图片的属性 19832个

########################add negative pairs#######################
#x_negative = np.empty_like(x)
#x_negative_label = np.empty_like(train_label)
#print(x.shape[0])

#for i in range(x.shape[0]):
#    pick=np.random.choice(np.where(train_label[i]!=train_id)[0], replace=True)
#    x_negative[i] = x[pick]
#    x_negative_label[i] = train_label[pick]
    
x_test = feature[test_unseen_loc]                   # test_feature 5685个
test_label = label[test_unseen_loc].astype(int)     # test_label   5685个

x_test_seen = feature[test_seen_loc]                #test_seen_feature 4958个
test_label_seen = label[test_seen_loc].astype(int)  # test_seen_label  4958个
    
test_id = np.unique(test_label)                     # test_id  10个类 ，unique去重
att_pro = attribute[test_id]                        # test_attribute 每一类的属性向量 10x85

# train set
train_features = torch.from_numpy(x)   #np-->tensor
#train_fearures_negative = torch.from_numpy(x_negative)

sample_attributes=[]
train_label = torch.from_numpy(train_label).unsqueeze(1) #每张图片的属性转化 ，unsqueeze(1)就是插入到第一维度 AxB维-->Ax1xB
#train_negative_label = torch.from_numpy(x_negative_label).unsqueeze(1)
# attributes
all_attributes = np.array(attribute)  #所有50类属性转变为numpy数组???属性向量仍然用的numpy类型 没有转化为pytorch
#print(all_attributes)
    
#print('-'*50)
attributes = torch.from_numpy(attribute) 
#print(attribute)
# test set

test_features = torch.from_numpy(x_test)
#print(test_features.shape)

test_label = torch.from_numpy(test_label).unsqueeze(1)
#print(test_label.shape)

testclasses_id = np.array(test_id)
#print(testclasses_id.shape)

test_attributes = torch.from_numpy(att_pro).float()
#print(test_attributes.shape)

test_seen_features = torch.from_numpy(x_test_seen)
#print(test_seen_features.shape)

test_seen_label = torch.from_numpy(test_label_seen)

train_data = TensorDataset( train_label, train_features )
#train_data = TensorDataset(train_label, train_features, train_fearures_negative)

#################here need new code to make triplet data#####################
print('-'*100)
# Out:
# init dataset
# ----------------------------------------------------------------------------------------------------

# %%
from my_net import AttributeNetwork
from my_net import TripletNetwork

# %%
# init network
print("init networks")
attribute_network = AttributeNetwork(85,1024,2048)  #85d属性 1024隐藏层 2048输出 85d到2048d
#triplet_network = TripletNetwork(attribute_network)  #metric learning   
attribute_network.cuda(GPU)   
#attribute_network_optim = torch.optim.Adam(attribute_network.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
#优化器adam 学习率 正则1e-5

#attribute_network_scheduler = StepLR(attribute_network_optim, step_size=200000, gamma=0.5)
#学习率每200k步 乘0.5
#triplet_network_optim = torch.optim.Adam(triplet_network.parameters(), lr=LEARNING_RATE)
#
attribute_network_optim = torch.optim.SGD(attribute_network.parameters(), lr=LEARNING_RATE, momentum=0.5)
attribute_network_scheduler = StepLR(attribute_network_optim , step_size=200000 , gamma=0.5)
#
print('-'*100)
# Out:
# init networks
# ----------------------------------------------------------------------------------------------------

# %%
print("training...")
last_accuracy = 0.0
for episode in range(EPISODE):
   
    attribute_network_scheduler.step(episode)

    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

    batch_labels, batch_features  = train_loader.__iter__().next()
    
    batch_features_negative = np.empty_like(batch_features.numpy())
    
    batch_attributes = torch.Tensor([all_attributes[i] for i in batch_labels.numpy()]).squeeze(1)
    
    batch_features = Variable(batch_features).cuda(GPU).float()  # 32*2048
    
    
   
    for i in range(batch_features_negative.shape[0]):
        pick=np.random.choice(np.where(batch_labels.numpy()[i]!=train_id)[0], replace=True)
        batch_features_negative[i] = x[pick]
        
    batch_features_negative = torch.from_numpy(batch_features_negative)
    batch_features_negative = Variable(batch_features_negative).cuda(GPU).float()  # 32*2048
    
    batch_attributes = attribute_network(Variable(batch_attributes).cuda(GPU))
    #batch_attributes = Variable(batch_attributes).cuda(GPU)
    #dista, distb, embedded_x, embedded_y, embedded_z = triplet_network(data1, data2, data3)
    criterion = nn.TripletMarginLoss(margin = Margin).cuda(GPU)
    
    
    loss_triplet= criterion(batch_attributes, batch_features, batch_features_negative)
    loss = loss_triplet #+ 0.001 * loss_embedd

    # update
    attribute_network.zero_grad()
    loss.backward()
    attribute_network_optim.step()
    
    if (episode+1)%500 == 0:
        print("episode:", episode+1, "loss", loss.data)
    if (episode+1)%2000 == 0:
        print("Testing...")
        zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
        gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(50), attributes)
        gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(50), attributes)
        H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)
        print('zsl:', zsl_accuracy)
        print('gzsl: seen=%.4f, unseen=%.4f, h=%.4f' % (gzsl_seen_accuracy, gzsl_unseen_accuracy, H))
        print('_'*100)
# Out:
# training...
# episode: 500 loss tensor(1.2644, device='cuda:0')
# episode: 1000 loss tensor(0.9848, device='cuda:0')
# episode: 1500 loss tensor(1.0662, device='cuda:0')
# episode: 2000 loss tensor(0.6291, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.04591029023746702
# gzsl: seen=0.0280, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 2500 loss tensor(0.5019, device='cuda:0')
# episode: 3000 loss tensor(0.4652, device='cuda:0')
# episode: 3500 loss tensor(0.7310, device='cuda:0')
# episode: 4000 loss tensor(0.4027, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.04591029023746702
# gzsl: seen=0.0280, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 4500 loss tensor(0.4172, device='cuda:0')
# episode: 5000 loss tensor(0.3885, device='cuda:0')
# episode: 5500 loss tensor(0.1529, device='cuda:0')
# episode: 6000 loss tensor(0.1462, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.046262093227792435
# gzsl: seen=0.0280, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 6500 loss tensor(0.2570, device='cuda:0')
# episode: 7000 loss tensor(0.4206, device='cuda:0')
# episode: 7500 loss tensor(0.2118, device='cuda:0')
# episode: 8000 loss tensor(1.00000e-02 *
#        9.2156, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.06367634124890062
# gzsl: seen=0.0280, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 8500 loss tensor(0.1652, device='cuda:0')
# episode: 9000 loss tensor(1.00000e-02 *
#        8.4693, device='cuda:0')
# episode: 9500 loss tensor(1.00000e-02 *
#        8.6246, device='cuda:0')
# episode: 10000 loss tensor(0.2113, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.1386103781882146
# gzsl: seen=0.0280, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 10500 loss tensor(1.00000e-02 *
#        5.7248, device='cuda:0')
# episode: 11000 loss tensor(1.00000e-02 *
#        5.6245, device='cuda:0')
# episode: 11500 loss tensor(1.00000e-02 *
#        6.4206, device='cuda:0')
# episode: 12000 loss tensor(0.1480, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.15285839929639403
# gzsl: seen=0.0288, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 12500 loss tensor(0.1062, device='cuda:0')
# episode: 13000 loss tensor(0.1343, device='cuda:0')
# episode: 13500 loss tensor(1.00000e-02 *
#        6.6303, device='cuda:0')
# episode: 14000 loss tensor(1.00000e-02 *
#        2.7549, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.15145118733509236
# gzsl: seen=0.0301, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 14500 loss tensor(0.1431, device='cuda:0')
# episode: 15000 loss tensor(1.00000e-02 *
#        8.7148, device='cuda:0')
# episode: 15500 loss tensor(1.00000e-02 *
#        1.8736, device='cuda:0')
# episode: 16000 loss tensor(1.00000e-02 *
#        4.9223, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.14810905892700088
# gzsl: seen=0.0301, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 16500 loss tensor(1.00000e-02 *
#        7.4866, device='cuda:0')
# episode: 17000 loss tensor(1.00000e-02 *
#        4.0067, device='cuda:0')
# episode: 17500 loss tensor(0.1141, device='cuda:0')
# episode: 18000 loss tensor(1.00000e-02 *
#        3.5733, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.14547053649956024
# gzsl: seen=0.0296, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 18500 loss tensor(1.00000e-02 *
#        7.1337, device='cuda:0')
# episode: 19000 loss tensor(1.00000e-02 *
#        4.8651, device='cuda:0')
# episode: 19500 loss tensor(1.00000e-02 *
#        4.1613, device='cuda:0')
# episode: 20000 loss tensor(1.00000e-02 *
#        6.7237, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.14335971855760773
# gzsl: seen=0.0301, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 20500 loss tensor(1.00000e-02 *
#        5.3034, device='cuda:0')
# episode: 21000 loss tensor(1.00000e-02 *
#        2.7748, device='cuda:0')
# episode: 21500 loss tensor(1.00000e-02 *
#        9.7756, device='cuda:0')
# episode: 22000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.1405452946350044
# gzsl: seen=0.0309, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 22500 loss tensor(1.00000e-02 *
#        3.6465, device='cuda:0')
# episode: 23000 loss tensor(1.00000e-03 *
#        3.3646, device='cuda:0')
# episode: 23500 loss tensor(1.00000e-02 *
#        5.9823, device='cuda:0')
# episode: 24000 loss tensor(1.00000e-02 *
#        3.2656, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.13948988566402815
# gzsl: seen=0.0307, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 24500 loss tensor(1.00000e-02 *
#        8.6977, device='cuda:0')
# episode: 25000 loss tensor(1.00000e-02 *
#        1.7294, device='cuda:0')
# episode: 25500 loss tensor(1.00000e-03 *
#        8.6374, device='cuda:0')
# episode: 26000 loss tensor(1.00000e-02 *
#        6.0871, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.13896218117854
# gzsl: seen=0.0311, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 26500 loss tensor(1.00000e-02 *
#        9.9994, device='cuda:0')
# episode: 27000 loss tensor(1.00000e-02 *
#        3.6120, device='cuda:0')
# episode: 27500 loss tensor(1.00000e-02 *
#        4.1863, device='cuda:0')
# episode: 28000 loss tensor(1.00000e-02 *
#        3.2505, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.13896218117854
# gzsl: seen=0.0317, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 28500 loss tensor(1.00000e-02 *
#        5.9067, device='cuda:0')
# episode: 29000 loss tensor(0., device='cuda:0')
# episode: 29500 loss tensor(0.1441, device='cuda:0')
# episode: 30000 loss tensor(1.00000e-03 *
#        6.6423, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.13948988566402815
# gzsl: seen=0.0321, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 30500 loss tensor(1.00000e-02 *
#        2.3687, device='cuda:0')
# episode: 31000 loss tensor(1.00000e-02 *
#        1.0157, device='cuda:0')
# episode: 31500 loss tensor(1.00000e-02 *
#        4.1925, device='cuda:0')
# episode: 32000 loss tensor(1.00000e-02 *
#        6.2165, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.1386103781882146
# gzsl: seen=0.0329, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 32500 loss tensor(0., device='cuda:0')
# episode: 33000 loss tensor(1.00000e-02 *
#        3.0615, device='cuda:0')
# episode: 33500 loss tensor(1.00000e-02 *
#        9.0203, device='cuda:0')
# episode: 34000 loss tensor(1.00000e-02 *
#        7.7307, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.13966578715919084
# gzsl: seen=0.0331, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 34500 loss tensor(0.1026, device='cuda:0')
# episode: 35000 loss tensor(1.00000e-02 *
#        4.4502, device='cuda:0')
# episode: 35500 loss tensor(1.00000e-02 *
#        2.8292, device='cuda:0')
# episode: 36000 loss tensor(1.00000e-02 *
#        3.5089, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.13913808267370273
# gzsl: seen=0.0331, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 36500 loss tensor(1.00000e-03 *
#        8.7471, device='cuda:0')
# episode: 37000 loss tensor(1.00000e-02 *
#        5.3955, device='cuda:0')
# episode: 37500 loss tensor(1.00000e-02 *
#        3.5053, device='cuda:0')
# episode: 38000 loss tensor(1.00000e-02 *
#        2.9235, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.14036939313984167
# gzsl: seen=0.0329, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 38500 loss tensor(1.00000e-02 *
#        3.5495, device='cuda:0')
# episode: 39000 loss tensor(0.1019, device='cuda:0')
# episode: 39500 loss tensor(1.00000e-02 *
#        4.0469, device='cuda:0')
# episode: 40000 loss tensor(1.00000e-03 *
#        8.3389, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.1421284080914688
# gzsl: seen=0.0333, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 40500 loss tensor(1.00000e-02 *
#        4.9336, device='cuda:0')
# episode: 41000 loss tensor(1.00000e-03 *
#        7.8287, device='cuda:0')
# episode: 41500 loss tensor(1.00000e-02 *
#        1.2654, device='cuda:0')
# episode: 42000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.144415127528584
# gzsl: seen=0.0333, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 42500 loss tensor(1.00000e-02 *
#        3.4503, device='cuda:0')
# episode: 43000 loss tensor(1.00000e-02 *
#        2.0657, device='cuda:0')
# episode: 43500 loss tensor(1.00000e-02 *
#        1.8465, device='cuda:0')
# episode: 44000 loss tensor(0.1402, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.1465259454705365
# gzsl: seen=0.0333, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 44500 loss tensor(1.00000e-02 *
#        1.4451, device='cuda:0')
# episode: 45000 loss tensor(1.00000e-02 *
#        2.8021, device='cuda:0')
# episode: 45500 loss tensor(1.00000e-02 *
#        2.0391, device='cuda:0')
# episode: 46000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.148636763412489
# gzsl: seen=0.0335, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 46500 loss tensor(1.00000e-02 *
#        5.1950, device='cuda:0')
# episode: 47000 loss tensor(0.1083, device='cuda:0')
# episode: 47500 loss tensor(1.00000e-02 *
#        6.8455, device='cuda:0')
# episode: 48000 loss tensor(1.00000e-02 *
#        3.1579, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.15162708883025505
# gzsl: seen=0.0337, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 48500 loss tensor(1.00000e-02 *
#        4.1663, device='cuda:0')
# episode: 49000 loss tensor(1.00000e-02 *
#        3.7063, device='cuda:0')
# episode: 49500 loss tensor(1.00000e-02 *
#        4.2675, device='cuda:0')
# episode: 50000 loss tensor(1.00000e-03 *
#        1.7362, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.15408970976253297
# gzsl: seen=0.0341, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 50500 loss tensor(0., device='cuda:0')
# episode: 51000 loss tensor(1.00000e-02 *
#        4.6606, device='cuda:0')
# episode: 51500 loss tensor(1.00000e-03 *
#        3.2582, device='cuda:0')
# episode: 52000 loss tensor(1.00000e-02 *
#        1.1117, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.15883905013192612
# gzsl: seen=0.0339, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 52500 loss tensor(1.00000e-02 *
#        1.6366, device='cuda:0')
# episode: 53000 loss tensor(0., device='cuda:0')
# episode: 53500 loss tensor(1.00000e-02 *
#        2.5414, device='cuda:0')
# episode: 54000 loss tensor(1.00000e-03 *
#        4.7340, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.16200527704485487
# gzsl: seen=0.0341, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 54500 loss tensor(1.00000e-02 *
#        1.2538, device='cuda:0')
# episode: 55000 loss tensor(1.00000e-03 *
#        9.3307, device='cuda:0')
# episode: 55500 loss tensor(0., device='cuda:0')
# episode: 56000 loss tensor(1.00000e-02 *
#        2.4980, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.16710642040457344
# gzsl: seen=0.0335, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 56500 loss tensor(1.00000e-02 *
#        3.0097, device='cuda:0')
# episode: 57000 loss tensor(1.00000e-02 *
#        1.2385, device='cuda:0')
# episode: 57500 loss tensor(0., device='cuda:0')
# episode: 58000 loss tensor(1.00000e-04 *
#        3.9101, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.16974494283201408
# gzsl: seen=0.0331, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 58500 loss tensor(1.00000e-03 *
#        9.2607, device='cuda:0')
# episode: 59000 loss tensor(1.00000e-02 *
#        4.6966, device='cuda:0')
# episode: 59500 loss tensor(1.00000e-02 *
#        1.9592, device='cuda:0')
# episode: 60000 loss tensor(1.00000e-02 *
#        2.2176, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.17554969217238348
# gzsl: seen=0.0331, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 60500 loss tensor(1.00000e-02 *
#        2.7828, device='cuda:0')
# episode: 61000 loss tensor(1.00000e-02 *
#        1.9780, device='cuda:0')
# episode: 61500 loss tensor(1.00000e-02 *
#        3.9616, device='cuda:0')
# episode: 62000 loss tensor(1.00000e-03 *
#        4.8361, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.18328935795954265
# gzsl: seen=0.0331, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 62500 loss tensor(1.00000e-02 *
#        3.3572, device='cuda:0')
# episode: 63000 loss tensor(1.00000e-02 *
#        3.0541, device='cuda:0')
# episode: 63500 loss tensor(1.00000e-02 *
#        5.0638, device='cuda:0')
# episode: 64000 loss tensor(1.00000e-03 *
#        6.6323, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.19050131926121372
# gzsl: seen=0.0333, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 64500 loss tensor(1.00000e-02 *
#        3.6770, device='cuda:0')
# episode: 65000 loss tensor(1.00000e-04 *
#        3.3760, device='cuda:0')
# episode: 65500 loss tensor(0., device='cuda:0')
# episode: 66000 loss tensor(1.00000e-03 *
#        6.8889, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.19349164467897978
# gzsl: seen=0.0329, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 66500 loss tensor(1.00000e-02 *
#        1.9523, device='cuda:0')
# episode: 67000 loss tensor(1.00000e-03 *
#        6.1750, device='cuda:0')
# episode: 67500 loss tensor(1.00000e-03 *
#        2.9645, device='cuda:0')
# episode: 68000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.19718557607739665
# gzsl: seen=0.0329, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 68500 loss tensor(1.00000e-03 *
#        8.7080, device='cuda:0')
# episode: 69000 loss tensor(1.00000e-02 *
#        1.4786, device='cuda:0')
# episode: 69500 loss tensor(1.00000e-03 *
#        4.9906, device='cuda:0')
# episode: 70000 loss tensor(1.00000e-02 *
#        3.8317, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.20246262093227793
# gzsl: seen=0.0327, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 70500 loss tensor(0., device='cuda:0')
# episode: 71000 loss tensor(1.00000e-02 *
#        6.1674, device='cuda:0')
# episode: 71500 loss tensor(1.00000e-02 *
#        1.0942, device='cuda:0')
# episode: 72000 loss tensor(1.00000e-02 *
#        1.1477, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.20580474934036938
# gzsl: seen=0.0327, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 72500 loss tensor(0., device='cuda:0')
# episode: 73000 loss tensor(0., device='cuda:0')
# episode: 73500 loss tensor(0., device='cuda:0')
# episode: 74000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.20879507475813544
# gzsl: seen=0.0325, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 74500 loss tensor(1.00000e-02 *
#        4.0444, device='cuda:0')
# episode: 75000 loss tensor(0., device='cuda:0')
# episode: 75500 loss tensor(1.00000e-02 *
#        2.3085, device='cuda:0')
# episode: 76000 loss tensor(1.00000e-02 *
#        2.4217, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.21442392260334212
# gzsl: seen=0.0325, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 76500 loss tensor(0., device='cuda:0')
# episode: 77000 loss tensor(1.00000e-02 *
#        2.2411, device='cuda:0')
# episode: 77500 loss tensor(0., device='cuda:0')
# episode: 78000 loss tensor(1.00000e-02 *
#        1.4026, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.21635883905013192
# gzsl: seen=0.0327, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 78500 loss tensor(1.00000e-02 *
#        2.0260, device='cuda:0')
# episode: 79000 loss tensor(1.00000e-02 *
#        2.2903, device='cuda:0')
# episode: 79500 loss tensor(0., device='cuda:0')
# episode: 80000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.21741424802110818
# gzsl: seen=0.0319, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 80500 loss tensor(1.00000e-02 *
#        7.8152, device='cuda:0')
# episode: 81000 loss tensor(1.00000e-02 *
#        1.3023, device='cuda:0')
# episode: 81500 loss tensor(0., device='cuda:0')
# episode: 82000 loss tensor(1.00000e-03 *
#        1.9722, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.21794195250659631
# gzsl: seen=0.0319, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 82500 loss tensor(0., device='cuda:0')
# episode: 83000 loss tensor(1.00000e-02 *
#        2.2747, device='cuda:0')
# episode: 83500 loss tensor(1.00000e-02 *
#        1.4163, device='cuda:0')
# episode: 84000 loss tensor(1.00000e-03 *
#        8.5258, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2198768689533861
# gzsl: seen=0.0319, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 84500 loss tensor(0., device='cuda:0')
# episode: 85000 loss tensor(1.00000e-03 *
#        8.4925, device='cuda:0')
# episode: 85500 loss tensor(0., device='cuda:0')
# episode: 86000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2237467018469657
# gzsl: seen=0.0315, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 86500 loss tensor(0., device='cuda:0')
# episode: 87000 loss tensor(1.00000e-02 *
#        4.4312, device='cuda:0')
# episode: 87500 loss tensor(1.00000e-03 *
#        4.0083, device='cuda:0')
# episode: 88000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.22832014072119614
# gzsl: seen=0.0315, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 88500 loss tensor(1.00000e-03 *
#        1.7490, device='cuda:0')
# episode: 89000 loss tensor(1.00000e-02 *
#        4.4232, device='cuda:0')
# episode: 89500 loss tensor(1.00000e-02 *
#        7.1867, device='cuda:0')
# episode: 90000 loss tensor(1.00000e-03 *
#        8.8944, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.23025505716798592
# gzsl: seen=0.0315, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 90500 loss tensor(1.00000e-02 *
#        1.0893, device='cuda:0')
# episode: 91000 loss tensor(0., device='cuda:0')
# episode: 91500 loss tensor(0., device='cuda:0')
# episode: 92000 loss tensor(1.00000e-02 *
#        2.0161, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.23131046613896217
# gzsl: seen=0.0315, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 92500 loss tensor(1.00000e-02 *
#        2.8446, device='cuda:0')
# episode: 93000 loss tensor(1.00000e-02 *
#        1.7087, device='cuda:0')
# episode: 93500 loss tensor(1.00000e-02 *
#        2.3477, device='cuda:0')
# episode: 94000 loss tensor(1.00000e-02 *
#        3.0424, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.23324538258575198
# gzsl: seen=0.0315, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 94500 loss tensor(0., device='cuda:0')
# episode: 95000 loss tensor(1.00000e-03 *
#        9.7075, device='cuda:0')
# episode: 95500 loss tensor(0., device='cuda:0')
# episode: 96000 loss tensor(1.00000e-02 *
#        1.9552, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.23465259454705364
# gzsl: seen=0.0315, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 96500 loss tensor(1.00000e-02 *
#        3.0900, device='cuda:0')
# episode: 97000 loss tensor(0., device='cuda:0')
# episode: 97500 loss tensor(1.00000e-02 *
#        2.7340, device='cuda:0')
# episode: 98000 loss tensor(1.00000e-03 *
#        3.9210, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.24256816182937554
# gzsl: seen=0.0317, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 98500 loss tensor(1.00000e-02 *
#        2.8479, device='cuda:0')
# episode: 99000 loss tensor(1.00000e-03 *
#        1.2760, device='cuda:0')
# episode: 99500 loss tensor(0., device='cuda:0')
# episode: 100000 loss tensor(1.00000e-03 *
#        7.9050, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2494283201407212
# gzsl: seen=0.0317, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 100500 loss tensor(0., device='cuda:0')
# episode: 101000 loss tensor(0., device='cuda:0')
# episode: 101500 loss tensor(1.00000e-02 *
#        4.3072, device='cuda:0')
# episode: 102000 loss tensor(1.00000e-02 *
#        3.0154, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25065963060686014
# gzsl: seen=0.0315, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 102500 loss tensor(1.00000e-02 *
#        1.1820, device='cuda:0')
# episode: 103000 loss tensor(0., device='cuda:0')
# episode: 103500 loss tensor(1.00000e-02 *
#        8.2717, device='cuda:0')
# episode: 104000 loss tensor(1.00000e-04 *
#        7.4148, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25294635004397537
# gzsl: seen=0.0309, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 104500 loss tensor(1.00000e-02 *
#        2.8686, device='cuda:0')
# episode: 105000 loss tensor(1.00000e-03 *
#        1.7099, device='cuda:0')
# episode: 105500 loss tensor(1.00000e-02 *
#        6.2710, device='cuda:0')
# episode: 106000 loss tensor(1.00000e-03 *
#        4.2415, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2534740545294635
# gzsl: seen=0.0311, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 106500 loss tensor(1.00000e-03 *
#        8.0953, device='cuda:0')
# episode: 107000 loss tensor(1.00000e-04 *
#        2.3270, device='cuda:0')
# episode: 107500 loss tensor(1.00000e-02 *
#        1.5115, device='cuda:0')
# episode: 108000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25628847845206687
# gzsl: seen=0.0311, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 108500 loss tensor(1.00000e-02 *
#        3.4764, device='cuda:0')
# episode: 109000 loss tensor(1.00000e-02 *
#        2.3932, device='cuda:0')
# episode: 109500 loss tensor(0., device='cuda:0')
# episode: 110000 loss tensor(1.00000e-03 *
#        5.1064, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.256816182937555
# gzsl: seen=0.0311, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 110500 loss tensor(1.00000e-02 *
#        4.2654, device='cuda:0')
# episode: 111000 loss tensor(0., device='cuda:0')
# episode: 111500 loss tensor(0., device='cuda:0')
# episode: 112000 loss tensor(1.00000e-03 *
#        8.6751, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2583992963940194
# gzsl: seen=0.0311, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 112500 loss tensor(1.00000e-02 *
#        2.6360, device='cuda:0')
# episode: 113000 loss tensor(0., device='cuda:0')
# episode: 113500 loss tensor(1.00000e-03 *
#        4.6849, device='cuda:0')
# episode: 114000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25822339489885665
# gzsl: seen=0.0311, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 114500 loss tensor(1.00000e-02 *
#        5.9350, device='cuda:0')
# episode: 115000 loss tensor(0., device='cuda:0')
# episode: 115500 loss tensor(0., device='cuda:0')
# episode: 116000 loss tensor(1.00000e-02 *
#        1.1090, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2617414248021108
# gzsl: seen=0.0309, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 116500 loss tensor(1.00000e-02 *
#        1.6989, device='cuda:0')
# episode: 117000 loss tensor(1.00000e-02 *
#        4.4138, device='cuda:0')
# episode: 117500 loss tensor(1.00000e-02 *
#        1.8230, device='cuda:0')
# episode: 118000 loss tensor(1.00000e-02 *
#        1.6280, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.26191732629727354
# gzsl: seen=0.0307, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 118500 loss tensor(0., device='cuda:0')
# episode: 119000 loss tensor(1.00000e-02 *
#        3.1790, device='cuda:0')
# episode: 119500 loss tensor(0., device='cuda:0')
# episode: 120000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2620932277924362
# gzsl: seen=0.0309, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 120500 loss tensor(1.00000e-02 *
#        2.1247, device='cuda:0')
# episode: 121000 loss tensor(0., device='cuda:0')
# episode: 121500 loss tensor(0., device='cuda:0')
# episode: 122000 loss tensor(1.00000e-03 *
#        9.2216, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2620932277924362
# gzsl: seen=0.0309, unseen=0.0000, h=0.0000
# ...
# episode: 159000 loss tensor(0., device='cuda:0')
# episode: 159500 loss tensor(0., device='cuda:0')
# episode: 160000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.255584872471416
# gzsl: seen=0.0299, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 160500 loss tensor(0., device='cuda:0')
# episode: 161000 loss tensor(1.00000e-02 *
#        1.4163, device='cuda:0')
# episode: 161500 loss tensor(0., device='cuda:0')
# episode: 162000 loss tensor(1.00000e-02 *
#        1.3770, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25488126649076515
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 162500 loss tensor(0., device='cuda:0')
# episode: 163000 loss tensor(1.00000e-03 *
#        3.9024, device='cuda:0')
# episode: 163500 loss tensor(1.00000e-02 *
#        1.0017, device='cuda:0')
# episode: 164000 loss tensor(1.00000e-03 *
#        8.8539, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25400175901495164
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 164500 loss tensor(1.00000e-02 *
#        3.2326, device='cuda:0')
# episode: 165000 loss tensor(0., device='cuda:0')
# episode: 165500 loss tensor(0., device='cuda:0')
# episode: 166000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2534740545294635
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 166500 loss tensor(0., device='cuda:0')
# episode: 167000 loss tensor(0., device='cuda:0')
# episode: 167500 loss tensor(0., device='cuda:0')
# episode: 168000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25294635004397537
# gzsl: seen=0.0296, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 168500 loss tensor(1.00000e-02 *
#        2.9474, device='cuda:0')
# episode: 169000 loss tensor(0., device='cuda:0')
# episode: 169500 loss tensor(0., device='cuda:0')
# episode: 170000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25294635004397537
# gzsl: seen=0.0296, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 170500 loss tensor(0., device='cuda:0')
# episode: 171000 loss tensor(0., device='cuda:0')
# episode: 171500 loss tensor(0., device='cuda:0')
# episode: 172000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2511873350923483
# gzsl: seen=0.0296, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 172500 loss tensor(0., device='cuda:0')
# episode: 173000 loss tensor(1.00000e-03 *
#        2.7356, device='cuda:0')
# episode: 173500 loss tensor(0., device='cuda:0')
# episode: 174000 loss tensor(1.00000e-02 *
#        1.5713, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2510114335971856
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 174500 loss tensor(0., device='cuda:0')
# episode: 175000 loss tensor(1.00000e-02 *
#        1.9767, device='cuda:0')
# episode: 175500 loss tensor(0., device='cuda:0')
# episode: 176000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25030782761653475
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 176500 loss tensor(1.00000e-03 *
#        8.0185, device='cuda:0')
# episode: 177000 loss tensor(1.00000e-03 *
#        7.5841, device='cuda:0')
# episode: 177500 loss tensor(0., device='cuda:0')
# episode: 178000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2497801231310466
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 178500 loss tensor(0., device='cuda:0')
# episode: 179000 loss tensor(1.00000e-02 *
#        1.7197, device='cuda:0')
# episode: 179500 loss tensor(0., device='cuda:0')
# episode: 180000 loss tensor(1.00000e-03 *
#        3.0661, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.25013192612137203
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 180500 loss tensor(0., device='cuda:0')
# episode: 181000 loss tensor(0., device='cuda:0')
# episode: 181500 loss tensor(0., device='cuda:0')
# episode: 182000 loss tensor(1.00000e-02 *
#        2.1626, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.24960422163588392
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 182500 loss tensor(1.00000e-02 *
#        1.1279, device='cuda:0')
# episode: 183000 loss tensor(1.00000e-02 *
#        3.7263, device='cuda:0')
# episode: 183500 loss tensor(0., device='cuda:0')
# episode: 184000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2494283201407212
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 184500 loss tensor(1.00000e-04 *
#        9.2506, device='cuda:0')
# episode: 185000 loss tensor(0., device='cuda:0')
# episode: 185500 loss tensor(1.00000e-03 *
#        4.8261, device='cuda:0')
# episode: 186000 loss tensor(1.00000e-02 *
#        4.2126, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.24872471416007036
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 186500 loss tensor(0., device='cuda:0')
# episode: 187000 loss tensor(0., device='cuda:0')
# episode: 187500 loss tensor(0., device='cuda:0')
# episode: 188000 loss tensor(1.00000e-02 *
#        1.5477, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.24837291116974494
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 188500 loss tensor(1.00000e-03 *
#        3.2010, device='cuda:0')
# episode: 189000 loss tensor(1.00000e-02 *
#        1.3978, device='cuda:0')
# episode: 189500 loss tensor(0., device='cuda:0')
# episode: 190000 loss tensor(1.00000e-02 *
#        1.1872, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.24819700967458225
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 190500 loss tensor(1.00000e-02 *
#        1.2721, device='cuda:0')
# episode: 191000 loss tensor(1.00000e-03 *
#        4.6463, device='cuda:0')
# episode: 191500 loss tensor(0., device='cuda:0')
# episode: 192000 loss tensor(1.00000e-02 *
#        2.1012, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.24802110817941952
# gzsl: seen=0.0292, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 192500 loss tensor(0., device='cuda:0')
# episode: 193000 loss tensor(1.00000e-02 *
#        1.8280, device='cuda:0')
# episode: 193500 loss tensor(1.00000e-02 *
#        2.8682, device='cuda:0')
# episode: 194000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.24749340369393139
# gzsl: seen=0.0292, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 194500 loss tensor(1.00000e-02 *
#        1.2948, device='cuda:0')
# episode: 195000 loss tensor(0., device='cuda:0')
# episode: 195500 loss tensor(1.00000e-02 *
#        1.5790, device='cuda:0')
# episode: 196000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2473175021987687
# gzsl: seen=0.0294, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 196500 loss tensor(1.00000e-02 *
#        1.0959, device='cuda:0')
# episode: 197000 loss tensor(0., device='cuda:0')
# episode: 197500 loss tensor(1.00000e-02 *
#        3.0458, device='cuda:0')
# episode: 198000 loss tensor(0., device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.2473175021987687
# gzsl: seen=0.0292, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________
# episode: 198500 loss tensor(0., device='cuda:0')
# episode: 199000 loss tensor(0., device='cuda:0')
# episode: 199500 loss tensor(1.00000e-03 *
#        5.5799, device='cuda:0')
# episode: 200000 loss tensor(1.00000e-02 *
#        4.1755, device='cuda:0')
# Testing...
# class num: 10
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# class num: 50
# ____________________________________________________________________________________________________
# zsl: 0.24661389621811786
# gzsl: seen=0.0290, unseen=0.0000, h=0.0000
# ____________________________________________________________________________________________________

# %%
def compute_accuracy(test_features, test_label, test_id, test_attributes):
    
    test_data = TensorDataset(test_features, test_label)
    test_batch = 32
    test_loader = DataLoader(test_data, batch_size=test_batch, shuffle=False)
    total_rewards = 0

    sample_labels = test_id
    sample_attributes = test_attributes
    class_num = sample_attributes.shape[0]
    test_size = test_features.shape[0]

    print("class num:", class_num)
    print('_'*100)

    for batch_features,batch_labels in test_loader:

        batch_size = batch_labels.shape[0]
        batch_features_ext = torch.from_numpy(batch_features.numpy().repeat(class_num, 0))
        batch_features_ext = Variable(batch_features_ext).cuda(GPU).float()  # 32*1024

        #print(batch_features_ext)

        sample_features = attribute_network(Variable(sample_attributes).cuda(GPU).float())
        sample_features_ext = sample_features.repeat(batch_size, 1)
        #print(sample_features_ext.shape)


        relations = F.pairwise_distance(batch_features_ext, sample_features_ext, 2).view(-1, class_num)
        re_batch_labels = []
        for label in batch_labels.numpy():
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.cuda.LongTensor(re_batch_labels)


        _, predict_labels = torch.min(relations.data, 1)
        #print(predict_labels)
        rewards = [1 if predict_labels[j] == re_batch_labels[j] else 0 for j in range(batch_size)]
        total_rewards += np.sum(rewards)
    test_accuracy = total_rewards/1.0/test_size
    return  test_accuracy

#zsl_accuracy = compute_accuracy(test_features, test_label, test_id, test_attributes)
#gzsl_unseen_accuracy = compute_accuracy(test_features, test_label, np.arange(50), attributes)
#gzsl_seen_accuracy = compute_accuracy(test_seen_features, test_seen_label, np.arange(50), attributes)
#H = 2 * gzsl_seen_accuracy * gzsl_unseen_accuracy / (gzsl_unseen_accuracy + gzsl_seen_accuracy)

#print('zsl:', zsl_accuracy)
#print('gzsl: seen=%.4f, unseen=%.4f, h=%.4f' % (gzsl_seen_accuracy, gzsl_unseen_accuracy, H))
